# %%
# Import required libraries
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('training_data.csv')
data.head()
# Out:
#          name team position  games  receptions  targets  receiving_yards  \
# 0  A.J. Brown  TEN       WR     16          52       84           1051.0
# 1  A.J. Brown  TEN       WR     14          70      106           1075.0
# 2  A.J. Brown  TEN       WR     13          63      105            869.0
# 3  A.J. Brown  PHI       WR     17          88      145           1496.0
# 4  A.J. Brown  PHI       WR     17         106      158           1456.0
#
#    rec_ypg  receiving_tds    ypr  ...  sacks  sack_fumbles  offense_snaps  \
# 0    65.69              8  20.21  ...    0.0             0          678.0
# 1    76.79             11  15.36  ...    0.0             0          760.0
# 2    66.85              5  13.79  ...    0.0             0          604.0
# 3    88.00             11  17.00  ...    0.0             0         1004.0
# 4    85.65              7  13.74  ...    0.0             0         1019.0
#
#    teams_offense_snaps  round  overall             stadium_name  \
# 0                997.0    2.0     51.0           Nissan Stadium
# 1                945.0    2.0     51.0           Nissan Stadium
# 2                876.0    2.0     51.0           Nissan Stadium
# 3               1189.0    2.0     51.0  Lincoln Financial Field
# 4               1154.0    2.0     51.0  Lincoln Financial Field
#
#    stadium_weather_type  stadium_surface  fantasy_points_ppr
# 0              moderate            Grass               217.1
# 1              moderate            Grass               247.5
# 2              moderate            Grass               180.9
# 3                  cold            Grass               299.6
# 4                  cold            Grass               289.6
#
# [5 rows x 40 columns]

# %%
data.columns
# Out:
# Index(['name', 'team', 'position', 'games', 'receptions', 'targets',
#        'receiving_yards', 'rec_ypg', 'receiving_tds', 'ypr',
#        'receiving_fumbles', 'receiving_2pt_conversions', 'target_share',
#        'air_yards_share', 'carries', 'rushing_yards', 'rush_ypg',
#        'rushing_tds', 'rush_td_percentage', 'rushing_fumbles',
#        'rushing_2pt_conversions', 'completions', 'attempts', 'comp_percentage',
#        'passing_yards', 'pass_ypg', 'passing_tds', 'passing_2pt_conversions',
#        'td_percentage', 'interceptions', 'sacks', 'sack_fumbles',
#        'offense_snaps', 'teams_offense_snaps', 'round', 'overall',
#        'stadium_name', 'stadium_weather_type', 'stadium_surface',
#        'fantasy_points_ppr'],
#       dtype='object')

# %%
data = data.drop(columns = ['name', 'team', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions'])
data
# Out:
#      position  games  targets  rec_ypg    ypr  receiving_fumbles  \
# 0          WR     16       84    65.69  20.21                1.0
# 1          WR     14      106    76.79  15.36                2.0
# 2          WR     13      105    66.85  13.79                0.0
# 3          WR     17      145    88.00  17.00                2.0
# 4          WR     17      158    85.65  13.74                2.0
# ...       ...    ...      ...      ...    ...                ...
# 2101       WR     16      102    40.75  11.64                1.0
# 2102       WR     11       20    14.00  11.00                0.0
# 2103       WR     15       70    36.40  11.62                1.0
# 2104       WR     16      121    51.44  10.04                0.0
# 2105       WR      9       64    35.67   9.44                0.0
#
#       target_share  air_yards_share  carries  rush_ypg  ...  sacks  \
# 0             0.20             0.29        3      3.75  ...    0.0
# 1             0.27             0.35        0      0.00  ...    0.0
# 2             0.28             0.45        2      0.77  ...    0.0
# 3             0.29             0.41        0      0.00  ...    0.0
# 4             0.30             0.42        0      0.00  ...    0.0
# ...            ...              ...      ...       ...  ...    ...
# 2101          0.21             0.26        1      0.00  ...    0.0
# 2102          0.05             0.04        0      0.00  ...    0.0
# 2103          0.14             0.24        2      0.20  ...    0.0
# 2104          0.22             0.26        4      1.12  ...    0.0
# 2105          0.18             0.27        0      0.00  ...    0.0
#
#       sack_fumbles  offense_snaps  teams_offense_snaps  round  overall  \
# 0                0          678.0                997.0    2.0     51.0
# 1                0          760.0                945.0    2.0     51.0
# 2                0          604.0                876.0    2.0     51.0
# 3                0         1004.0               1189.0    2.0     51.0
# 4                0         1019.0               1154.0    2.0     51.0
# ...            ...            ...                  ...    ...      ...
# 2101             0          941.0               1063.0    2.0     37.0
# 2102             0          248.0                771.0    2.0     37.0
# 2103             0          614.0               1026.0    2.0     37.0
# 2104             0          930.0               1082.0    2.0     37.0
# 2105             0          475.0                655.0    2.0     37.0
#
#                  stadium_name  stadium_weather_type  stadium_surface  \
# 0              Nissan Stadium              moderate            Grass
# 1              Nissan Stadium              moderate            Grass
# 2              Nissan Stadium              moderate            Grass
# 3     Lincoln Financial Field                  cold            Grass
# 4     Lincoln Financial Field                  cold            Grass
# ...                       ...                   ...              ...
# 2101            New Era Field                  cold        FieldTurf
# 2102        Allegiant Stadium                indoor            Grass
# 2103        Allegiant Stadium                indoor            Grass
# 2104          TIAA Bank Field                  warm            Grass
# 2105          TIAA Bank Field                  warm            Grass
#
#       fantasy_points_ppr
# 0                 217.10
# 1                 247.50
# 2                 180.90
# 3                 299.60
# 4                 289.60
# ...                  ...
# 2101              165.20
# 2102               36.56
# 2103              105.90
# 2104              198.10
# 2105               78.10
#
# [2106 rows x 27 columns]

# %%
# Encoding categorical columns for model
encoded_data = pd.get_dummies(data)
encoded_data
# Out:
#       games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 0        16       84    65.69  20.21                1.0          0.20
# 1        14      106    76.79  15.36                2.0          0.27
# 2        13      105    66.85  13.79                0.0          0.28
# 3        17      145    88.00  17.00                2.0          0.29
# 4        17      158    85.65  13.74                2.0          0.30
# ...     ...      ...      ...    ...                ...           ...
# 2101     16      102    40.75  11.64                1.0          0.21
# 2102     11       20    14.00  11.00                0.0          0.05
# 2103     15       70    36.40  11.62                1.0          0.14
# 2104     16      121    51.44  10.04                0.0          0.22
# 2105      9       64    35.67   9.44                0.0          0.18
#
#       air_yards_share  carries  rush_ypg  rush_td_percentage  ...  \
# 0                0.29        3      3.75                0.33  ...
# 1                0.35        0      0.00                0.00  ...
# 2                0.45        2      0.77                0.00  ...
# 3                0.41        0      0.00                0.00  ...
# 4                0.42        0      0.00                0.00  ...
# ...               ...      ...       ...                 ...  ...
# 2101             0.26        1      0.00                0.00  ...
# 2102             0.04        0      0.00                0.00  ...
# 2103             0.24        2      0.20                0.00  ...
# 2104             0.26        4      1.12                0.00  ...
# 2105             0.27        0      0.00                0.00  ...
#
#       stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 0                          False                            False
# 1                          False                            False
# 2                          False                            False
# 3                          False                            False
# 4                          False                            False
# ...                          ...                              ...
# 2101                       False                            False
# 2102                       False                            False
# 2103                       False                            False
# 2104                       False                            False
# 2105                       False                            False
#
#       stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ...                            ...                             ...
# 2101                         False                           False
# 2102                         False                           False
# 2103                         False                           False
# 2104                          True                           False
# 2105                          True                           False
#
#       stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                          True                        False
# 4                          True                        False
# ...                         ...                          ...
# 2101                       True                        False
# 2102                      False                         True
# 2103                      False                         True
# 2104                      False                        False
# 2105                      False                        False
#
#       stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                              True                      False
# 1                              True                      False
# 2                              True                      False
# 3                             False                      False
# 4                             False                      False
# ...                             ...                        ...
# 2101                          False                      False
# 2102                          False                      False
# 2103                          False                      False
# 2104                          False                       True
# 2105                          False                       True
#
#       stadium_surface_FieldTurf  stadium_surface_Grass
# 0                         False                   True
# 1                         False                   True
# 2                         False                   True
# 3                         False                   True
# 4                         False                   True
# ...                         ...                    ...
# 2101                       True                  False
# 2102                      False                   True
# 2103                      False                   True
# 2104                      False                   True
# 2105                      False                   True
#
# [2106 rows x 64 columns]

# %%
# Defining y (target variable)
y = encoded_data['fantasy_points_ppr']

# Defining X (features)
X = encoded_data.drop(columns = 'fantasy_points_ppr')

X.shape
# Out:
# (2106, 63)

# %%
# Spliting model into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=42)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
intercept = lr_model.intercept_
intercept
# Out:
# -9.038865919951547

# %%
m = lr_model.coef_
m
# Out:
# array([ 1.08175753e+00,  1.44975250e+00,  1.64774209e+00, -7.53834106e-01,
#        -3.39064198e-01, -2.74178224e+02, -9.59526852e+00,  5.10205193e-01,
#         5.84696326e-01,  2.01562709e+01,  1.59880565e+00,  4.55855109e-01,
#         3.43177297e+00,  4.84189756e-02,  5.38977260e+00,  6.56244520e+01,
#        -4.54421452e-01, -2.86351604e+00,  2.97876185e-03, -7.87182259e-03,
#        -6.01545745e+00,  1.81662892e-01, -8.36461804e+00, -3.65299175e+00,
#         7.43564424e+00,  4.58196555e+00,  4.57554709e-01, -1.23873546e+00,
#         4.42967909e+00, -9.93650118e+00,  8.26452153e+00, -7.16446075e-01,
#        -5.03282130e+00, -3.57196566e+00,  2.56803548e+00,  1.12149078e+00,
#        -1.62189031e+00,  2.57772145e+00, -5.42276989e+00,  5.21336165e+00,
#         8.54334462e-01,  3.91101178e+00,  2.18229187e+00, -4.20790762e+00,
#         2.81323449e+00, -4.86153936e+00,  3.64649427e+00, -7.60233372e+00,
#         3.44963017e+00,  4.16506708e+00,  4.33206999e+00, -5.20663852e-01,
#        -9.63744649e-01, -4.18804697e-01,  4.78156724e-01, -3.95221013e+00,
#        -3.96321643e-01, -3.32128681e-01, -1.55117743e+00,  2.75569364e+00,
#        -8.72387528e-01,  1.25770636e+00, -1.25770636e+00])

# %%
predictions = lr_model.predict(X_train)

# %%
len(predictions)
# Out:
# 1579

# %%
r2_score(y_train, predictions)
# Out:
# 0.9649431595700579

# %%
mse = mean_squared_error(y_train, predictions)
mse
# Out:
# 335.86987759548003

# %%
prediction_data = pd.read_csv('predicting_data.csv')
prediction_data.head()
# Out:
#             name team position      games  receptions     targets  \
# 0     A.J. Brown  PHI       WR  15.400000   75.800000  119.600000
# 1     A.T. Perry   NO       WR   8.000000   12.000000   18.000000
# 2    AJ McCarron  CIN       QB   2.000000    0.000000    0.000000
# 3    Aaron Jones   GB       RB  13.571429   38.857143   52.000000
# 4  Aaron Rodgers  NYJ       QB  13.272727    0.181818    0.181818
#
#    receiving_yards    rec_ypg  receiving_tds        ypr  ...  interceptions  \
# 0      1189.400000  76.596000       8.400000  16.020000  ...       0.000000
# 1       246.000000  30.750000       4.000000  20.500000  ...       0.000000
# 2         0.000000   0.000000       0.000000   0.000000  ...       0.250000
# 3       296.571429  20.691429       2.571429   7.080000  ...       0.000000
# 4        -0.909091  -0.057273       0.000000  -0.909091  ...       5.363636
#
#        sacks  sack_fumbles  offense_snaps  teams_offense_snaps  round  \
# 0   0.000000      0.000000     813.000000          1032.200000    2.0
# 1   0.000000      0.000000     319.000000           519.000000    6.0
# 2   2.000000      0.000000       0.000000             0.000000    0.0
# 3   0.000000      0.000000     482.285714           890.285714    5.0
# 4  29.090909      3.363636     847.636364           891.181818    1.0
#
#    overall             stadium_name  stadium_weather_type  stadium_surface
# 0     51.0  Lincoln Financial Field                  cold            Grass
# 1    195.0  Mercedes-Benz Superdome                indoor        FieldTurf
# 2      0.0       Paul Brown Stadium                  cold        FieldTurf
# 3    182.0            Lambeau Field                  cold            Grass
# 4     24.0          MetLife Stadium                  cold        FieldTurf
#
# [5 rows x 39 columns]

# %%
prediction_data_cleaned.columns
# Out:
# Index(['position', 'games', 'receptions', 'targets', 'receiving_yards',
#        'rec_ypg', 'receiving_tds', 'ypr', 'receiving_fumbles',
#        'receiving_2pt_conversions', 'target_share', 'air_yards_share',
#        'carries', 'rushing_yards', 'rush_ypg', 'rushing_tds',
#        'rush_td_percentage', 'rushing_fumbles', 'rushing_2pt_conversions',
#        'completions', 'attempts', 'comp_percentage', 'passing_yards',
#        'pass_ypg', 'passing_tds', 'passing_2pt_conversions', 'td_percentage',
#        'interceptions', 'sacks', 'sack_fumbles', 'offense_snaps',
#        'teams_offense_snaps', 'round', 'overall', 'stadium_weather_type',
#        'stadium_surface'],
#       dtype='object')

# %%
prediction_data_cleaned = prediction_data.drop(columns = ['name', 'team', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions'])
prediction_data_cleaned.head()
# Out:
#   position      games     targets    rec_ypg        ypr  receiving_fumbles  \
# 0       WR  15.400000  119.600000  76.596000  16.020000           1.400000
# 1       WR   8.000000   18.000000  30.750000  20.500000           0.000000
# 2       QB   2.000000    0.000000   0.000000   0.000000           0.000000
# 3       RB  13.571429   52.000000  20.691429   7.080000           0.857143
# 4       QB  13.272727    0.181818  -0.057273  -0.909091           0.000000
#
#    target_share  air_yards_share     carries   rush_ypg  ...  td_percentage  \
# 0      0.268000         0.384000    1.000000   0.904000  ...       0.116000
# 1      0.070000         0.160000    0.000000   0.000000  ...       0.330000
# 2      0.000000         0.000000    1.250000   4.875000  ...       0.005000
# 3      0.115714         0.007143  168.142857  61.561429  ...       0.042857
# 4      0.000000         0.000000   37.818182  12.918182  ...       0.052727
#
#        sacks  sack_fumbles  offense_snaps  teams_offense_snaps  round  \
# 0   0.000000      0.000000     813.000000          1032.200000    2.0
# 1   0.000000      0.000000     319.000000           519.000000    6.0
# 2   2.000000      0.000000       0.000000             0.000000    0.0
# 3   0.000000      0.000000     482.285714           890.285714    5.0
# 4  29.090909      3.363636     847.636364           891.181818    1.0
#
#    overall             stadium_name  stadium_weather_type  stadium_surface
# 0     51.0  Lincoln Financial Field                  cold            Grass
# 1    195.0  Mercedes-Benz Superdome                indoor        FieldTurf
# 2      0.0       Paul Brown Stadium                  cold        FieldTurf
# 3    182.0            Lambeau Field                  cold            Grass
# 4     24.0          MetLife Stadium                  cold        FieldTurf
#
# [5 rows x 26 columns]

# %%
# Encoding categorical columns for model
encoded_prediction_data = pd.get_dummies(prediction_data_cleaned)
encoded_prediction_data
# Out:
#          games     targets    rec_ypg        ypr  receiving_fumbles  \
# 0    15.400000  119.600000  76.596000  16.020000           1.400000
# 1     8.000000   18.000000  30.750000  20.500000           0.000000
# 2     2.000000    0.000000   0.000000   0.000000           0.000000
# 3    13.571429   52.000000  20.691429   7.080000           0.857143
# 4    13.272727    0.181818  -0.057273  -0.909091           0.000000
# ..         ...         ...        ...        ...                ...
# 519  11.333333    0.666667   0.073333   0.666667           0.000000
# 520  12.000000   23.000000   9.417500   6.367500           0.500000
# 521  12.000000    9.500000   3.770000   3.265000           0.000000
# 522  16.000000  108.000000  53.620000  11.140000           0.000000
# 523  13.500000   75.166667  33.471667  10.906667           0.333333
#
#      target_share  air_yards_share     carries   rush_ypg  rush_td_percentage  \
# 0        0.268000         0.384000    1.000000   0.904000            0.066000
# 1        0.070000         0.160000    0.000000   0.000000            0.000000
# 2        0.000000         0.000000    1.250000   4.875000            0.050000
# 3        0.115714         0.007143  168.142857  61.561429            0.037143
# 4        0.000000         0.000000   37.818182  12.918182            0.036364
# ..            ...              ...         ...        ...                 ...
# 519      0.000000         0.003333   31.000000  14.380000            0.060000
# 520      0.050000         0.002500  116.750000  41.467500            0.030000
# 521      0.020000         0.000000   60.500000  20.525000            0.005000
# 522      0.240000         0.240000    8.000000   3.500000            0.120000
# 523      0.163333         0.225000    1.166667   0.220000            0.000000
#
#      ...  stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 0    ...                       False                            False
# 1    ...                       False                            False
# 2    ...                       False                            False
# 3    ...                       False                            False
# 4    ...                       False                            False
# ..   ...                         ...                              ...
# 519  ...                       False                            False
# 520  ...                       False                            False
# 521  ...                       False                            False
# 522  ...                       False                            False
# 523  ...                       False                            False
#
#      stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# ..                            ...                             ...
# 519                         False                           False
# 520                         False                           False
# 521                         False                           False
# 522                         False                           False
# 523                          True                           False
#
#      stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         True                        False
# 1                        False                         True
# 2                         True                        False
# 3                         True                        False
# 4                         True                        False
# ..                         ...                          ...
# 519                       True                        False
# 520                      False                         True
# 521                      False                         True
# 522                      False                        False
# 523                      False                        False
#
#      stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# ..                             ...                        ...
# 519                          False                      False
# 520                          False                      False
# 521                          False                      False
# 522                           True                      False
# 523                          False                       True
#
#      stadium_surface_FieldTurf  stadium_surface_Grass
# 0                        False                   True
# 1                         True                  False
# 2                         True                  False
# 3                        False                   True
# 4                         True                  False
# ..                         ...                    ...
# 519                       True                  False
# 520                       True                  False
# 521                      False                   True
# 522                       True                  False
# 523                      False                   True
#
# [524 rows x 63 columns]

# %%
list_of_lists = encoded_prediction_data.values.tolist()  # Get a list of rows
test = list_of_lists[5]

real_predictions = lr_model.predict([test])
real_predictions
# Out:
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([160.05047641])

# %%
names_list = prediction_data['name'].tolist()

# %%
# Assuming encoded_prediction_data has data
list_of_lists = encoded_prediction_data.values.tolist()  # Get a list of rows

# Initialize an empty list to store all predictions
all_predictions = []

# Loop through each index from 0 to 524 (inclusive)
for index in range(524):
  # Get the data for the current index
  data_for_prediction = list_of_lists[index]

  # Make prediction using your model
  prediction = lr_model.predict([data_for_prediction])

  # Append the prediction to the all_predictions list
  all_predictions.append(prediction)  # Assuming single prediction per row

# Print or use the all_predictions list for further analysis
all_predictions
# Out:
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [array([226.10292925]),
#  array([65.98481716]),
#  array([0.03570406]),
#  array([202.48393255]),
#  array([221.97106862]),
#  array([160.05047641]),
#  array([46.95854051]),
#  array([150.79324548]),
#  array([32.50862276]),
#  array([111.90751406]),
#  array([3.57939838]),
#  array([41.66119988]),
#  array([111.70721244]),
#  array([88.1652287]),
#  array([155.72053547]),
#  array([269.63377875]),
#  array([218.12812875]),
#  array([2.38917698]),
#  array([57.35587889]),
#  array([259.75509747]),
#  array([47.96227359]),
#  array([36.88734318]),
#  array([186.60708472]),
#  array([-2.73414523]),
#  array([70.66730938]),
#  array([-10.04614775]),
#  array([183.80535597]),
#  array([228.21484421]),
#  array([104.00213774]),
#  array([-9.48039665]),
#  array([69.10299984]),
#  array([207.75941753]),
#  array([24.3161922]),
#  array([54.66234133]),
#  array([259.90921749]),
#  array([43.96403304]),
#  array([21.71938536]),
#  array([68.96144622]),
#  array([70.03329471]),
#  array([201.89737798]),
#  array([195.24878866]),
#  array([33.36364262]),
#  array([31.14026748]),
#  array([37.6716436]),
#  array([71.90849278]),
#  array([201.42429775]),
#  array([9.82012984]),
#  array([43.60117252]),
#  array([9.48726292]),
#  array([178.35105069]),
#  array([8.7783553]),
#  array([163.13815566]),
#  array([41.93793724]),
#  array([216.46914546]),
#  array([10.49342862]),
#  array([50.62746526]),
#  array([36.05067149]),
#  array([232.98637175]),
#  array([49.69518564]),
#  array([108.09012903]),
#  array([49.39913787]),
#  array([191.14838755]),
#  array([71.32674042]),
#  array([211.29871648]),
#  array([99.90278119]),
#  array([58.19130317]),
#  array([273.3388735]),
#  array([14.19268509]),
#  array([36.59201742]),
#  array([4.29581448]),
#  array([54.57023803]),
#  array([105.17312968]),
#  array([87.38898484]),
#  array([111.58295329]),
#  array([72.37346848]),
#  array([14.76692878]),
#  array([206.87792636]),
#  array([2.77915906]),
#  array([53.86810064]),
#  array([226.6093006]),
#  array([37.1847996]),
#  array([166.98277238]),
#  array([266.60262515]),
#  array([119.27188764]),
#  array([143.38694298]),
#  array([-1.69663291]),
#  array([125.20185634]),
#  array([7.42964098]),
#  array([46.56254524]),
#  array([-11.93710064]),
#  array([115.98121493]),
#  array([5.43131805]),
#  array([27.25081234]),
#  array([-5.95307828]),
#  array([37.03659753]),
#  array([217.95022343]),
#  array([20.72277734]),
#  array([126.5935061]),
#  array([143.54022423]),
#  array([29.45801662]),
#  array([123.03747005]),
#  array([192.54289826]),
#  array([28.60719765]),
#  array([73.3650935]),
#  array([21.9136709]),
#  array([114.55009058]),
#  array([14.38874887]),
#  array([225.09947362]),
#  array([248.96761111]),
#  array([251.56628051]),
#  array([130.97677361]),
#  array([157.96958186]),
#  array([112.82795854]),
#  array([154.67674553]),
#  array([81.4702936]),
#  array([54.33951525]),
#  array([56.5083663]),
#  array([194.64127684]),
#  array([45.15415703]),
#  array([132.70909905]),
#  array([144.06279595]),
#  array([5.10857303]),
#  array([86.63288646]),
#  array([129.94692751]),
#  array([-2.09052085]),
#  array([237.9519147]),
#  array([49.87942256]),
#  array([212.38040693]),
#  array([64.05898844]),
#  array([112.43948881]),
#  array([-30.72695922]),
#  array([32.14219858]),
#  array([135.32891936]),
#  array([103.34134515]),
#  array([54.42189316]),
#  array([248.89576452]),
#  array([134.62688784]),
#  array([209.78376463]),
#  array([53.61114105]),
#  array([188.1426479]),
#  array([86.24223247]),
#  array([130.3492786]),
#  array([24.34982474]),
#  array([22.16294825]),
#  array([256.80818018]),
#  array([28.91654664]),
#  array([23.293001]),
#  array([218.49898038]),
#  array([195.67359548]),
#  array([129.76410657]),
#  array([17.52532579]),
#  array([17.09800567]),
#  array([60.32378223]),
#  array([184.31105952]),
#  array([0.15366563]),
#  array([200.25279084]),
#  array([53.53822848]),
#  array([86.04145351]),
#  array([122.99793706]),
#  array([47.85402809]),
#  array([171.62665648]),
#  array([110.05730535]),
#  array([29.94758406]),
#  array([46.56615223]),
#  array([30.77570512]),
#  array([35.7366996]),
#  array([4.16243239]),
#  array([-3.7205408]),
#  array([34.88899152]),
#  array([97.50449899]),
#  array([137.9889744]),
#  array([13.10267901]),
#  array([73.99922099]),
#  array([33.44851716]),
#  array([4.07974603]),
#  array([14.61676283]),
#  array([-3.98635137]),
#  array([159.21178127]),
#  array([-17.07548925]),
#  array([259.21815288]),
#  array([72.98092036]),
#  array([175.36917406]),
#  array([135.74149863]),
#  array([246.69119501]),
#  array([0.32238281]),
#  array([112.27141246]),
#  array([21.36806355]),
#  array([180.85620548]),
#  array([172.75018399]),
#  array([102.24077708]),
#  array([-1.82861961]),
#  array([15.00327415]),
#  array([65.34108101]),
#  array([36.33862622]),
#  array([-0.89850237]),
#  array([114.35362202]),
#  array([55.48322772]),
#  array([70.89573607]),
#  array([126.5963552]),
#  array([7.15820228]),
#  array([121.03481525]),
#  array([32.62668655]),
#  array([27.13665258]),
#  array([67.84583836]),
#  array([-25.79683433]),
#  array([65.9332051]),
#  array([98.22661256]),
#  array([53.94200114]),
#  array([8.98868345]),
#  array([183.29846033]),
#  array([7.38471496]),
#  array([76.5938573]),
#  array([260.1358572]),
#  array([9.50284246]),
#  array([98.11468761]),
#  array([122.31524766]),
#  array([228.68153478]),
#  array([82.03801297]),
#  array([132.8642072]),
#  array([113.20979103]),
#  array([155.04732401]),
#  array([88.62824591]),
#  array([21.54945936]),
#  array([42.3573718]),
#  array([265.70178702]),
#  array([18.73125732]),
#  array([55.70974793]),
#  array([26.91989772]),
#  array([52.75063019]),
#  array([144.36443661]),
#  array([49.23813418]),
#  array([159.84134804]),
#  array([176.49599368]),
#  array([182.79555568]),
#  array([20.92980268]),
#  array([5.79475499]),
#  array([48.7030362]),
#  array([118.41969611]),
#  array([239.50171043]),
#  array([-4.27939978]),
#  array([16.73712238]),
#  array([-29.30244697]),
#  array([13.61124562]),
#  array([69.95786884]),
#  array([148.33991559]),
#  array([158.95548978]),
#  array([186.5350208]),
#  array([233.46112261]),
#  array([144.69143928]),
#  array([53.24145748]),
#  array([9.76707559]),
#  array([122.73089624]),
#  array([106.98321444]),
#  array([146.64700735]),
#  array([18.47780966]),
#  array([90.19593607]),
#  array([150.70166654]),
#  array([230.8574121]),
#  array([137.75945663]),
#  array([227.7512225]),
#  array([40.54294673]),
#  array([-2.28726286]),
#  array([17.60590515]),
#  array([99.8890464]),
#  array([214.57732339]),
#  array([16.10619979]),
#  array([16.70657721]),
#  array([79.97258388]),
#  array([197.93998162]),
#  array([71.60046671]),
#  array([112.50522027]),
#  array([35.06774362]),
#  array([-28.35304369]),
#  array([320.25629817]),
#  array([160.94789907]),
#  array([254.47674434]),
#  array([23.21561365]),
#  array([131.57093302]),
#  array([90.72821948]),
#  array([26.73774172]),
#  array([32.85252969]),
#  array([64.93912376]),
#  array([27.94288284]),
#  array([163.34096304]),
#  array([8.68794157]),
#  array([223.47485001]),
#  array([54.39982553]),
#  array([206.18075511]),
#  array([310.8929022]),
#  array([294.68065188]),
#  array([48.59860487]),
#  array([10.4880534]),
#  array([92.04530979]),
#  array([-8.90633825]),
#  array([147.37713143]),
#  array([76.69769083]),
#  array([56.18001199]),
#  array([162.87316722]),
#  array([-10.23252633]),
#  array([72.41010821]),
#  array([-12.43353769]),
#  array([254.62996379]),
#  array([10.76619071]),
#  array([46.40948482]),
#  array([105.27338847]),
#  array([-1.18956124]),
#  array([99.82588916]),
#  array([217.13050236]),
#  array([185.68624384]),
#  array([-2.18274801]),
#  array([116.57252852]),
#  array([10.70402864]),
#  array([-2.40692862]),
#  array([16.91008861]),
#  array([106.33174391]),
#  array([69.66558196]),
#  array([219.94076107]),
#  array([38.93658408]),
#  array([-5.21622502]),
#  array([55.70265687]),
#  array([25.56716315]),
#  array([127.68469459]),
#  array([-16.42946189]),
#  array([53.91135483]),
#  array([265.48118882]),
#  array([136.04440047]),
#  array([27.63534686]),
#  array([276.28697051]),
#  array([38.20960213]),
#  array([136.43753909]),
#  array([97.39283654]),
#  array([20.28647345]),
#  array([194.43316403]),
#  array([13.83733305]),
#  array([78.25380995]),
#  array([-11.2871258]),
#  array([20.50647971]),
#  array([6.53011296]),
#  array([82.20002297]),
#  array([34.04079528]),
#  array([49.36786558]),
#  array([214.50763444]),
#  array([50.33023933]),
#  array([39.99314614]),
#  array([-4.53880289]),
#  array([23.19950041]),
#  array([45.62725712]),
#  array([131.56891296]),
#  array([172.40038756]),
#  array([116.02566838]),
#  array([167.20531735]),
#  array([59.89225367]),
#  array([160.8913724]),
#  array([58.99687999]),
#  array([-4.85924648]),
#  array([42.0863691]),
#  array([2.19230674]),
#  array([79.87233263]),
#  array([246.38123763]),
#  array([102.69556855]),
#  array([199.07355901]),
#  array([112.08964988]),
#  array([139.5511891]),
#  array([62.44492968]),
#  array([201.84497943]),
#  array([201.23475549]),
#  array([110.26054648]),
#  array([243.76204201]),
#  array([115.20099464]),
#  array([-12.2992593]),
#  array([49.68113096]),
#  array([121.13673207]),
#  array([9.24217289]),
#  array([170.9365634]),
#  array([131.75677308]),
#  array([12.58523164]),
#  array([48.81166684]),
#  array([16.58054266]),
#  array([261.67602015]),
#  array([-7.11408743]),
#  array([-3.79939958]),
#  array([124.78207028]),
#  array([186.17230794]),
#  array([56.96424734]),
#  array([13.61159418]),
#  array([20.04831287]),
#  array([94.70043567]),
#  array([148.84564666]),
#  array([56.51468259]),
#  array([136.06894891]),
#  array([62.86792503]),
#  array([68.00357695]),
#  array([36.42472785]),
#  array([49.93045087]),
#  array([118.18527992]),
#  array([273.5262717]),
#  array([18.38473952]),
#  array([8.46268358]),
#  array([32.9974722]),
#  array([26.98499415]),
#  array([49.69524929]),
#  array([36.02533444]),
#  array([304.70637338]),
#  array([105.26140232]),
#  array([68.28840798]),
#  array([35.31330108]),
#  array([227.20810196]),
#  array([10.76109139]),
#  array([82.96965301]),
#  array([2.86507833]),
#  array([130.40898542]),
#  array([53.41256982]),
#  array([197.38751753]),
#  array([123.04587574]),
#  array([91.82024743]),
#  array([45.63020434]),
#  array([182.1171593]),
#  array([62.63790954]),
#  array([43.36753569]),
#  array([23.27996792]),
#  array([29.71798195]),
#  array([60.24578959]),
#  array([168.83083969]),
#  array([-18.53538065]),
#  array([138.78275872]),
#  array([107.10791283]),
#  array([46.31741686]),
#  array([13.65413711]),
#  array([101.64856675]),
#  array([24.53061313]),
#  array([65.38256732]),
#  array([250.61346051]),
#  array([210.56344952]),
#  array([44.28114351]),
#  array([151.64565401]),
#  array([157.40749639]),
#  array([203.21757928]),
#  array([68.56155006]),
#  array([22.72073385]),
#  array([218.4716824]),
#  array([51.22874414]),
#  array([-5.32018223]),
#  array([4.24463287]),
#  array([-2.78401349]),
#  array([-11.37828646]),
#  array([29.5072127]),
#  array([60.14954819]),
#  array([242.39309596]),
#  array([1.79977075]),
#  array([117.25865502]),
#  array([50.4129113]),
#  array([17.50016699]),
#  array([154.75176513]),
#  array([22.48029527]),
#  array([173.225082]),
#  array([31.65747807]),
#  array([76.4992448]),
#  array([94.34075824]),
#  array([22.26823842]),
#  array([113.34770422]),
#  array([190.63556729]),
#  array([48.48798373]),
#  array([211.43430483]),
#  array([2.63457105]),
#  array([92.4485302]),
#  array([46.97883963]),
#  array([0.50465915]),
#  array([169.24807931]),
#  array([246.98501018]),
#  array([24.54980871]),
#  array([241.06083708]),
#  array([7.70127696]),
#  array([67.85978264]),
#  array([38.96551597]),
#  array([35.99553879]),
#  array([28.36680099]),
#  array([0.38792287]),
#  array([293.31142352]),
#  array([67.20197167]),
#  array([121.83019036]),
#  array([102.80632095]),
#  array([11.87894604]),
#  array([72.83836696]),
#  array([-8.19720571]),
#  array([200.76966952]),
#  array([-10.43999814]),
#  array([87.50661187]),
#  array([91.90436202]),
#  array([53.10693202]),
#  array([72.77468423]),
#  array([20.25269105]),
#  array([164.43030589]),
#  array([2.08741274]),
#  array([149.46121847]),
#  array([170.53487423]),
#  array([78.19642969]),
#  array([5.79198625]),
#  array([109.15597207]),
#  array([63.99724981]),
#  array([46.44564481]),
#  array([188.53576801]),
#  array([40.9311097]),
#  array([48.76122286]),
#  array([268.76755819]),
#  array([12.44457334]),
#  array([103.41214265]),
#  array([80.2405399]),
#  array([73.84741099]),
#  array([19.54520222]),
#  array([82.31894409]),
#  array([69.20996704]),
#  array([117.92619772]),
#  array([39.51516754]),
#  array([93.35295275]),
#  array([61.89808769]),
#  array([27.28174169]),
#  array([133.63091558]),
#  array([-0.26896928]),
#  array([80.05113585]),
#  array([144.77501905]),
#  array([104.60179728]),
#  array([44.91425685]),
#  array([193.40771398]),
#  array([108.14719057])]

# %%
fantasy_2024_predictions = pd.DataFrame(list(zip(names_list, all_predictions)), columns = ['name', '2024_Fantasy_Prediction'])
fantasy_2024_predictions = fantasy_2024_predictions.merge(prediction_data, how='left', on='name')
fantasy_2024_predictions = fantasy_2024_predictions[['name', 'team', 'position', '2024_Fantasy_Prediction']]
fantasy_2024_predictions
# Out:
#               name team position 2024_Fantasy_Prediction
# 0       A.J. Brown  PHI       WR      [226.102929247163]
# 1       A.T. Perry   NO       WR     [65.98481715944158]
# 2      AJ McCarron  CIN       QB   [0.03570406190679343]
# 3      Aaron Jones   GB       RB    [202.48393255108954]
# 4    Aaron Rodgers  NYJ       QB    [221.97106861857446]
# ..             ...  ...      ...                     ...
# 519    Zach Wilson  NYJ       QB    [144.77501905484294]
# 520      Zack Moss  IND       RB    [104.60179728069548]
# 521    Zamir White   LV       RB     [44.91425685462852]
# 522    Zay Flowers  BAL       WR     [193.4077139795765]
# 523      Zay Jones  JAX       WR    [108.14719057190801]
#
# [524 rows x 4 columns]

# %%
mse = mean_squared_error(y_test, all_predictions)
mse
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 mse = mean_squared_error(y_test, all_predictions)
#       2 mse
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\validation.py:409, in check_consistent_length(*arrays)
#     407 uniques = np.unique(lengths)
#     408 if len(uniques) > 1:
# --> 409     raise ValueError(
#     410         "Found input variables with inconsistent numbers of samples: %r"
#     411         % [int(l) for l in lengths]
#     412     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [527, 524]

# %%
r2_score(y_train, real_predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 r2_score(y_train, real_predictions)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_regression.py:989, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#     848 @validate_params(
#     849     {
#     850         "y_true": ["array-like"],
#    (...)
#     868     force_finite=True,
#     869 ):
#     870     """:math:`R^2` (coefficient of determination) regression score function.
#     871
#     872     Best possible score is 1.0 and it can be negative (because the
#    (...)
#     987     -inf
#     988     """
# --> 989     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     990         y_true, y_pred, multioutput
#     991     )
#     992     check_consistent_length(y_true, y_pred, sample_weight)
#     994     if _num_samples(y_pred) < 2:
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\validation.py:409, in check_consistent_length(*arrays)
#     407 uniques = np.unique(lengths)
#     408 if len(uniques) > 1:
# --> 409     raise ValueError(
#     410         "Found input variables with inconsistent numbers of samples: %r"
#     411         % [int(l) for l in lengths]
#     412     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1579, 524]
