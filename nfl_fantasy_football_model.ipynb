# %%
# Import required libraries
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('training_data.csv')
data.head()
# Out:
#          name team position  games  receptions  targets  receiving_yards  \
# 0  A.J. Brown  TEN       WR     16          52       84           1051.0
# 1  A.J. Brown  TEN       WR     14          70      106           1075.0
# 2  A.J. Brown  TEN       WR     13          63      105            869.0
# 3  A.J. Brown  PHI       WR     17          88      145           1496.0
# 4  A.J. Brown  PHI       WR     17         106      158           1456.0
#
#    rec_ypg  receiving_tds    ypr  ...  sacks  sack_fumbles  offense_snaps  \
# 0    65.69              8  20.21  ...    0.0             0          678.0
# 1    76.79             11  15.36  ...    0.0             0          760.0
# 2    66.85              5  13.79  ...    0.0             0          604.0
# 3    88.00             11  17.00  ...    0.0             0         1004.0
# 4    85.65              7  13.74  ...    0.0             0         1019.0
#
#    teams_offense_snaps  round  overall             stadium_name  \
# 0                997.0    2.0     51.0           Nissan Stadium
# 1                945.0    2.0     51.0           Nissan Stadium
# 2                876.0    2.0     51.0           Nissan Stadium
# 3               1189.0    2.0     51.0  Lincoln Financial Field
# 4               1154.0    2.0     51.0  Lincoln Financial Field
#
#    stadium_weather_type  stadium_surface  fantasy_points_ppr
# 0              moderate            Grass               217.1
# 1              moderate            Grass               247.5
# 2              moderate            Grass               180.9
# 3                  cold            Grass               299.6
# 4                  cold            Grass               289.6
#
# [5 rows x 40 columns]

# %%
data = data.drop(columns = ['name', 'team', 'stadium_name'])
data
# Out:
#      position  games  receptions  targets  receiving_yards  rec_ypg  \
# 0          WR     16          52       84           1051.0    65.69
# 1          WR     14          70      106           1075.0    76.79
# 2          WR     13          63      105            869.0    66.85
# 3          WR     17          88      145           1496.0    88.00
# 4          WR     17         106      158           1456.0    85.65
# ...       ...    ...         ...      ...              ...      ...
# 2101       WR     16          56      102            652.0    40.75
# 2102       WR     11          14       20            154.0    14.00
# 2103       WR     15          47       70            546.0    36.40
# 2104       WR     16          82      121            823.0    51.44
# 2105       WR      9          34       64            321.0    35.67
#
#       receiving_tds    ypr  receiving_fumbles  receiving_2pt_conversions  ...  \
# 0                 8  20.21                1.0                          0  ...
# 1                11  15.36                2.0                          0  ...
# 2                 5  13.79                0.0                          0  ...
# 3                11  17.00                2.0                          0  ...
# 4                 7  13.74                2.0                          0  ...
# ...             ...    ...                ...                        ...  ...
# 2101              7  11.64                1.0                          1  ...
# 2102              1  11.00                0.0                          0  ...
# 2103              1  11.62                1.0                          0  ...
# 2104              5  10.04                0.0                          1  ...
# 2105              2   9.44                0.0                          0  ...
#
#       interceptions  sacks  sack_fumbles  offense_snaps  teams_offense_snaps  \
# 0               0.0    0.0             0          678.0                997.0
# 1               0.0    0.0             0          760.0                945.0
# 2               0.0    0.0             0          604.0                876.0
# 3               0.0    0.0             0         1004.0               1189.0
# 4               0.0    0.0             0         1019.0               1154.0
# ...             ...    ...           ...            ...                  ...
# 2101            0.0    0.0             0          941.0               1063.0
# 2102            0.0    0.0             0          248.0                771.0
# 2103            0.0    0.0             0          614.0               1026.0
# 2104            0.0    0.0             0          930.0               1082.0
# 2105            0.0    0.0             0          475.0                655.0
#
#       round  overall  stadium_weather_type  stadium_surface  \
# 0       2.0     51.0              moderate            Grass
# 1       2.0     51.0              moderate            Grass
# 2       2.0     51.0              moderate            Grass
# 3       2.0     51.0                  cold            Grass
# 4       2.0     51.0                  cold            Grass
# ...     ...      ...                   ...              ...
# 2101    2.0     37.0                  cold        FieldTurf
# 2102    2.0     37.0                indoor            Grass
# 2103    2.0     37.0                indoor            Grass
# 2104    2.0     37.0                  warm            Grass
# 2105    2.0     37.0                  warm            Grass
#
#       fantasy_points_ppr
# 0                 217.10
# 1                 247.50
# 2                 180.90
# 3                 299.60
# 4                 289.60
# ...                  ...
# 2101              165.20
# 2102               36.56
# 2103              105.90
# 2104              198.10
# 2105               78.10
#
# [2106 rows x 37 columns]

# %%
# Encoding categorical columns for model
encoded_data = pd.get_dummies(data)
encoded_data
# Out:
#       games  receptions  targets  receiving_yards  rec_ypg  receiving_tds  \
# 0        16          52       84           1051.0    65.69              8
# 1        14          70      106           1075.0    76.79             11
# 2        13          63      105            869.0    66.85              5
# 3        17          88      145           1496.0    88.00             11
# 4        17         106      158           1456.0    85.65              7
# ...     ...         ...      ...              ...      ...            ...
# 2101     16          56      102            652.0    40.75              7
# 2102     11          14       20            154.0    14.00              1
# 2103     15          47       70            546.0    36.40              1
# 2104     16          82      121            823.0    51.44              5
# 2105      9          34       64            321.0    35.67              2
#
#         ypr  receiving_fumbles  receiving_2pt_conversions  target_share  ...  \
# 0     20.21                1.0                          0          0.20  ...
# 1     15.36                2.0                          0          0.27  ...
# 2     13.79                0.0                          0          0.28  ...
# 3     17.00                2.0                          0          0.29  ...
# 4     13.74                2.0                          0          0.30  ...
# ...     ...                ...                        ...           ...  ...
# 2101  11.64                1.0                          1          0.21  ...
# 2102  11.00                0.0                          0          0.05  ...
# 2103  11.62                1.0                          0          0.14  ...
# 2104  10.04                0.0                          1          0.22  ...
# 2105   9.44                0.0                          0          0.18  ...
#
#       position_QB  position_RB  position_TE  position_WR  \
# 0           False        False        False         True
# 1           False        False        False         True
# 2           False        False        False         True
# 3           False        False        False         True
# 4           False        False        False         True
# ...           ...          ...          ...          ...
# 2101        False        False        False         True
# 2102        False        False        False         True
# 2103        False        False        False         True
# 2104        False        False        False         True
# 2105        False        False        False         True
#
#       stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                          True                        False
# 4                          True                        False
# ...                         ...                          ...
# 2101                       True                        False
# 2102                      False                         True
# 2103                      False                         True
# 2104                      False                        False
# 2105                      False                        False
#
#       stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                              True                      False
# 1                              True                      False
# 2                              True                      False
# 3                             False                      False
# 4                             False                      False
# ...                             ...                        ...
# 2101                          False                      False
# 2102                          False                      False
# 2103                          False                      False
# 2104                          False                       True
# 2105                          False                       True
#
#       stadium_surface_FieldTurf  stadium_surface_Grass
# 0                         False                   True
# 1                         False                   True
# 2                         False                   True
# 3                         False                   True
# 4                         False                   True
# ...                         ...                    ...
# 2101                       True                  False
# 2102                      False                   True
# 2103                      False                   True
# 2104                      False                   True
# 2105                      False                   True
#
# [2106 rows x 44 columns]

# %%
# Defining y (target variable)
y = encoded_data['fantasy_points_ppr']

# Defining X (features)
X = encoded_data.drop(columns = 'fantasy_points_ppr')

X.shape
# Out:
# (2106, 43)

# %%
# Spliting model into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=42)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
intercept = lr_model.intercept_
intercept
# Out:
# 0.12448781746863347

# %%
m = lr_model.coef_
m
# Out:
# array([ 1.75444234e-02,  1.01753689e+00, -1.45173159e-02,  1.00590722e-01,
#        -1.90191074e-03,  6.01454392e+00, -3.11527065e-03, -1.07569148e+00,
#         1.93219596e+00, -3.91985303e-01, -1.81358177e+00, -2.12849054e-02,
#         1.03933946e-01,  1.12333336e-03,  6.00318824e+00, -1.81163127e-01,
#        -6.76741278e-01,  2.01258324e+00, -3.32490437e-02,  1.06296629e-02,
#         7.81682088e-02,  4.13728124e-02, -5.15534819e-04,  4.01641722e+00,
#         1.81421035e+00,  6.85271962e-02, -1.96771403e+00,  2.77440984e-02,
#        -1.06092070e+00, -6.61760110e-04,  3.67720436e-04,  2.34551708e-02,
#        -1.60844500e-03, -1.86875971e-01, -1.89873657e-01, -1.10310057e-01,
#         4.87059685e-01,  1.21896194e-02,  6.81013170e-02,  9.39123105e-02,
#        -1.74203247e-01, -3.29541480e-02,  3.29541480e-02])

# %%
predictions = lr_model.predict(X_train)

# %%
len(predictions)
# Out:
# 1579

# %%
r2_score(y_train, predictions)
# Out:
# 0.9997549643470564

# %%
mse = mean_squared_error(y_train, predictions)
mse
# Out:
# 2.3476187172427223

# %%
prediction_data = pd.read_csv('predicting_data.csv')
prediction_data.head()
# Out:
#             name team position      games  receptions     targets  \
# 0     A.J. Brown  PHI       WR  15.400000   75.800000  119.600000
# 1     A.T. Perry   NO       WR   8.000000   12.000000   18.000000
# 2    AJ McCarron  CIN       QB   2.000000    0.000000    0.000000
# 3    Aaron Jones   GB       RB  13.571429   38.857143   52.000000
# 4  Aaron Rodgers  NYJ       QB  13.272727    0.181818    0.181818
#
#    receiving_yards    rec_ypg  receiving_tds        ypr  ...  interceptions  \
# 0      1189.400000  76.596000       8.400000  16.020000  ...       0.000000
# 1       246.000000  30.750000       4.000000  20.500000  ...       0.000000
# 2         0.000000   0.000000       0.000000   0.000000  ...       0.250000
# 3       296.571429  20.691429       2.571429   7.080000  ...       0.000000
# 4        -0.909091  -0.057273       0.000000  -0.909091  ...       5.363636
#
#        sacks  sack_fumbles  offense_snaps  teams_offense_snaps  round  \
# 0   0.000000      0.000000     813.000000          1032.200000    2.0
# 1   0.000000      0.000000     319.000000           519.000000    6.0
# 2   2.000000      0.000000       0.000000             0.000000    0.0
# 3   0.000000      0.000000     482.285714           890.285714    5.0
# 4  29.090909      3.363636     847.636364           891.181818    1.0
#
#    overall             stadium_name  stadium_weather_type  stadium_surface
# 0     51.0  Lincoln Financial Field                  cold            Grass
# 1    195.0  Mercedes-Benz Superdome                indoor        FieldTurf
# 2      0.0       Paul Brown Stadium                  cold        FieldTurf
# 3    182.0            Lambeau Field                  cold            Grass
# 4     24.0          MetLife Stadium                  cold        FieldTurf
#
# [5 rows x 39 columns]

# %%
prediction_data_cleaned = prediction_data.drop(columns = ['name', 'team', 'stadium_name'])
prediction_data_cleaned.head()
# Out:
#   position      games  receptions     targets  receiving_yards    rec_ypg  \
# 0       WR  15.400000   75.800000  119.600000      1189.400000  76.596000
# 1       WR   8.000000   12.000000   18.000000       246.000000  30.750000
# 2       QB   2.000000    0.000000    0.000000         0.000000   0.000000
# 3       RB  13.571429   38.857143   52.000000       296.571429  20.691429
# 4       QB  13.272727    0.181818    0.181818        -0.909091  -0.057273
#
#    receiving_tds        ypr  receiving_fumbles  receiving_2pt_conversions  \
# 0       8.400000  16.020000           1.400000                   0.000000
# 1       4.000000  20.500000           0.000000                   0.000000
# 2       0.000000   0.000000           0.000000                   0.000000
# 3       2.571429   7.080000           0.857143                   0.142857
# 4       0.000000  -0.909091           0.000000                   0.000000
#
#    ...  td_percentage  interceptions      sacks  sack_fumbles  offense_snaps  \
# 0  ...       0.116000       0.000000   0.000000      0.000000     813.000000
# 1  ...       0.330000       0.000000   0.000000      0.000000     319.000000
# 2  ...       0.005000       0.250000   2.000000      0.000000       0.000000
# 3  ...       0.042857       0.000000   0.000000      0.000000     482.285714
# 4  ...       0.052727       5.363636  29.090909      3.363636     847.636364
#
#    teams_offense_snaps  round  overall  stadium_weather_type  stadium_surface
# 0          1032.200000    2.0     51.0                  cold            Grass
# 1           519.000000    6.0    195.0                indoor        FieldTurf
# 2             0.000000    0.0      0.0                  cold        FieldTurf
# 3           890.285714    5.0    182.0                  cold            Grass
# 4           891.181818    1.0     24.0                  cold        FieldTurf
#
# [5 rows x 36 columns]

# %%
# Encoding categorical columns for model
encoded_prediction_data = pd.get_dummies(prediction_data_cleaned)
encoded_prediction_data
# Out:
#          games  receptions     targets  receiving_yards    rec_ypg  \
# 0    15.400000   75.800000  119.600000      1189.400000  76.596000
# 1     8.000000   12.000000   18.000000       246.000000  30.750000
# 2     2.000000    0.000000    0.000000         0.000000   0.000000
# 3    13.571429   38.857143   52.000000       296.571429  20.691429
# 4    13.272727    0.181818    0.181818        -0.909091  -0.057273
# ..         ...         ...         ...              ...        ...
# 519  11.333333    0.333333    0.666667         0.666667   0.073333
# 520  12.000000   17.000000   23.000000       124.000000   9.417500
# 521  12.000000    7.500000    9.500000        49.000000   3.770000
# 522  16.000000   77.000000  108.000000       858.000000  53.620000
# 523  13.500000   43.333333   75.166667       468.666667  33.471667
#
#      receiving_tds        ypr  receiving_fumbles  receiving_2pt_conversions  \
# 0         8.400000  16.020000           1.400000                   0.000000
# 1         4.000000  20.500000           0.000000                   0.000000
# 2         0.000000   0.000000           0.000000                   0.000000
# 3         2.571429   7.080000           0.857143                   0.142857
# 4         0.000000  -0.909091           0.000000                   0.000000
# ..             ...        ...                ...                        ...
# 519       0.333333   0.666667           0.000000                   0.000000
# 520       1.000000   6.367500           0.500000                   0.250000
# 521       0.000000   3.265000           0.000000                   0.000000
# 522       5.000000  11.140000           0.000000                   1.000000
# 523       3.000000  10.906667           0.333333                   0.333333
#
#      target_share  ...  position_QB  position_RB  position_TE  position_WR  \
# 0        0.268000  ...        False        False        False         True
# 1        0.070000  ...        False        False        False         True
# 2        0.000000  ...         True        False        False        False
# 3        0.115714  ...        False         True        False        False
# 4        0.000000  ...         True        False        False        False
# ..            ...  ...          ...          ...          ...          ...
# 519      0.000000  ...         True        False        False        False
# 520      0.050000  ...        False         True        False        False
# 521      0.020000  ...        False         True        False        False
# 522      0.240000  ...        False        False        False         True
# 523      0.163333  ...        False        False        False         True
#
#      stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         True                        False
# 1                        False                         True
# 2                         True                        False
# 3                         True                        False
# 4                         True                        False
# ..                         ...                          ...
# 519                       True                        False
# 520                      False                         True
# 521                      False                         True
# 522                      False                        False
# 523                      False                        False
#
#      stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# ..                             ...                        ...
# 519                          False                      False
# 520                          False                      False
# 521                          False                      False
# 522                           True                      False
# 523                          False                       True
#
#      stadium_surface_FieldTurf  stadium_surface_Grass
# 0                        False                   True
# 1                         True                  False
# 2                         True                  False
# 3                        False                   True
# 4                         True                  False
# ..                         ...                    ...
# 519                       True                  False
# 520                       True                  False
# 521                      False                   True
# 522                       True                  False
# 523                      False                   True
#
# [524 rows x 43 columns]

# %%
list_of_lists = encoded_prediction_data.values.tolist()  # Get a list of rows
test = list_of_lists[5]

real_predictions = lr_model.predict([test])
real_predictions
# Out:
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([178.86200935])

# %%
names_list = prediction_data['name'].tolist()

# %%
# Assuming encoded_prediction_data has data
list_of_lists = encoded_prediction_data.values.tolist()  # Get a list of rows

# Initialize an empty list to store all predictions
all_predictions = []

# Loop through each index from 0 to 524 (inclusive)
for index in range(524):
  # Get the data for the current index
  data_for_prediction = list_of_lists[index]

  # Make prediction using your model
  prediction = lr_model.predict([data_for_prediction])

  # Append the prediction to the all_predictions list
  all_predictions.append(prediction)  # Assuming single prediction per row

# Print or use the all_predictions list for further analysis
all_predictions
# Out:
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\nmrod\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [array([246.42377132]),
#  array([60.92915922]),
#  array([5.32504847]),
#  array([205.77054613]),
#  array([262.34677345]),
#  array([178.86200935]),
#  array([51.87635856]),
#  array([126.22002815]),
#  array([32.83477321]),
#  array([103.3697852]),
#  array([9.31976538]),
#  array([38.63831654]),
#  array([101.33760648]),
#  array([96.95718121]),
#  array([152.75420344]),
#  array([282.24939002]),
#  array([219.91975345]),
#  array([14.64439114]),
#  array([57.8164022]),
#  array([276.07841287]),
#  array([51.15244481]),
#  array([35.72714005]),
#  array([185.31342958]),
#  array([8.40374194]),
#  array([72.23489777]),
#  array([1.67001887]),
#  array([182.337128]),
#  array([237.29440913]),
#  array([111.3743774]),
#  array([5.40898251]),
#  array([55.88402596]),
#  array([203.53244527]),
#  array([12.29518313]),
#  array([43.70415143]),
#  array([249.12400268]),
#  array([34.15547941]),
#  array([16.23192941]),
#  array([45.83952063]),
#  array([71.28571567]),
#  array([200.21496707]),
#  array([209.02835443]),
#  array([42.63174523]),
#  array([45.13742217]),
#  array([35.07078143]),
#  array([69.73114896]),
#  array([202.42299251]),
#  array([14.29377971]),
#  array([44.50713046]),
#  array([15.48538746]),
#  array([154.49342816]),
#  array([8.68346895]),
#  array([200.90814172]),
#  array([42.6645741]),
#  array([158.80021689]),
#  array([10.54272756]),
#  array([53.63366114]),
#  array([40.5240503]),
#  array([276.9977703]),
#  array([52.89846849]),
#  array([104.91381875]),
#  array([53.22275425]),
#  array([197.11326106]),
#  array([71.97224035]),
#  array([194.25106167]),
#  array([87.7544133]),
#  array([44.42881045]),
#  array([288.3077568]),
#  array([15.1253677]),
#  array([15.04625039]),
#  array([5.66350026]),
#  array([52.84494263]),
#  array([103.58765055]),
#  array([86.46017825]),
#  array([105.31177112]),
#  array([66.93934385]),
#  array([21.42286194]),
#  array([203.08146088]),
#  array([8.20121229]),
#  array([52.48108285]),
#  array([215.67285465]),
#  array([39.46926176]),
#  array([173.70842931]),
#  array([275.98897426]),
#  array([132.96181938]),
#  array([135.70116966]),
#  array([8.02753866]),
#  array([115.93665216]),
#  array([2.55870064]),
#  array([35.7298574]),
#  array([1.67915457]),
#  array([127.5076635]),
#  array([13.61854232]),
#  array([28.01784323]),
#  array([1.9386642]),
#  array([37.75159641]),
#  array([228.23236759]),
#  array([21.14413493]),
#  array([139.88993775]),
#  array([144.82922876]),
#  array([25.14070056]),
#  array([129.05122151]),
#  array([197.12545441]),
#  array([35.68210772]),
#  array([66.37909119]),
#  array([14.88319202]),
#  array([109.83052065]),
#  array([10.82491029]),
#  array([221.2824655]),
#  array([242.64914074]),
#  array([271.81554577]),
#  array([132.57552912]),
#  array([151.40042065]),
#  array([112.67503821]),
#  array([121.26210233]),
#  array([82.71753551]),
#  array([63.37350119]),
#  array([63.09303345]),
#  array([183.34617836]),
#  array([42.47935144]),
#  array([132.00647775]),
#  array([137.64060822]),
#  array([13.19548581]),
#  array([89.34077514]),
#  array([128.18197122]),
#  array([7.78038465]),
#  array([252.41910137]),
#  array([47.73907296]),
#  array([203.51210113]),
#  array([75.15380614]),
#  array([108.45690296]),
#  array([-0.15944593]),
#  array([25.22163897]),
#  array([117.60659541]),
#  array([100.27354584]),
#  array([54.95935281]),
#  array([240.37868494]),
#  array([125.39603755]),
#  array([223.74501154]),
#  array([43.65610863]),
#  array([204.99587334]),
#  array([84.08019496]),
#  array([108.4031082]),
#  array([31.59588055]),
#  array([20.35991569]),
#  array([247.3817049]),
#  array([32.7118953]),
#  array([29.58976615]),
#  array([226.98280454]),
#  array([227.27258317]),
#  array([110.65723396]),
#  array([14.66557068]),
#  array([23.72448746]),
#  array([61.2099371]),
#  array([166.49110161]),
#  array([6.27428437]),
#  array([197.62988039]),
#  array([52.84276072]),
#  array([85.67528632]),
#  array([119.24134461]),
#  array([20.53305695]),
#  array([177.99636076]),
#  array([82.69397349]),
#  array([31.89400454]),
#  array([43.9972921]),
#  array([32.50855053]),
#  array([34.86424772]),
#  array([7.18316572]),
#  array([3.62504331]),
#  array([36.5684475]),
#  array([85.25202884]),
#  array([119.96735117]),
#  array([14.99991622]),
#  array([73.45323298]),
#  array([35.55577187]),
#  array([12.09970854]),
#  array([12.87275421]),
#  array([2.14599929]),
#  array([151.43407345]),
#  array([1.63919308]),
#  array([250.42971949]),
#  array([62.56279073]),
#  array([167.62742495]),
#  array([132.48995438]),
#  array([215.11801484]),
#  array([13.99564646]),
#  array([97.80187351]),
#  array([25.77783028]),
#  array([187.617207]),
#  array([186.16642699]),
#  array([98.42814862]),
#  array([9.80503784]),
#  array([10.35719974]),
#  array([62.87600506]),
#  array([45.48369923]),
#  array([9.67762248]),
#  array([112.47484991]),
#  array([56.8455719]),
#  array([78.84271787]),
#  array([134.87765663]),
#  array([12.79822656]),
#  array([130.67679975]),
#  array([40.82028235]),
#  array([28.17388641]),
#  array([66.23373184]),
#  array([0.52882946]),
#  array([77.20453717]),
#  array([96.26862803]),
#  array([59.69687364]),
#  array([13.33281015]),
#  array([175.8837998]),
#  array([18.04511656]),
#  array([86.89715185]),
#  array([270.2225627]),
#  array([12.83136566]),
#  array([92.8238945]),
#  array([128.00013743]),
#  array([242.90918178]),
#  array([57.75169754]),
#  array([141.60739738]),
#  array([112.8548704]),
#  array([159.60094314]),
#  array([106.73951867]),
#  array([12.84797585]),
#  array([45.54925379]),
#  array([287.56152372]),
#  array([19.71508608]),
#  array([52.57832701]),
#  array([32.50330239]),
#  array([59.41659074]),
#  array([133.35972292]),
#  array([52.31070909]),
#  array([157.43717475]),
#  array([180.11180691]),
#  array([170.40458561]),
#  array([16.51838908]),
#  array([13.06936192]),
#  array([47.65708062]),
#  array([123.03638602]),
#  array([235.22727801]),
#  array([4.02968202]),
#  array([19.89386317]),
#  array([4.17852878]),
#  array([16.96466967]),
#  array([71.95971627]),
#  array([142.48153831]),
#  array([150.46550421]),
#  array([218.03635058]),
#  array([235.40912565]),
#  array([145.37483262]),
#  array([40.40216137]),
#  array([16.39986426]),
#  array([118.65147577]),
#  array([106.66026589]),
#  array([146.24629241]),
#  array([11.38678471]),
#  array([95.05383275]),
#  array([147.42090389]),
#  array([246.27905531]),
#  array([108.81126182]),
#  array([214.40292]),
#  array([38.10946112]),
#  array([2.20342483]),
#  array([16.55519852]),
#  array([83.62465549]),
#  array([233.48618234]),
#  array([6.15701198]),
#  array([20.40495001]),
#  array([85.18855237]),
#  array([221.63885123]),
#  array([67.18651299]),
#  array([116.70847291]),
#  array([38.64085529]),
#  array([-0.13817304]),
#  array([347.94666588]),
#  array([157.65247854]),
#  array([241.79402678]),
#  array([28.66124449]),
#  array([123.17832857]),
#  array([87.37113788]),
#  array([24.48029854]),
#  array([25.3536774]),
#  array([56.99446638]),
#  array([25.7283288]),
#  array([160.12634391]),
#  array([9.62768155]),
#  array([202.10204519]),
#  array([53.86673207]),
#  array([216.02074539]),
#  array([305.07252849]),
#  array([294.20817945]),
#  array([42.33996974]),
#  array([11.80077014]),
#  array([95.21120094]),
#  array([5.27901133]),
#  array([144.3255814]),
#  array([63.86384976]),
#  array([57.92486123]),
#  array([170.90638219]),
#  array([3.95572747]),
#  array([70.70125938]),
#  array([9.32108847]),
#  array([249.34035199]),
#  array([14.73341384]),
#  array([43.23225936]),
#  array([107.95490217]),
#  array([5.95456007]),
#  array([103.37647365]),
#  array([200.11099731]),
#  array([128.60034705]),
#  array([5.00598298]),
#  array([118.94211561]),
#  array([16.00797221]),
#  array([1.54261581]),
#  array([25.35254196]),
#  array([103.25322017]),
#  array([74.27209266]),
#  array([233.35917673]),
#  array([14.06262731]),
#  array([1.79465435]),
#  array([45.7262536]),
#  array([24.93217804]),
#  array([129.36211085]),
#  array([0.21729656]),
#  array([51.75174113]),
#  array([259.16584018]),
#  array([143.07078822]),
#  array([22.94865823]),
#  array([286.95656851]),
#  array([33.54046719]),
#  array([129.22994655]),
#  array([95.66709877]),
#  array([22.15379316]),
#  array([174.47574795]),
#  array([23.4951255]),
#  array([73.80334093]),
#  array([-0.05488631]),
#  array([23.52925571]),
#  array([15.8881277]),
#  array([75.19284684]),
#  array([26.7151985]),
#  array([38.31930705]),
#  array([166.4594384]),
#  array([57.24322383]),
#  array([34.3151616]),
#  array([8.88559765]),
#  array([12.98975866]),
#  array([42.64940116]),
#  array([133.29595797]),
#  array([184.13486415]),
#  array([100.11673454]),
#  array([168.88607463]),
#  array([61.96078558]),
#  array([160.261124]),
#  array([69.37833297]),
#  array([2.1881887]),
#  array([45.03722321]),
#  array([15.37881174]),
#  array([80.49182734]),
#  array([246.14531104]),
#  array([101.80136608]),
#  array([194.25652113]),
#  array([105.05971168]),
#  array([128.16472487]),
#  array([71.39564814]),
#  array([201.44157]),
#  array([204.853499]),
#  array([114.70237837]),
#  array([249.84887895]),
#  array([110.8835116]),
#  array([6.79699716]),
#  array([34.40381079]),
#  array([119.24446404]),
#  array([26.51646928]),
#  array([163.63971392]),
#  array([126.10303387]),
#  array([18.7098957]),
#  array([52.39695139]),
#  array([27.14631991]),
#  array([239.34535952]),
#  array([6.38050074]),
#  array([3.3724912]),
#  array([117.14414257]),
#  array([197.5549824]),
#  array([54.65695349]),
#  array([3.13357342]),
#  array([25.14338409]),
#  array([92.59925633]),
#  array([147.05454928]),
#  array([50.19793666]),
#  array([123.28614803]),
#  array([52.48070693]),
#  array([63.16041133]),
#  array([40.42651661]),
#  array([53.03746138]),
#  array([125.80597033]),
#  array([306.74584762]),
#  array([17.69146586]),
#  array([10.58815265]),
#  array([23.73493339]),
#  array([26.86862256]),
#  array([54.03209404]),
#  array([35.8139406]),
#  array([297.45434569]),
#  array([94.13638597]),
#  array([65.37444591]),
#  array([15.9412746]),
#  array([205.33579331]),
#  array([31.29200713]),
#  array([93.74651555]),
#  array([10.40420275]),
#  array([131.94399992]),
#  array([54.97594796]),
#  array([213.27087492]),
#  array([126.16331417]),
#  array([78.45339791]),
#  array([40.34055976]),
#  array([169.48079612]),
#  array([57.31936564]),
#  array([47.00134088]),
#  array([18.78697118]),
#  array([22.93863681]),
#  array([67.6845718]),
#  array([161.64809556]),
#  array([-0.00803958]),
#  array([137.67728566]),
#  array([101.29370253]),
#  array([31.3489604]),
#  array([14.9380025]),
#  array([101.45352532]),
#  array([21.04100508]),
#  array([61.36655378]),
#  array([295.66411291]),
#  array([220.08640498]),
#  array([40.8554316]),
#  array([126.36431489]),
#  array([138.83578915]),
#  array([239.13131785]),
#  array([76.04377998]),
#  array([18.38684962]),
#  array([216.29640644]),
#  array([49.35870006]),
#  array([0.68646983]),
#  array([5.33801484]),
#  array([4.85639125]),
#  array([0.3842783]),
#  array([6.8147033]),
#  array([52.28720367]),
#  array([246.87760141]),
#  array([10.19992851]),
#  array([118.7854778]),
#  array([50.9943945]),
#  array([19.07042733]),
#  array([150.4747238]),
#  array([25.72039307]),
#  array([165.25155803]),
#  array([30.66411224]),
#  array([72.18635076]),
#  array([112.7059268]),
#  array([17.68814746]),
#  array([106.69562474]),
#  array([193.63008301]),
#  array([49.34594158]),
#  array([212.33973897]),
#  array([13.14727183]),
#  array([95.07538116]),
#  array([56.06006257]),
#  array([9.22985492]),
#  array([167.20058088]),
#  array([243.88552371]),
#  array([32.15812506]),
#  array([249.01439014]),
#  array([13.03304984]),
#  array([72.45315548]),
#  array([33.91579758]),
#  array([32.38203311]),
#  array([33.34131593]),
#  array([4.92129066]),
#  array([256.38730887]),
#  array([63.83146721]),
#  array([120.4740212]),
#  array([94.61298403]),
#  array([16.78125065]),
#  array([64.34212835]),
#  array([5.39217974]),
#  array([202.41480701]),
#  array([1.88043388]),
#  array([78.59369063]),
#  array([87.76426972]),
#  array([51.50256349]),
#  array([63.46143334]),
#  array([23.4521169]),
#  array([152.76709971]),
#  array([5.05894707]),
#  array([147.99798357]),
#  array([164.66763541]),
#  array([76.3541277]),
#  array([18.31857243]),
#  array([105.35916682]),
#  array([40.35429349]),
#  array([40.92051341]),
#  array([200.64945336]),
#  array([37.2367414]),
#  array([47.05725062]),
#  array([287.69369983]),
#  array([5.90282652]),
#  array([110.52799714]),
#  array([55.00737881]),
#  array([79.33530861]),
#  array([25.89037938]),
#  array([92.91277721]),
#  array([57.7134723]),
#  array([104.16843854]),
#  array([37.71149777]),
#  array([90.35822984]),
#  array([56.62696777]),
#  array([22.53743395]),
#  array([106.00677131]),
#  array([1.54559957]),
#  array([79.96714037]),
#  array([125.43427622]),
#  array([105.64752627]),
#  array([41.20543217]),
#  array([206.80830284]),
#  array([109.05686674])]

# %%
fantasy_2024_predictions = pd.DataFrame(list(zip(names_list, all_predictions)), columns = ['name', '2024_Fantasy_Prediction'])
fantasy_2024_predictions = fantasy_2024_predictions.merge(prediction_data, how='left', on='name')
fantasy_2024_predictions = fantasy_2024_predictions[['name', 'team', 'position', '2024_Fantasy_Prediction']]
fantasy_2024_predictions
# Out:
#               name team position 2024_Fantasy_Prediction
# 0       A.J. Brown  PHI       WR    [246.42377132126487]
# 1       A.T. Perry   NO       WR     [60.92915921981991]
# 2      AJ McCarron  CIN       QB     [5.325048472053764]
# 3      Aaron Jones   GB       RB    [205.77054612523557]
# 4    Aaron Rodgers  NYJ       QB     [262.3467734454945]
# ..             ...  ...      ...                     ...
# 519    Zach Wilson  NYJ       QB    [125.43427621849672]
# 520      Zack Moss  IND       RB    [105.64752626535525]
# 521    Zamir White   LV       RB    [41.205432172046585]
# 522    Zay Flowers  BAL       WR    [206.80830284305034]
# 523      Zay Jones  JAX       WR     [109.0568667383408]
#
# [524 rows x 4 columns]

# %%
mse = mean_squared_error(y_train, real_predictions)
mse
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 mse = mean_squared_error(y_train, real_predictions)
#       2 mse
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\validation.py:409, in check_consistent_length(*arrays)
#     407 uniques = np.unique(lengths)
#     408 if len(uniques) > 1:
# --> 409     raise ValueError(
#     410         "Found input variables with inconsistent numbers of samples: %r"
#     411         % [int(l) for l in lengths]
#     412     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1579, 524]

# %%
r2_score(y_train, real_predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 r2_score(y_train, real_predictions)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_regression.py:989, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#     848 @validate_params(
#     849     {
#     850         "y_true": ["array-like"],
#    (...)
#     868     force_finite=True,
#     869 ):
#     870     """:math:`R^2` (coefficient of determination) regression score function.
#     871
#     872     Best possible score is 1.0 and it can be negative (because the
#    (...)
#     987     -inf
#     988     """
# --> 989     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     990         y_true, y_pred, multioutput
#     991     )
#     992     check_consistent_length(y_true, y_pred, sample_weight)
#     994     if _num_samples(y_pred) < 2:
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\validation.py:409, in check_consistent_length(*arrays)
#     407 uniques = np.unique(lengths)
#     408 if len(uniques) > 1:
# --> 409     raise ValueError(
#     410         "Found input variables with inconsistent numbers of samples: %r"
#     411         % [int(l) for l in lengths]
#     412     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1579, 524]
