# %%
# Import required libraries
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a59b9c01-26c0-4ac1-a859-7c67f3aa5a4d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"423fc3e2-f78f-477e-a22a-cf93e8a99b35":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"9e2211decee9475fa5e7013f065645a3","client_comm_id":"257ed1565a7e47dab7da252cbd2dd807"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"423fc3e2-f78f-477e-a22a-cf93e8a99b35","roots":{"p1002":"a59b9c01-26c0-4ac1-a859-7c67f3aa5a4d"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
data = pd.read_csv('training_data.csv')
data.head()
# Out:
#          name team position  games  receptions  targets  receiving_yards  \
# 0  A.J. Brown  TEN       WR     16          52       84           1051.0
# 1  A.J. Brown  TEN       WR     14          70      106           1075.0
# 2  A.J. Brown  TEN       WR     13          63      105            869.0
# 3  A.J. Brown  PHI       WR     17          88      145           1496.0
# 4  A.J. Brown  PHI       WR     17         106      158           1456.0
#
#    rec_ypg  receiving_tds    ypr  ...  sacks  sack_fumbles  offense_snaps  \
# 0    65.69              8  20.21  ...    0.0             0          678.0
# 1    76.79             11  15.36  ...    0.0             0          760.0
# 2    66.85              5  13.79  ...    0.0             0          604.0
# 3    88.00             11  17.00  ...    0.0             0         1004.0
# 4    85.65              7  13.74  ...    0.0             0         1019.0
#
#    teams_offense_snaps  round  overall             stadium_name  \
# 0                997.0    2.0     51.0           Nissan Stadium
# 1                945.0    2.0     51.0           Nissan Stadium
# 2                876.0    2.0     51.0           Nissan Stadium
# 3               1189.0    2.0     51.0  Lincoln Financial Field
# 4               1154.0    2.0     51.0  Lincoln Financial Field
#
#    stadium_weather_type  stadium_surface  fantasy_points_ppr
# 0              moderate            Grass               217.1
# 1              moderate            Grass               247.5
# 2              moderate            Grass               180.9
# 3                  cold            Grass               299.6
# 4                  cold            Grass               289.6
#
# [5 rows x 40 columns]

# %%
data = data.drop(columns = ['name', 'team', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions'])
data
# Out:
#      position  games  targets  rec_ypg    ypr  receiving_fumbles  \
# 0          WR     16       84    65.69  20.21                1.0
# 1          WR     14      106    76.79  15.36                2.0
# 2          WR     13      105    66.85  13.79                0.0
# 3          WR     17      145    88.00  17.00                2.0
# 4          WR     17      158    85.65  13.74                2.0
# ...       ...    ...      ...      ...    ...                ...
# 2101       WR     16      102    40.75  11.64                1.0
# 2102       WR     11       20    14.00  11.00                0.0
# 2103       WR     15       70    36.40  11.62                1.0
# 2104       WR     16      121    51.44  10.04                0.0
# 2105       WR      9       64    35.67   9.44                0.0
#
#       target_share  air_yards_share  carries  rush_ypg  ...  sacks  \
# 0             0.20             0.29        3      3.75  ...    0.0
# 1             0.27             0.35        0      0.00  ...    0.0
# 2             0.28             0.45        2      0.77  ...    0.0
# 3             0.29             0.41        0      0.00  ...    0.0
# 4             0.30             0.42        0      0.00  ...    0.0
# ...            ...              ...      ...       ...  ...    ...
# 2101          0.21             0.26        1      0.00  ...    0.0
# 2102          0.05             0.04        0      0.00  ...    0.0
# 2103          0.14             0.24        2      0.20  ...    0.0
# 2104          0.22             0.26        4      1.12  ...    0.0
# 2105          0.18             0.27        0      0.00  ...    0.0
#
#       sack_fumbles  offense_snaps  teams_offense_snaps  round  overall  \
# 0                0          678.0                997.0    2.0     51.0
# 1                0          760.0                945.0    2.0     51.0
# 2                0          604.0                876.0    2.0     51.0
# 3                0         1004.0               1189.0    2.0     51.0
# 4                0         1019.0               1154.0    2.0     51.0
# ...            ...            ...                  ...    ...      ...
# 2101             0          941.0               1063.0    2.0     37.0
# 2102             0          248.0                771.0    2.0     37.0
# 2103             0          614.0               1026.0    2.0     37.0
# 2104             0          930.0               1082.0    2.0     37.0
# 2105             0          475.0                655.0    2.0     37.0
#
#                  stadium_name  stadium_weather_type  stadium_surface  \
# 0              Nissan Stadium              moderate            Grass
# 1              Nissan Stadium              moderate            Grass
# 2              Nissan Stadium              moderate            Grass
# 3     Lincoln Financial Field                  cold            Grass
# 4     Lincoln Financial Field                  cold            Grass
# ...                       ...                   ...              ...
# 2101            New Era Field                  cold        FieldTurf
# 2102        Allegiant Stadium                indoor            Grass
# 2103        Allegiant Stadium                indoor            Grass
# 2104          TIAA Bank Field                  warm            Grass
# 2105          TIAA Bank Field                  warm            Grass
#
#       fantasy_points_ppr
# 0                 217.10
# 1                 247.50
# 2                 180.90
# 3                 299.60
# 4                 289.60
# ...                  ...
# 2101              165.20
# 2102               36.56
# 2103              105.90
# 2104              198.10
# 2105               78.10
#
# [2106 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['position', 'games', 'targets', 'rec_ypg', 'ypr', 'receiving_fumbles',
#        'target_share', 'air_yards_share', 'carries', 'rush_ypg',
#        'rush_td_percentage', 'rushing_fumbles', 'attempts', 'comp_percentage',
#        'pass_ypg', 'passing_2pt_conversions', 'td_percentage', 'sacks',
#        'sack_fumbles', 'offense_snaps', 'teams_offense_snaps', 'round',
#        'overall', 'stadium_name', 'stadium_weather_type', 'stadium_surface',
#        'fantasy_points_ppr'],
#       dtype='object')

# %%
# Encoding categorical columns for model
encoded_data = pd.get_dummies(data)
encoded_data
# Out:
#       games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 0        16       84    65.69  20.21                1.0          0.20
# 1        14      106    76.79  15.36                2.0          0.27
# 2        13      105    66.85  13.79                0.0          0.28
# 3        17      145    88.00  17.00                2.0          0.29
# 4        17      158    85.65  13.74                2.0          0.30
# ...     ...      ...      ...    ...                ...           ...
# 2101     16      102    40.75  11.64                1.0          0.21
# 2102     11       20    14.00  11.00                0.0          0.05
# 2103     15       70    36.40  11.62                1.0          0.14
# 2104     16      121    51.44  10.04                0.0          0.22
# 2105      9       64    35.67   9.44                0.0          0.18
#
#       air_yards_share  carries  rush_ypg  rush_td_percentage  ...  \
# 0                0.29        3      3.75                0.33  ...
# 1                0.35        0      0.00                0.00  ...
# 2                0.45        2      0.77                0.00  ...
# 3                0.41        0      0.00                0.00  ...
# 4                0.42        0      0.00                0.00  ...
# ...               ...      ...       ...                 ...  ...
# 2101             0.26        1      0.00                0.00  ...
# 2102             0.04        0      0.00                0.00  ...
# 2103             0.24        2      0.20                0.00  ...
# 2104             0.26        4      1.12                0.00  ...
# 2105             0.27        0      0.00                0.00  ...
#
#       stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 0                          False                            False
# 1                          False                            False
# 2                          False                            False
# 3                          False                            False
# 4                          False                            False
# ...                          ...                              ...
# 2101                       False                            False
# 2102                       False                            False
# 2103                       False                            False
# 2104                       False                            False
# 2105                       False                            False
#
#       stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ...                            ...                             ...
# 2101                         False                           False
# 2102                         False                           False
# 2103                         False                           False
# 2104                          True                           False
# 2105                          True                           False
#
#       stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                          True                        False
# 4                          True                        False
# ...                         ...                          ...
# 2101                       True                        False
# 2102                      False                         True
# 2103                      False                         True
# 2104                      False                        False
# 2105                      False                        False
#
#       stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                              True                      False
# 1                              True                      False
# 2                              True                      False
# 3                             False                      False
# 4                             False                      False
# ...                             ...                        ...
# 2101                          False                      False
# 2102                          False                      False
# 2103                          False                      False
# 2104                          False                       True
# 2105                          False                       True
#
#       stadium_surface_FieldTurf  stadium_surface_Grass
# 0                         False                   True
# 1                         False                   True
# 2                         False                   True
# 3                         False                   True
# 4                         False                   True
# ...                         ...                    ...
# 2101                       True                  False
# 2102                      False                   True
# 2103                      False                   True
# 2104                      False                   True
# 2105                      False                   True
#
# [2106 rows x 64 columns]

# %%
# Defining y (target variable)
y = encoded_data['fantasy_points_ppr']

# Defining X (features)
X = encoded_data.drop(columns = 'fantasy_points_ppr')

X.shape
# Out:
# (2106, 63)

# %%
# Spliting model into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=42)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
intercept = lr_model.intercept_
intercept
# Out:
# -9.038865919951547

# %%
m = lr_model.coef_
m
# Out:
# array([ 1.08175753e+00,  1.44975250e+00,  1.64774209e+00, -7.53834106e-01,
#        -3.39064198e-01, -2.74178224e+02, -9.59526852e+00,  5.10205193e-01,
#         5.84696326e-01,  2.01562709e+01,  1.59880565e+00,  4.55855109e-01,
#         3.43177297e+00,  4.84189756e-02,  5.38977260e+00,  6.56244520e+01,
#        -4.54421452e-01, -2.86351604e+00,  2.97876185e-03, -7.87182259e-03,
#        -6.01545745e+00,  1.81662892e-01, -8.36461804e+00, -3.65299175e+00,
#         7.43564424e+00,  4.58196555e+00,  4.57554709e-01, -1.23873546e+00,
#         4.42967909e+00, -9.93650118e+00,  8.26452153e+00, -7.16446075e-01,
#        -5.03282130e+00, -3.57196566e+00,  2.56803548e+00,  1.12149078e+00,
#        -1.62189031e+00,  2.57772145e+00, -5.42276989e+00,  5.21336165e+00,
#         8.54334462e-01,  3.91101178e+00,  2.18229187e+00, -4.20790762e+00,
#         2.81323449e+00, -4.86153936e+00,  3.64649427e+00, -7.60233372e+00,
#         3.44963017e+00,  4.16506708e+00,  4.33206999e+00, -5.20663852e-01,
#        -9.63744649e-01, -4.18804697e-01,  4.78156724e-01, -3.95221013e+00,
#        -3.96321643e-01, -3.32128681e-01, -1.55117743e+00,  2.75569364e+00,
#        -8.72387528e-01,  1.25770636e+00, -1.25770636e+00])

# %%
predictions = lr_model.predict(X_train)

# %%
len(predictions)
# Out:
# 1579

# %%
r2_score(y_train, predictions)
# Out:
# 0.9649431595700579

# %%
mse = mean_squared_error(y_train, predictions)
mse
# Out:
# 335.86987759548003

# %% [markdown]
# # Testing model with 2023 player stats

# %%
test_2023_data = pd.read_csv('2023_player_stats.csv')
test_2023_data.head()
# Out:
#             name team position  season  games  receptions  targets  \
# 0     A.J. Brown  PHI       WR    2023     17         106      158
# 1     A.T. Perry   NO       WR    2023      8          12       18
# 2    AJ McCarron  CIN       QB    2023      2           0        0
# 3    Aaron Jones   GB       RB    2023     11          30       43
# 4  Aaron Rodgers  NYJ       QB    2023      1           0        0
#
#    receiving_yards  rec_ypg  receiving_tds  ...  sacks  sack_fumbles  \
# 0           1456.0    85.65              7  ...    0.0             0
# 1            246.0    30.75              4  ...    0.0             0
# 2              0.0     0.00              0  ...    1.0             0
# 3            233.0    21.18              1  ...    0.0             0
# 4              0.0     0.00              0  ...    1.0             0
#
#    offense_snaps  teams_offense_snaps  round  overall  \
# 0         1019.0               1154.0    2.0     51.0
# 1          319.0                519.0    6.0    195.0
# 2            0.0                  0.0    0.0      0.0
# 3          354.0                724.0    5.0    182.0
# 4            4.0                 58.0    1.0     24.0
#
#               stadium_name  stadium_weather_type  stadium_surface  \
# 0  Lincoln Financial Field                  cold            Grass
# 1  Mercedes-Benz Superdome                indoor        FieldTurf
# 2       Paul Brown Stadium                  cold        FieldTurf
# 3            Lambeau Field                  cold            Grass
# 4          MetLife Stadium                  cold        FieldTurf
#
#    fantasy_points_ppr
# 0              289.60
# 1               60.60
# 2                0.76
# 3              134.90
# 4                0.00
#
# [5 rows x 41 columns]

# %%
test_2023_data_cleaned = test_2023_data.drop(columns = ['name', 'season', 'team', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions', 'fantasy_points_ppr'])
test_2023_data_cleaned
# Out:
#     position  games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 0         WR     17      158    85.65  13.74                2.0          0.30
# 1         WR      8       18    30.75  20.50                0.0          0.07
# 2         QB      2        0     0.00   0.00                0.0          0.00
# 3         RB     11       43    21.18   7.77                1.0          0.12
# 4         QB      1        0     0.00   0.00                0.0          0.00
# ..       ...    ...      ...      ...    ...                ...           ...
# 519       QB     12        0     0.00   0.00                0.0          0.00
# 520       RB     14       37    13.71   7.11                0.0          0.07
# 521       RB     13       19     7.54   6.53                0.0          0.04
# 522       WR     16      108    53.62  11.14                0.0          0.24
# 523       WR      9       64    35.67   9.44                0.0          0.18
#
#      air_yards_share  carries  rush_ypg  ...  td_percentage  sacks  \
# 0               0.42        0      0.00  ...           0.07    0.0
# 1               0.16        0      0.00  ...           0.33    0.0
# 2               0.00        0      0.00  ...           0.00    1.0
# 3              -0.02      142     59.64  ...           0.02    0.0
# 4               0.00        0      0.00  ...           0.00    1.0
# ..               ...      ...       ...  ...            ...    ...
# 519             0.00       36     17.58  ...           0.02   46.0
# 520            -0.01      183     56.71  ...           0.03    0.0
# 521            -0.00      104     34.69  ...           0.01    0.0
# 522             0.24        8      3.50  ...           0.07    0.0
# 523             0.27        0      0.00  ...           0.06    0.0
#
#      sack_fumbles  offense_snaps  teams_offense_snaps  round  overall  \
# 0               0         1019.0               1154.0    2.0     51.0
# 1               0          319.0                519.0    6.0    195.0
# 2               0            0.0                  0.0    0.0      0.0
# 3               0          354.0                724.0    5.0    182.0
# 4               0            4.0                 58.0    1.0     24.0
# ..            ...            ...                  ...    ...      ...
# 519             7          688.0                747.0    1.0      2.0
# 520             0          531.0                957.0    3.0     86.0
# 521             0          227.0                803.0    4.0    122.0
# 522             0          905.0               1081.0    1.0     22.0
# 523             0          475.0                655.0    2.0     37.0
#
#                 stadium_name  stadium_weather_type  stadium_surface
# 0    Lincoln Financial Field                  cold            Grass
# 1    Mercedes-Benz Superdome                indoor        FieldTurf
# 2         Paul Brown Stadium                  cold        FieldTurf
# 3              Lambeau Field                  cold            Grass
# 4            MetLife Stadium                  cold        FieldTurf
# ..                       ...                   ...              ...
# 519          MetLife Stadium                  cold        FieldTurf
# 520        Lucas Oil Stadium                indoor        FieldTurf
# 521        Allegiant Stadium                indoor            Grass
# 522         M&T Bank Stadium              moderate        FieldTurf
# 523          TIAA Bank Field                  warm            Grass
#
# [524 rows x 26 columns]

# %%
# Encoding categorical columns for model
encoded_2023_test_data = pd.get_dummies(test_2023_data_cleaned)
encoded_2023_test_data
# Out:
#      games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 0       17      158    85.65  13.74                2.0          0.30
# 1        8       18    30.75  20.50                0.0          0.07
# 2        2        0     0.00   0.00                0.0          0.00
# 3       11       43    21.18   7.77                1.0          0.12
# 4        1        0     0.00   0.00                0.0          0.00
# ..     ...      ...      ...    ...                ...           ...
# 519     12        0     0.00   0.00                0.0          0.00
# 520     14       37    13.71   7.11                0.0          0.07
# 521     13       19     7.54   6.53                0.0          0.04
# 522     16      108    53.62  11.14                0.0          0.24
# 523      9       64    35.67   9.44                0.0          0.18
#
#      air_yards_share  carries  rush_ypg  rush_td_percentage  ...  \
# 0               0.42        0      0.00                0.00  ...
# 1               0.16        0      0.00                0.00  ...
# 2               0.00        0      0.00                0.00  ...
# 3              -0.02      142     59.64                0.01  ...
# 4               0.00        0      0.00                0.00  ...
# ..               ...      ...       ...                 ...  ...
# 519             0.00       36     17.58                0.00  ...
# 520            -0.01      183     56.71                0.03  ...
# 521            -0.00      104     34.69                0.01  ...
# 522             0.24        8      3.50                0.12  ...
# 523             0.27        0      0.00                0.00  ...
#
#      stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
# ..                          ...                              ...
# 519                       False                            False
# 520                       False                            False
# 521                       False                            False
# 522                       False                            False
# 523                       False                            False
#
#      stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# ..                            ...                             ...
# 519                         False                           False
# 520                         False                           False
# 521                         False                           False
# 522                         False                           False
# 523                          True                           False
#
#      stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         True                        False
# 1                        False                         True
# 2                         True                        False
# 3                         True                        False
# 4                         True                        False
# ..                         ...                          ...
# 519                       True                        False
# 520                      False                         True
# 521                      False                         True
# 522                      False                        False
# 523                      False                        False
#
#      stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# ..                             ...                        ...
# 519                          False                      False
# 520                          False                      False
# 521                          False                      False
# 522                           True                      False
# 523                          False                       True
#
#      stadium_surface_FieldTurf  stadium_surface_Grass
# 0                        False                   True
# 1                         True                  False
# 2                         True                  False
# 3                        False                   True
# 4                         True                  False
# ..                         ...                    ...
# 519                       True                  False
# 520                       True                  False
# 521                      False                   True
# 522                       True                  False
# 523                      False                   True
#
# [524 rows x 63 columns]

# %%
test_2023_predictions = lr_model.predict(encoded_2023_test_data)

test_2023_predictions
# Out:
# array([ 2.84903750e+02,  6.59848172e+01, -9.80480234e+00,  1.69937625e+02,
#        -2.50972475e+01,  2.20584509e+02,  5.53956001e+01,  1.50793245e+02,
#        -5.62688864e+00,  1.01967939e+02, -1.27308377e+01,  5.48395837e+01,
#         1.75776677e+02,  6.61720924e+01,  6.27792411e+01,  2.45398350e+02,
#         2.45089956e+02, -1.98633486e+01,  3.14331682e+01,  3.10250762e+02,
#         4.79622736e+01,  3.68873432e+01,  1.23262784e+01, -1.43428375e+01,
#         7.06673094e+01, -1.00461477e+01,  1.31252951e+02,  2.29419037e+02,
#         4.44752098e+01, -8.18872726e+00,  9.46294838e+01,  2.77916649e+02,
#         2.43161922e+01,  2.12219730e+01,  2.59909217e+02,  2.10223714e+01,
#         2.00313689e+01,  6.89614462e+01,  1.26103332e+01,  1.52352519e+02,
#         2.18343930e+02,  1.45981887e+01,  5.97533423e+01,  7.65720992e+01,
#         5.89676652e+01,  2.85660614e+02,  9.82012984e+00,  5.04555168e+01,
#         6.69911844e+00,  2.01606705e+02,  8.77835530e+00,  2.30075351e+02,
#         2.93554705e+01,  2.16469145e+02,  1.44394741e+01,  3.11310038e+01,
#         1.83042106e+01,  2.32986372e+02,  1.56624642e+01,  1.08190311e+02,
#         1.02664323e+01,  1.20664529e+02,  5.12881731e+01,  1.17926198e+02,
#         3.95151675e+01, -4.30795773e+00,  6.18980877e+01,  2.72817417e+01,
#         1.33630916e+02, -2.68969281e-01,  5.89193975e+00,  1.59190724e+02,
#         1.70450598e+02,  8.96601952e+01,  1.93407714e+02,  8.65836845e+01])

# %%
fantasy_2023_predictions = test_2023_data.copy()

# Creating a new column that holds model predictions
fantasy_2023_predictions['fantasy_2023_score_prediction'] = test_2023_predictions

# Rounding the fantasy score predictions to 2 decimal places
fantasy_2023_predictions['fantasy_2023_score_prediction'] = round(fantasy_2023_predictions['fantasy_2023_score_prediction'], 2)

# Chosing the columns that are shown in the dataframe
fantasy_2023_predictions = fantasy_2023_predictions[['name', 'team', 'position', 'fantasy_2023_score_prediction']]

# Pulling in a new column that has the actual fantasy score for each player from 2023
fantasy_2023_predictions['actual_fantasy_score'] = test_2023_data['fantasy_points_ppr']

fantasy_2023_predictions
# Out:
#               name team position  fantasy_2023_score_prediction  \
# 0       A.J. Brown  PHI       WR                         284.90
# 1       A.T. Perry   NO       WR                          65.98
# 2      AJ McCarron  CIN       QB                          -9.80
# 3      Aaron Jones   GB       RB                         169.94
# 4    Aaron Rodgers  NYJ       QB                         -25.10
# ..             ...  ...      ...                            ...
# 519    Zach Wilson  NYJ       QB                         159.19
# 520      Zack Moss  IND       RB                         170.45
# 521    Zamir White   LV       RB                          89.66
# 522    Zay Flowers  BAL       WR                         193.41
# 523      Zay Jones  JAX       WR                          86.58
#
#      actual_fantasy_score
# 0                  289.60
# 1                   60.60
# 2                    0.76
# 3                  134.90
# 4                    0.00
# ..                    ...
# 519                119.94
# 520                169.60
# 521                 73.90
# 522                206.40
# 523                 78.10
#
# [524 rows x 5 columns]

# %%
import math
mse_2023 = mean_squared_error(fantasy_2023_predictions['actual_fantasy_score'], fantasy_2023_predictions['fantasy_2023_score_prediction'])
rmse_2023 = math.sqrt(mse_2023)
rmse_2023
# Out:
# 15.900810231888636

# %%
r2_2023 = r2_score(fantasy_2023_predictions['actual_fantasy_score'], fantasy_2023_predictions['fantasy_2023_score_prediction'])
r2_2023
# Out:
# 0.9675404751863173

# %% [markdown]
# # Predictions for 2024

# %%
prediction_data = pd.read_csv('predicting_data.csv')
prediction_data.head()
# Out:
#             name team position      games  receptions     targets  \
# 0     A.J. Brown  PHI       WR  15.400000   75.800000  119.600000
# 1     A.T. Perry   NO       WR   8.000000   12.000000   18.000000
# 2    AJ McCarron  CIN       QB   2.000000    0.000000    0.000000
# 3    Aaron Jones   GB       RB  13.571429   38.857143   52.000000
# 4  Aaron Rodgers  NYJ       QB  13.272727    0.181818    0.181818
#
#    receiving_yards    rec_ypg  receiving_tds        ypr  ...  interceptions  \
# 0      1189.400000  76.596000       8.400000  16.020000  ...       0.000000
# 1       246.000000  30.750000       4.000000  20.500000  ...       0.000000
# 2         0.000000   0.000000       0.000000   0.000000  ...       0.250000
# 3       296.571429  20.691429       2.571429   7.080000  ...       0.000000
# 4        -0.909091  -0.057273       0.000000  -0.909091  ...       5.363636
#
#        sacks  sack_fumbles  offense_snaps  teams_offense_snaps  round  \
# 0   0.000000      0.000000     813.000000          1032.200000    2.0
# 1   0.000000      0.000000     319.000000           519.000000    6.0
# 2   2.000000      0.000000       0.000000             0.000000    0.0
# 3   0.000000      0.000000     482.285714           890.285714    5.0
# 4  29.090909      3.363636     847.636364           891.181818    1.0
#
#    overall             stadium_name  stadium_weather_type  stadium_surface
# 0     51.0  Lincoln Financial Field                  cold            Grass
# 1    195.0  Mercedes-Benz Superdome                indoor        FieldTurf
# 2      0.0       Paul Brown Stadium                  cold        FieldTurf
# 3    182.0            Lambeau Field                  cold            Grass
# 4     24.0          MetLife Stadium                  cold        FieldTurf
#
# [5 rows x 39 columns]

# %%
prediction_data_cleaned = prediction_data.drop(columns = ['name', 'team', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions'])
prediction_data_cleaned.head()
# Out:
#   position      games     targets    rec_ypg        ypr  receiving_fumbles  \
# 0       WR  15.400000  119.600000  76.596000  16.020000           1.400000
# 1       WR   8.000000   18.000000  30.750000  20.500000           0.000000
# 2       QB   2.000000    0.000000   0.000000   0.000000           0.000000
# 3       RB  13.571429   52.000000  20.691429   7.080000           0.857143
# 4       QB  13.272727    0.181818  -0.057273  -0.909091           0.000000
#
#    target_share  air_yards_share     carries   rush_ypg  ...  td_percentage  \
# 0      0.268000         0.384000    1.000000   0.904000  ...       0.116000
# 1      0.070000         0.160000    0.000000   0.000000  ...       0.330000
# 2      0.000000         0.000000    1.250000   4.875000  ...       0.005000
# 3      0.115714         0.007143  168.142857  61.561429  ...       0.042857
# 4      0.000000         0.000000   37.818182  12.918182  ...       0.052727
#
#        sacks  sack_fumbles  offense_snaps  teams_offense_snaps  round  \
# 0   0.000000      0.000000     813.000000          1032.200000    2.0
# 1   0.000000      0.000000     319.000000           519.000000    6.0
# 2   2.000000      0.000000       0.000000             0.000000    0.0
# 3   0.000000      0.000000     482.285714           890.285714    5.0
# 4  29.090909      3.363636     847.636364           891.181818    1.0
#
#    overall             stadium_name  stadium_weather_type  stadium_surface
# 0     51.0  Lincoln Financial Field                  cold            Grass
# 1    195.0  Mercedes-Benz Superdome                indoor        FieldTurf
# 2      0.0       Paul Brown Stadium                  cold        FieldTurf
# 3    182.0            Lambeau Field                  cold            Grass
# 4     24.0          MetLife Stadium                  cold        FieldTurf
#
# [5 rows x 26 columns]

# %%
prediction_data_cleaned.columns
# Out:
# Index(['position', 'games', 'targets', 'rec_ypg', 'ypr', 'receiving_fumbles',
#        'target_share', 'air_yards_share', 'carries', 'rush_ypg',
#        'rush_td_percentage', 'rushing_fumbles', 'attempts', 'comp_percentage',
#        'pass_ypg', 'passing_2pt_conversions', 'td_percentage', 'sacks',
#        'sack_fumbles', 'offense_snaps', 'teams_offense_snaps', 'round',
#        'overall', 'stadium_name', 'stadium_weather_type', 'stadium_surface'],
#       dtype='object')

# %%
# Encoding categorical columns for model
encoded_prediction_data = pd.get_dummies(prediction_data_cleaned)
encoded_prediction_data
# Out:
#          games     targets    rec_ypg        ypr  receiving_fumbles  \
# 0    15.400000  119.600000  76.596000  16.020000           1.400000
# 1     8.000000   18.000000  30.750000  20.500000           0.000000
# 2     2.000000    0.000000   0.000000   0.000000           0.000000
# 3    13.571429   52.000000  20.691429   7.080000           0.857143
# 4    13.272727    0.181818  -0.057273  -0.909091           0.000000
# ..         ...         ...        ...        ...                ...
# 519  11.333333    0.666667   0.073333   0.666667           0.000000
# 520  12.000000   23.000000   9.417500   6.367500           0.500000
# 521  12.000000    9.500000   3.770000   3.265000           0.000000
# 522  16.000000  108.000000  53.620000  11.140000           0.000000
# 523  13.500000   75.166667  33.471667  10.906667           0.333333
#
#      target_share  air_yards_share     carries   rush_ypg  rush_td_percentage  \
# 0        0.268000         0.384000    1.000000   0.904000            0.066000
# 1        0.070000         0.160000    0.000000   0.000000            0.000000
# 2        0.000000         0.000000    1.250000   4.875000            0.050000
# 3        0.115714         0.007143  168.142857  61.561429            0.037143
# 4        0.000000         0.000000   37.818182  12.918182            0.036364
# ..            ...              ...         ...        ...                 ...
# 519      0.000000         0.003333   31.000000  14.380000            0.060000
# 520      0.050000         0.002500  116.750000  41.467500            0.030000
# 521      0.020000         0.000000   60.500000  20.525000            0.005000
# 522      0.240000         0.240000    8.000000   3.500000            0.120000
# 523      0.163333         0.225000    1.166667   0.220000            0.000000
#
#      ...  stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 0    ...                       False                            False
# 1    ...                       False                            False
# 2    ...                       False                            False
# 3    ...                       False                            False
# 4    ...                       False                            False
# ..   ...                         ...                              ...
# 519  ...                       False                            False
# 520  ...                       False                            False
# 521  ...                       False                            False
# 522  ...                       False                            False
# 523  ...                       False                            False
#
#      stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# ..                            ...                             ...
# 519                         False                           False
# 520                         False                           False
# 521                         False                           False
# 522                         False                           False
# 523                          True                           False
#
#      stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         True                        False
# 1                        False                         True
# 2                         True                        False
# 3                         True                        False
# 4                         True                        False
# ..                         ...                          ...
# 519                       True                        False
# 520                      False                         True
# 521                      False                         True
# 522                      False                        False
# 523                      False                        False
#
#      stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# ..                             ...                        ...
# 519                          False                      False
# 520                          False                      False
# 521                          False                      False
# 522                           True                      False
# 523                          False                       True
#
#      stadium_surface_FieldTurf  stadium_surface_Grass
# 0                        False                   True
# 1                         True                  False
# 2                         True                  False
# 3                        False                   True
# 4                         True                  False
# ..                         ...                    ...
# 519                       True                  False
# 520                       True                  False
# 521                      False                   True
# 522                       True                  False
# 523                      False                   True
#
# [524 rows x 63 columns]

# %%
real_predictions = lr_model.predict(encoded_prediction_data)

real_predictions
# Out:
# array([ 2.26102929e+02,  6.59848172e+01,  3.57040619e-02,  2.02483933e+02,
#         2.21971069e+02,  1.60050476e+02,  4.69585405e+01,  1.50793245e+02,
#         3.25086228e+01,  1.11907514e+02,  3.57939838e+00,  4.16611999e+01,
#         1.11707212e+02,  8.81652287e+01,  1.55720535e+02,  2.69633779e+02,
#         2.18128129e+02,  2.38917698e+00,  5.73558789e+01,  2.59755097e+02,
#         4.79622736e+01,  3.68873432e+01,  1.86607085e+02, -2.73414523e+00,
#         7.06673094e+01, -1.00461477e+01,  1.83805356e+02,  2.28214844e+02,
#         1.04002138e+02, -9.48039665e+00,  6.91029998e+01,  2.07759418e+02,
#         2.43161922e+01,  5.46623413e+01,  2.59909217e+02,  4.39640330e+01,
#         2.17193854e+01,  6.89614462e+01,  7.00332947e+01,  2.01897378e+02,
#         1.95248789e+02,  3.33636426e+01,  3.11402675e+01,  3.76716436e+01,
#         7.19084928e+01,  2.01424298e+02,  9.82012984e+00,  4.36011725e+01,
#         9.48726292e+00,  1.78351051e+02,  8.77835530e+00,  1.63138156e+02,
#         1.88535768e+02,  4.09311097e+01,  4.87612229e+01,  2.68767558e+02,
#         1.24445733e+01,  1.03412143e+02,  8.02405399e+01,  7.38474110e+01,
#         1.95452022e+01,  8.23189441e+01,  6.92099670e+01,  1.17926198e+02,
#         3.95151675e+01,  9.33529527e+01,  6.18980877e+01,  2.72817417e+01,
#         1.33630916e+02, -2.68969281e-01,  8.00511358e+01,  1.44775019e+02,
#         1.04601797e+02,  4.49142569e+01,  1.93407714e+02,  1.08147191e+02])

# %%
# Creating copy of original dataframe to create a clean predictions dataframe with each player
fantasy_2024_predictions = prediction_data.copy()

# Creating a new column that holds model predictions & average per week score
fantasy_2024_predictions['fantasy_2024_score_prediction'] = real_predictions
fantasy_2024_predictions['fantasy_2024_per_week_score_prediction'] = (real_predictions/17)

# Rounding the fantasy score predictions & per week scores to 2 decimal places 
fantasy_2024_predictions['fantasy_2024_score_prediction'] = round(fantasy_2024_predictions['fantasy_2024_score_prediction'], 2)
fantasy_2024_predictions['fantasy_2024_per_week_score_prediction'] = round(fantasy_2024_predictions['fantasy_2024_per_week_score_prediction'], 2)


#### ================== ALL PLAYERS ========================= ####

# Chosing the columns that are shown in the dataframe
fantasy_2024_predictions = fantasy_2024_predictions[['name', 'team', 'position', 'fantasy_2024_score_prediction', 'fantasy_2024_per_week_score_prediction']]

# Sorting all players in descending order
fantasy_2024_predictions = fantasy_2024_predictions.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all players
display(fantasy_2024_predictions.reset_index(drop=True).head(10))

#### ================== WRs ========================= ####

# Filtering for WRs
fantasy_2024_predictions_WR = fantasy_2024_predictions[fantasy_2024_predictions['position'] == 'WR']

# # Sorting all WRs in descending order
fantasy_2024_predictions_WR = fantasy_2024_predictions_WR.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all WRs
display(fantasy_2024_predictions_WR.reset_index(drop=True).head(10))

#### ================== QBs ========================= ####

# Filtering for QBs
fantasy_2024_predictions_QB = fantasy_2024_predictions[fantasy_2024_predictions['position'] == 'QB']

# # Sorting all QBs in descending order
fantasy_2024_predictions_QB = fantasy_2024_predictions_QB.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all QBs
display(fantasy_2024_predictions_QB.reset_index(drop=True).head(10))

#### ================== RBs ========================= ####

# Filtering for RBs
fantasy_2024_predictions_RB = fantasy_2024_predictions[fantasy_2024_predictions['position'] == 'RB']

# # Sorting all RBs in descending order
fantasy_2024_predictions_RB = fantasy_2024_predictions_RB.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all RBs
display(fantasy_2024_predictions_RB.reset_index(drop=True).head(10))

#### ================== TEs ========================= ####

# Filtering for TEs
fantasy_2024_predictions_TE = fantasy_2024_predictions[fantasy_2024_predictions['position'] == 'TE']

# # Sorting all TEs in descending order
fantasy_2024_predictions_TE = fantasy_2024_predictions_TE.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all TEs
display(fantasy_2024_predictions_TE.reset_index(drop=True).head(10))
# Out:
#                name team position  fantasy_2024_score_prediction  \
# 0        Josh Allen  BUF       QB                         320.26
# 1    Justin Herbert  LAC       QB                         310.89
# 2        Puka Nacua   LA       WR                         304.71
# 3  Justin Jefferson  MIN       WR                         294.68
# 4   Trevor Lawrence  JAX       QB                         293.31
# 5     Lamar Jackson  BAL       QB                         276.29
# 6   Patrick Mahomes   KC       QB                         273.53
# 7       CeeDee Lamb  DAL       WR                         273.34
# 8      Alvin Kamara   NO       RB                         269.63
# 9       Tyreek Hill  MIA       WR                         268.77
#
#    fantasy_2024_per_week_score_prediction
# 0                                   18.84
# 1                                   18.29
# 2                                   17.92
# 3                                   17.33
# 4                                   17.25
# 5                                   16.25
# 6                                   16.09
# 7                                   16.08
# 8                                   15.86
# 9                                   15.81
#                 name team position  fantasy_2024_score_prediction  \
# 0         Puka Nacua   LA       WR                         304.71
# 1   Justin Jefferson  MIN       WR                         294.68
# 2        CeeDee Lamb  DAL       WR                         273.34
# 3        Tyreek Hill  MIA       WR                         268.77
# 4      Ja'Marr Chase  CIN       WR                         260.14
# 5  Amon-Ra St. Brown  DET       WR                         259.76
# 6       Keenan Allen  LAC       WR                         254.63
# 7         DK Metcalf  SEA       WR                         248.97
# 8    DeAndre Hopkins  TEN       WR                         248.90
# 9     Garrett Wilson  NYJ       WR                         246.69
#
#    fantasy_2024_per_week_score_prediction
# 0                                   17.92
# 1                                   17.33
# 2                                   16.08
# 3                                   15.81
# 4                                   15.30
# 5                                   15.28
# 6                                   14.98
# 7                                   14.65
# 8                                   14.64
# 9                                   14.51
#               name team position  fantasy_2024_score_prediction  \
# 0       Josh Allen  BUF       QB                         320.26
# 1   Justin Herbert  LAC       QB                         310.89
# 2  Trevor Lawrence  JAX       QB                         293.31
# 3    Lamar Jackson  BAL       QB                         276.29
# 4  Patrick Mahomes   KC       QB                         273.53
# 5      Jalen Hurts  PHI       QB                         265.70
# 6     Kyler Murray  ARI       QB                         265.48
# 7       Derek Carr   NO       QB                         256.81
# 8     Dak Prescott  DAL       QB                         251.57
# 9   Russell Wilson  DEN       QB                         250.61
#
#    fantasy_2024_per_week_score_prediction
# 0                                   18.84
# 1                                   18.29
# 2                                   17.25
# 3                                   16.25
# 4                                   16.09
# 5                                   15.63
# 6                                   15.62
# 7                                   15.11
# 8                                   14.80
# 9                                   14.74
#                   name team position  fantasy_2024_score_prediction  \
# 0         Alvin Kamara   NO       RB                         269.63
# 1  Christian McCaffrey   SF       RB                         266.60
# 2         Najee Harris  PIT       RB                         261.68
# 3       Bijan Robinson  ATL       RB                         259.91
# 4      Ezekiel Elliott   NE       RB                         259.22
# 5          Josh Jacobs   LV       RB                         254.48
# 6       Travis Etienne  JAX       RB                         246.99
# 7         Jahmyr Gibbs  DET       RB                         228.68
# 8        Austin Ekeler  LAC       RB                         228.21
# 9            Joe Mixon  CIN       RB                         227.75
#
#    fantasy_2024_per_week_score_prediction
# 0                                   15.86
# 1                                   15.68
# 2                                   15.39
# 3                                   15.29
# 4                                   15.25
# 5                                   14.97
# 6                                   14.53
# 7                                   13.45
# 8                                   13.42
# 9                                   13.40
#              name team position  fantasy_2024_score_prediction  \
# 0    Travis Kelce   KC       TE                         241.06
# 1     Sam LaPorta  DET       TE                         203.22
# 2   George Kittle   SF       TE                         180.86
# 3    Mark Andrews  BAL       TE                         172.40
# 4     Evan Engram  JAX       TE                         159.21
# 5  Dalton Kincaid  BUF       TE                         157.97
# 6  T.J. Hockenson  MIN       TE                         154.75
# 7    Jimmy Graham   NO       TE                         150.70
# 8       Noah Fant  SEA       TE                         136.07
# 9  Dallas Goedert  PHI       TE                         130.98
#
#    fantasy_2024_per_week_score_prediction
# 0                                   14.18
# 1                                   11.95
# 2                                   10.64
# 3                                   10.14
# 4                                    9.37
# 5                                    9.29
# 6                                    9.10
# 7                                    8.86
# 8                                    8.00
# 9                                    7.70
