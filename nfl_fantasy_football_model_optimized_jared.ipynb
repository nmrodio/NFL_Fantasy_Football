# %%
# Import required libraries
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import math
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="bd5cbbac-fc30-414e-8ea4-1ef073c2f88c" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"be4f7ede-5a90-45bf-b684-658b34f2a5b4":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"8d437d4757264d32a6fcb2c0b86fdec1","client_comm_id":"076bb08ca2284261b3aa627757a533ad"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"be4f7ede-5a90-45bf-b684-658b34f2a5b4","roots":{"p1002":"bd5cbbac-fc30-414e-8ea4-1ef073c2f88c"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# # Training model with all seasons data - Optimized

# %%
all_seasons_data = pd.read_csv('training_data.csv')
all_seasons_data
# Out:
#             name team position  season  games  receptions  targets  \
# 0     A.J. Brown  TEN       WR    2019     16          52       84
# 1     A.J. Brown  TEN       WR    2020     14          70      106
# 2     A.J. Brown  TEN       WR    2021     13          63      105
# 3     A.J. Brown  PHI       WR    2022     17          88      145
# 4     A.J. Brown  PHI       WR    2023     17         106      158
# ...          ...  ...      ...     ...    ...         ...      ...
# 2101   Zay Jones  BUF       WR    2018     16          56      102
# 2102   Zay Jones   LV       WR    2020     11          14       20
# 2103   Zay Jones   LV       WR    2021     15          47       70
# 2104   Zay Jones  JAX       WR    2022     16          82      121
# 2105   Zay Jones  JAX       WR    2023      9          34       64
#
#       receiving_yards  rec_ypg  receiving_tds  ...  sacks  sack_fumbles  \
# 0              1051.0    65.69              8  ...    0.0             0
# 1              1075.0    76.79             11  ...    0.0             0
# 2               869.0    66.85              5  ...    0.0             0
# 3              1496.0    88.00             11  ...    0.0             0
# 4              1456.0    85.65              7  ...    0.0             0
# ...               ...      ...            ...  ...    ...           ...
# 2101            652.0    40.75              7  ...    0.0             0
# 2102            154.0    14.00              1  ...    0.0             0
# 2103            546.0    36.40              1  ...    0.0             0
# 2104            823.0    51.44              5  ...    0.0             0
# 2105            321.0    35.67              2  ...    0.0             0
#
#       offense_snaps  teams_offense_snaps  round  overall  \
# 0             678.0                997.0    2.0     51.0
# 1             760.0                945.0    2.0     51.0
# 2             604.0                876.0    2.0     51.0
# 3            1004.0               1189.0    2.0     51.0
# 4            1019.0               1154.0    2.0     51.0
# ...             ...                  ...    ...      ...
# 2101          941.0               1063.0    2.0     37.0
# 2102          248.0                771.0    2.0     37.0
# 2103          614.0               1026.0    2.0     37.0
# 2104          930.0               1082.0    2.0     37.0
# 2105          475.0                655.0    2.0     37.0
#
#                  stadium_name  stadium_weather_type  stadium_surface  \
# 0              Nissan Stadium              moderate            Grass
# 1              Nissan Stadium              moderate            Grass
# 2              Nissan Stadium              moderate            Grass
# 3     Lincoln Financial Field                  cold            Grass
# 4     Lincoln Financial Field                  cold            Grass
# ...                       ...                   ...              ...
# 2101            New Era Field                  cold        FieldTurf
# 2102        Allegiant Stadium                indoor            Grass
# 2103        Allegiant Stadium                indoor            Grass
# 2104          TIAA Bank Field                  warm            Grass
# 2105          TIAA Bank Field                  warm            Grass
#
#       fantasy_points_ppr
# 0                 217.10
# 1                 247.50
# 2                 180.90
# 3                 299.60
# 4                 289.60
# ...                  ...
# 2101              165.20
# 2102               36.56
# 2103              105.90
# 2104              198.10
# 2105               78.10
#
# [2106 rows x 41 columns]

# %%
# Adding new features to training data
# Whatever you add into this cell for a "new feature" ==> Find the other three cells of code below that match up and add that line of code in there as well
opt_model_all_seasons_data = all_seasons_data.copy()

opt_model_all_seasons_data['target_per_game'] = round((opt_model_all_seasons_data['targets']/opt_model_all_seasons_data['games']),2)
opt_model_all_seasons_data['carries_per_game'] = round((opt_model_all_seasons_data['carries']/opt_model_all_seasons_data['games']),2)
opt_model_all_seasons_data['team_off_snaps_per_game'] = round((opt_model_all_seasons_data['teams_offense_snaps']/opt_model_all_seasons_data['games']),2)
opt_model_all_seasons_data['off_snaps_per_game'] = round((opt_model_all_seasons_data['offense_snaps']/opt_model_all_seasons_data['games']),2)
opt_model_all_seasons_data['attempts_per_game'] = round((opt_model_all_seasons_data['attempts']/opt_model_all_seasons_data['games']),2)
opt_model_all_seasons_data['attempts_per_game'] = round((opt_model_all_seasons_data['attempts']/opt_model_all_seasons_data['games']),2)



opt_model_all_seasons_data.fillna(0, inplace=True)
new_features_training_data_all_seasons = opt_model_all_seasons_data
new_features_training_data_all_seasons.head()
# Out:
#          name team position  season  games  receptions  targets  \
# 0  A.J. Brown  TEN       WR    2019     16          52       84
# 1  A.J. Brown  TEN       WR    2020     14          70      106
# 2  A.J. Brown  TEN       WR    2021     13          63      105
# 3  A.J. Brown  PHI       WR    2022     17          88      145
# 4  A.J. Brown  PHI       WR    2023     17         106      158
#
#    receiving_yards  rec_ypg  receiving_tds  ...  overall  \
# 0           1051.0    65.69              8  ...     51.0
# 1           1075.0    76.79             11  ...     51.0
# 2            869.0    66.85              5  ...     51.0
# 3           1496.0    88.00             11  ...     51.0
# 4           1456.0    85.65              7  ...     51.0
#
#               stadium_name  stadium_weather_type  stadium_surface  \
# 0           Nissan Stadium              moderate            Grass
# 1           Nissan Stadium              moderate            Grass
# 2           Nissan Stadium              moderate            Grass
# 3  Lincoln Financial Field                  cold            Grass
# 4  Lincoln Financial Field                  cold            Grass
#
#    fantasy_points_ppr  target_per_game  carries_per_game  \
# 0               217.1             5.25              0.19
# 1               247.5             7.57              0.00
# 2               180.9             8.08              0.15
# 3               299.6             8.53              0.00
# 4               289.6             9.29              0.00
#
#    team_off_snaps_per_game  off_snaps_per_game  attempts_per_game
# 0                    62.31               42.38               0.00
# 1                    67.50               54.29               0.00
# 2                    67.38               46.46               0.15
# 3                    69.94               59.06               0.00
# 4                    67.88               59.94               0.00
#
# [5 rows x 46 columns]

# %%
new_features_training_data_all_seasons.columns
# Out:
# Index(['name', 'team', 'position', 'season', 'games', 'receptions', 'targets',
#        'receiving_yards', 'rec_ypg', 'receiving_tds', 'ypr',
#        'receiving_fumbles', 'receiving_2pt_conversions', 'target_share',
#        'air_yards_share', 'carries', 'rushing_yards', 'rush_ypg',
#        'rushing_tds', 'rush_td_percentage', 'rushing_fumbles',
#        'rushing_2pt_conversions', 'completions', 'attempts', 'comp_percentage',
#        'passing_yards', 'pass_ypg', 'passing_tds', 'passing_2pt_conversions',
#        'td_percentage', 'interceptions', 'sacks', 'sack_fumbles',
#        'offense_snaps', 'teams_offense_snaps', 'round', 'overall',
#        'stadium_name', 'stadium_weather_type', 'stadium_surface',
#        'fantasy_points_ppr', 'target_per_game', 'carries_per_game',
#        'team_off_snaps_per_game', 'off_snaps_per_game', 'attempts_per_game'],
#       dtype='object')

# %%
# Cleaning up all seasons data columns
all_seasons_data_cleaned = new_features_training_data_all_seasons.drop(columns = ['name', 'season', 'team', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions'])
all_seasons_data_cleaned.head()
# Out:
#   position  games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 0       WR     16       84    65.69  20.21                1.0          0.20
# 1       WR     14      106    76.79  15.36                2.0          0.27
# 2       WR     13      105    66.85  13.79                0.0          0.28
# 3       WR     17      145    88.00  17.00                2.0          0.29
# 4       WR     17      158    85.65  13.74                2.0          0.30
#
#    air_yards_share  carries  rush_ypg  ...  overall             stadium_name  \
# 0             0.29        3      3.75  ...     51.0           Nissan Stadium
# 1             0.35        0      0.00  ...     51.0           Nissan Stadium
# 2             0.45        2      0.77  ...     51.0           Nissan Stadium
# 3             0.41        0      0.00  ...     51.0  Lincoln Financial Field
# 4             0.42        0      0.00  ...     51.0  Lincoln Financial Field
#
#    stadium_weather_type  stadium_surface  fantasy_points_ppr  target_per_game  \
# 0              moderate            Grass               217.1             5.25
# 1              moderate            Grass               247.5             7.57
# 2              moderate            Grass               180.9             8.08
# 3                  cold            Grass               299.6             8.53
# 4                  cold            Grass               289.6             9.29
#
#    carries_per_game  team_off_snaps_per_game  off_snaps_per_game  \
# 0              0.19                    62.31               42.38
# 1              0.00                    67.50               54.29
# 2              0.15                    67.38               46.46
# 3              0.00                    69.94               59.06
# 4              0.00                    67.88               59.94
#
#    attempts_per_game
# 0               0.00
# 1               0.00
# 2               0.15
# 3               0.00
# 4               0.00
#
# [5 rows x 32 columns]

# %%
all_seasons_data_cleaned.columns
# Out:
# Index(['position', 'games', 'targets', 'rec_ypg', 'ypr', 'receiving_fumbles',
#        'target_share', 'air_yards_share', 'carries', 'rush_ypg',
#        'rush_td_percentage', 'rushing_fumbles', 'attempts', 'comp_percentage',
#        'pass_ypg', 'passing_2pt_conversions', 'td_percentage', 'sacks',
#        'sack_fumbles', 'offense_snaps', 'teams_offense_snaps', 'round',
#        'overall', 'stadium_name', 'stadium_weather_type', 'stadium_surface',
#        'fantasy_points_ppr', 'target_per_game', 'carries_per_game',
#        'team_off_snaps_per_game', 'off_snaps_per_game', 'attempts_per_game'],
#       dtype='object')

# %%
# Encoding categorical columns for model
encoded_training_data_all_seasons = pd.get_dummies(all_seasons_data_cleaned)
encoded_training_data_all_seasons
# Out:
#       games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 0        16       84    65.69  20.21                1.0          0.20
# 1        14      106    76.79  15.36                2.0          0.27
# 2        13      105    66.85  13.79                0.0          0.28
# 3        17      145    88.00  17.00                2.0          0.29
# 4        17      158    85.65  13.74                2.0          0.30
# ...     ...      ...      ...    ...                ...           ...
# 2101     16      102    40.75  11.64                1.0          0.21
# 2102     11       20    14.00  11.00                0.0          0.05
# 2103     15       70    36.40  11.62                1.0          0.14
# 2104     16      121    51.44  10.04                0.0          0.22
# 2105      9       64    35.67   9.44                0.0          0.18
#
#       air_yards_share  carries  rush_ypg  rush_td_percentage  ...  \
# 0                0.29        3      3.75                0.33  ...
# 1                0.35        0      0.00                0.00  ...
# 2                0.45        2      0.77                0.00  ...
# 3                0.41        0      0.00                0.00  ...
# 4                0.42        0      0.00                0.00  ...
# ...               ...      ...       ...                 ...  ...
# 2101             0.26        1      0.00                0.00  ...
# 2102             0.04        0      0.00                0.00  ...
# 2103             0.24        2      0.20                0.00  ...
# 2104             0.26        4      1.12                0.00  ...
# 2105             0.27        0      0.00                0.00  ...
#
#       stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 0                          False                            False
# 1                          False                            False
# 2                          False                            False
# 3                          False                            False
# 4                          False                            False
# ...                          ...                              ...
# 2101                       False                            False
# 2102                       False                            False
# 2103                       False                            False
# 2104                       False                            False
# 2105                       False                            False
#
#       stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ...                            ...                             ...
# 2101                         False                           False
# 2102                         False                           False
# 2103                         False                           False
# 2104                          True                           False
# 2105                          True                           False
#
#       stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                          True                        False
# 4                          True                        False
# ...                         ...                          ...
# 2101                       True                        False
# 2102                      False                         True
# 2103                      False                         True
# 2104                      False                        False
# 2105                      False                        False
#
#       stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                              True                      False
# 1                              True                      False
# 2                              True                      False
# 3                             False                      False
# 4                             False                      False
# ...                             ...                        ...
# 2101                          False                      False
# 2102                          False                      False
# 2103                          False                      False
# 2104                          False                       True
# 2105                          False                       True
#
#       stadium_surface_FieldTurf  stadium_surface_Grass
# 0                         False                   True
# 1                         False                   True
# 2                         False                   True
# 3                         False                   True
# 4                         False                   True
# ...                         ...                    ...
# 2101                       True                  False
# 2102                      False                   True
# 2103                      False                   True
# 2104                      False                   True
# 2105                      False                   True
#
# [2106 rows x 69 columns]

# %%
# Defining y (target variable)
y = encoded_training_data_all_seasons['fantasy_points_ppr']

# Defining X (features)
X = encoded_training_data_all_seasons.drop(columns = 'fantasy_points_ppr')

# %%
# Spliting model into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=42)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
intercept = lr_model.intercept_
intercept
# Out:
# 9.918164376407645

# %%
m = lr_model.coef_
m
# Out:
# array([-3.09168598e-01,  1.62893158e+00,  2.15326902e+00, -1.10466671e+00,
#        -6.41667006e-01,  7.13887430e+01, -4.13240368e+01,  6.36494297e-01,
#         1.43962148e+00,  1.79025424e+01,  4.56792436e-01,  4.53312778e-01,
#        -7.26548481e-01,  8.63241187e-01,  5.91191252e+00,  5.79493076e+01,
#        -2.48072165e-01, -2.39330717e+00,  1.47277849e-02, -1.96954992e-03,
#        -4.20910112e+00,  1.20038147e-01, -1.52049319e+01, -5.75863763e+00,
#         1.38548423e-02, -2.13498452e-01, -6.29219471e+00, -4.20370487e-01,
#        -4.61426922e+00,  3.15356318e+00,  1.88107653e+00,  5.68081742e-01,
#        -3.23758892e+00,  5.31437708e+00, -6.04195375e+00,  5.98852102e+00,
#         2.95670436e+00, -4.35787428e+00, -1.98179716e+00,  2.94409788e+00,
#         1.59527592e+00, -3.40116924e+00,  2.68259230e-01, -1.49994356e+00,
#         4.22654748e+00, -2.16364837e+00,  1.95235187e+00,  2.96356003e-01,
#        -1.88249315e+00,  3.07235065e+00, -3.88201605e+00,  2.58084538e+00,
#        -5.24972598e+00,  2.49480067e+00,  2.89342058e+00,  1.41299223e+00,
#         4.52096879e-01,  4.47401633e-01, -3.22746726e+00,  2.01716196e+00,
#        -2.92702905e+00, -1.62893578e+00,  4.67114450e-02, -1.37486823e+00,
#         2.86464609e-01,  1.04169217e+00,  1.10625196e+00, -1.10625196e+00])

# %%
training_predictions_all_seasons = lr_model.predict(X_train)

# %%
training_all_seasons_data_r2 = r2_score(y_train, training_predictions_all_seasons)
training_all_seasons_data_r2
# Out:
# 0.9776173673678586

# %%
training_all_seasons_data_mse = mean_squared_error(y_train, training_predictions_all_seasons)
training_all_seasons_data_rmse = math.sqrt(training_all_seasons_data_mse)
training_all_seasons_data_rmse
# Out:
# 14.643831581074425

# %%
testing_predictions_all_seasons = lr_model.predict(X_test)

# %%
testing_all_seasons_data_r2 = r2_score(y_test, testing_predictions_all_seasons)
testing_all_seasons_data_r2
# Out:
# 0.9749548173727994

# %%
testing_all_seasons_data_mse = mean_squared_error(y_test, testing_predictions_all_seasons)
testing_all_seasons_data_rmse = math.sqrt(testing_all_seasons_data_mse)
testing_all_seasons_data_rmse
# Out:
# 14.927806296223993

# %% [markdown]
# # Training model without 2023 season data for testing 2023 fantasy scores - Optimized

# %%
# Creating a df with no 2023 data to test the performance of the model against last years fantasy scores
# Adding new features to training data

no_2023_season_data = all_seasons_data[all_seasons_data['season'] != 2023]
no_2023_season_data = no_2023_season_data.drop(columns = 'season')

no_2023_season_data['target_per_game'] = round((no_2023_season_data['targets']/no_2023_season_data['games']),2)
no_2023_season_data['carries_per_game'] = round((no_2023_season_data['carries']/no_2023_season_data['games']),2)
no_2023_season_data['team_off_snaps_per_game'] = round((no_2023_season_data['teams_offense_snaps']/no_2023_season_data['games']),2)
no_2023_season_data['off_snaps_per_game'] = round((no_2023_season_data['offense_snaps']/no_2023_season_data['games']),2)
no_2023_season_data['attempts_per_game'] = round((no_2023_season_data['attempts']/no_2023_season_data['games']),2)



no_2023_season_data.fillna(0, inplace=True)
new_features_training_data_2023 = no_2023_season_data
new_features_training_data_2023
# Out:
#              name team position  games  receptions  targets  receiving_yards  \
# 0      A.J. Brown  TEN       WR     16          52       84           1051.0
# 1      A.J. Brown  TEN       WR     14          70      106           1075.0
# 2      A.J. Brown  TEN       WR     13          63      105            869.0
# 3      A.J. Brown  PHI       WR     17          88      145           1496.0
# 6     AJ McCarron  CIN       QB      2           0        0              0.0
# ...           ...  ...      ...    ...         ...      ...              ...
# 2100    Zay Jones  BUF       WR     14          27       74            316.0
# 2101    Zay Jones  BUF       WR     16          56      102            652.0
# 2102    Zay Jones   LV       WR     11          14       20            154.0
# 2103    Zay Jones   LV       WR     15          47       70            546.0
# 2104    Zay Jones  JAX       WR     16          82      121            823.0
#
#       rec_ypg  receiving_tds    ypr  ...  overall             stadium_name  \
# 0       65.69              8  20.21  ...     51.0           Nissan Stadium
# 1       76.79             11  15.36  ...     51.0           Nissan Stadium
# 2       66.85              5  13.79  ...     51.0           Nissan Stadium
# 3       88.00             11  17.00  ...     51.0  Lincoln Financial Field
# 6        0.00              0   0.00  ...      0.0       Paul Brown Stadium
# ...       ...            ...    ...  ...      ...                      ...
# 2100    22.57              2  11.70  ...     37.0            New Era Field
# 2101    40.75              7  11.64  ...     37.0            New Era Field
# 2102    14.00              1  11.00  ...     37.0        Allegiant Stadium
# 2103    36.40              1  11.62  ...     37.0        Allegiant Stadium
# 2104    51.44              5  10.04  ...     37.0          TIAA Bank Field
#
#       stadium_weather_type  stadium_surface  fantasy_points_ppr  \
# 0                 moderate            Grass              217.10
# 1                 moderate            Grass              247.50
# 2                 moderate            Grass              180.90
# 3                     cold            Grass              299.60
# 6                     cold        FieldTurf                2.64
# ...                    ...              ...                 ...
# 2100                  cold        FieldTurf               70.60
# 2101                  cold        FieldTurf              165.20
# 2102                indoor            Grass               36.56
# 2103                indoor            Grass              105.90
# 2104                  warm            Grass              198.10
#
#       target_per_game  carries_per_game  team_off_snaps_per_game  \
# 0                5.25              0.19                    62.31
# 1                7.57              0.00                    67.50
# 2                8.08              0.15                    67.38
# 3                8.53              0.00                    69.94
# 6                0.00              0.00                     0.00
# ...               ...               ...                      ...
# 2100             5.29              0.00                    67.29
# 2101             6.38              0.06                    66.44
# 2102             1.82              0.00                    70.09
# 2103             4.67              0.13                    68.40
# 2104             7.56              0.25                    67.62
#
#       off_snaps_per_game  attempts_per_game
# 0                  42.38               0.00
# 1                  54.29               0.00
# 2                  46.46               0.15
# 3                  59.06               0.00
# 6                   0.00               7.00
# ...                  ...                ...
# 2100               53.64               0.00
# 2101               58.81               0.06
# 2102               22.55               0.09
# 2103               40.93               0.00
# 2104               58.12               0.00
#
# [1582 rows x 45 columns]

# %%
new_features_training_data_2023.columns
# Out:
# Index(['name', 'team', 'position', 'games', 'receptions', 'targets',
#        'receiving_yards', 'rec_ypg', 'receiving_tds', 'ypr',
#        'receiving_fumbles', 'receiving_2pt_conversions', 'target_share',
#        'air_yards_share', 'carries', 'rushing_yards', 'rush_ypg',
#        'rushing_tds', 'rush_td_percentage', 'rushing_fumbles',
#        'rushing_2pt_conversions', 'completions', 'attempts', 'comp_percentage',
#        'passing_yards', 'pass_ypg', 'passing_tds', 'passing_2pt_conversions',
#        'td_percentage', 'interceptions', 'sacks', 'sack_fumbles',
#        'offense_snaps', 'teams_offense_snaps', 'round', 'overall',
#        'stadium_name', 'stadium_weather_type', 'stadium_surface',
#        'fantasy_points_ppr', 'target_per_game', 'carries_per_game',
#        'team_off_snaps_per_game', 'off_snaps_per_game', 'attempts_per_game'],
#       dtype='object')

# %%
# Cleaning up all seasons data columns
no_2023_season_data_cleaned = new_features_training_data_2023.drop(columns = ['name', 'team', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions'])
no_2023_season_data_cleaned.head()
# Out:
#   position  games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 0       WR     16       84    65.69  20.21                1.0          0.20
# 1       WR     14      106    76.79  15.36                2.0          0.27
# 2       WR     13      105    66.85  13.79                0.0          0.28
# 3       WR     17      145    88.00  17.00                2.0          0.29
# 6       QB      2        0     0.00   0.00                0.0          0.00
#
#    air_yards_share  carries  rush_ypg  ...  overall             stadium_name  \
# 0             0.29        3      3.75  ...     51.0           Nissan Stadium
# 1             0.35        0      0.00  ...     51.0           Nissan Stadium
# 2             0.45        2      0.77  ...     51.0           Nissan Stadium
# 3             0.41        0      0.00  ...     51.0  Lincoln Financial Field
# 6             0.00        0      0.00  ...      0.0       Paul Brown Stadium
#
#    stadium_weather_type  stadium_surface  fantasy_points_ppr  target_per_game  \
# 0              moderate            Grass              217.10             5.25
# 1              moderate            Grass              247.50             7.57
# 2              moderate            Grass              180.90             8.08
# 3                  cold            Grass              299.60             8.53
# 6                  cold        FieldTurf                2.64             0.00
#
#    carries_per_game  team_off_snaps_per_game  off_snaps_per_game  \
# 0              0.19                    62.31               42.38
# 1              0.00                    67.50               54.29
# 2              0.15                    67.38               46.46
# 3              0.00                    69.94               59.06
# 6              0.00                     0.00                0.00
#
#    attempts_per_game
# 0               0.00
# 1               0.00
# 2               0.15
# 3               0.00
# 6               7.00
#
# [5 rows x 32 columns]

# %%
# Encoding categorical columns for model
no_2023_encoded_training_data = pd.get_dummies(no_2023_season_data_cleaned)
no_2023_encoded_training_data
# Out:
#       games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 0        16       84    65.69  20.21                1.0          0.20
# 1        14      106    76.79  15.36                2.0          0.27
# 2        13      105    66.85  13.79                0.0          0.28
# 3        17      145    88.00  17.00                2.0          0.29
# 6         2        0     0.00   0.00                0.0          0.00
# ...     ...      ...      ...    ...                ...           ...
# 2100     14       74    22.57  11.70                0.0          0.18
# 2101     16      102    40.75  11.64                1.0          0.21
# 2102     11       20    14.00  11.00                0.0          0.05
# 2103     15       70    36.40  11.62                1.0          0.14
# 2104     16      121    51.44  10.04                0.0          0.22
#
#       air_yards_share  carries  rush_ypg  rush_td_percentage  ...  \
# 0                0.29        3      3.75                0.33  ...
# 1                0.35        0      0.00                0.00  ...
# 2                0.45        2      0.77                0.00  ...
# 3                0.41        0      0.00                0.00  ...
# 6                0.00        0      0.00                0.00  ...
# ...               ...      ...       ...                 ...  ...
# 2100             0.28        0      0.00                0.00  ...
# 2101             0.26        1      0.00                0.00  ...
# 2102             0.04        0      0.00                0.00  ...
# 2103             0.24        2      0.20                0.00  ...
# 2104             0.26        4      1.12                0.00  ...
#
#       stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 0                          False                            False
# 1                          False                            False
# 2                          False                            False
# 3                          False                            False
# 6                          False                            False
# ...                          ...                              ...
# 2100                       False                            False
# 2101                       False                            False
# 2102                       False                            False
# 2103                       False                            False
# 2104                       False                            False
#
#       stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 6                            False                           False
# ...                            ...                             ...
# 2100                         False                           False
# 2101                         False                           False
# 2102                         False                           False
# 2103                         False                           False
# 2104                          True                           False
#
#       stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                          True                        False
# 6                          True                        False
# ...                         ...                          ...
# 2100                       True                        False
# 2101                       True                        False
# 2102                      False                         True
# 2103                      False                         True
# 2104                      False                        False
#
#       stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                              True                      False
# 1                              True                      False
# 2                              True                      False
# 3                             False                      False
# 6                             False                      False
# ...                             ...                        ...
# 2100                          False                      False
# 2101                          False                      False
# 2102                          False                      False
# 2103                          False                      False
# 2104                          False                       True
#
#       stadium_surface_FieldTurf  stadium_surface_Grass
# 0                         False                   True
# 1                         False                   True
# 2                         False                   True
# 3                         False                   True
# 6                          True                  False
# ...                         ...                    ...
# 2100                       True                  False
# 2101                       True                  False
# 2102                      False                   True
# 2103                      False                   True
# 2104                      False                   True
#
# [1582 rows x 69 columns]

# %%
# Defining y (target variable)
y_no_2023 = no_2023_encoded_training_data['fantasy_points_ppr']

# Defining X (features)
X_no_2023 = no_2023_encoded_training_data.drop(columns = 'fantasy_points_ppr')

# %%
no_2023_lr_model = LinearRegression()

# %%
# Training model without 2023 season data
no_2023_lr_model.fit(X_no_2023, y_no_2023)
# Out:
# LinearRegression()

# %%
no_2023_predictions = no_2023_lr_model.predict(X_no_2023)

# %%
no_2023_season_r2 = r2_score(y_no_2023, no_2023_predictions)
no_2023_season_r2
# Out:
# 0.9772149496403472

# %%
no_2023_season_mse = mean_squared_error(y_no_2023, no_2023_predictions)
no_2023_season_rmse = math.sqrt(no_2023_season_mse)
no_2023_season_rmse
# Out:
# 14.834569893029212

# %% [markdown]
# # Testing model with 2023 player stats using model without 2023 stats

# %%
# Adding new features to training data

test_2023_data = all_seasons_data.loc[all_seasons_data['season'] == 2023].copy()
test_2023_data.head()

test_2023_data['target_per_game'] = round((test_2023_data['targets']/test_2023_data['games']),2)
test_2023_data['carries_per_game'] = round((test_2023_data['carries']/test_2023_data['games']),2)
test_2023_data['team_off_snaps_per_game'] = round((test_2023_data['teams_offense_snaps']/test_2023_data['games']),2)
test_2023_data['off_snaps_per_game'] = round((test_2023_data['offense_snaps']/test_2023_data['games']),2)
test_2023_data['attempts_per_game'] = round((test_2023_data['attempts']/test_2023_data['games']),2)



test_2023_data.fillna(0, inplace=True)
new_features_training_data_2023 = test_2023_data
new_features_training_data_2023
# Out:
#                name team position  season  games  receptions  targets  \
# 4        A.J. Brown  PHI       WR    2023     17         106      158
# 5        A.T. Perry   NO       WR    2023      8          12       18
# 9       AJ McCarron  CIN       QB    2023      2           0        0
# 16      Aaron Jones   GB       RB    2023     11          30       43
# 27    Aaron Rodgers  NYJ       QB    2023      1           0        0
# ...             ...  ...      ...     ...    ...         ...      ...
# 2092    Zach Wilson  NYJ       QB    2023     12           0        0
# 2096      Zack Moss  IND       RB    2023     14          27       37
# 2098    Zamir White   LV       RB    2023     13          15       19
# 2099    Zay Flowers  BAL       WR    2023     16          77      108
# 2105      Zay Jones  JAX       WR    2023      9          34       64
#
#       receiving_yards  rec_ypg  receiving_tds  ...  overall  \
# 4              1456.0    85.65              7  ...     51.0
# 5               246.0    30.75              4  ...    195.0
# 9                 0.0     0.00              0  ...      0.0
# 16              233.0    21.18              1  ...    182.0
# 27                0.0     0.00              0  ...     24.0
# ...               ...      ...            ...  ...      ...
# 2092              0.0     0.00              0  ...      2.0
# 2096            192.0    13.71              2  ...     86.0
# 2098             98.0     7.54              0  ...    122.0
# 2099            858.0    53.62              5  ...     22.0
# 2105            321.0    35.67              2  ...     37.0
#
#                  stadium_name  stadium_weather_type  stadium_surface  \
# 4     Lincoln Financial Field                  cold            Grass
# 5     Mercedes-Benz Superdome                indoor        FieldTurf
# 9          Paul Brown Stadium                  cold        FieldTurf
# 16              Lambeau Field                  cold            Grass
# 27            MetLife Stadium                  cold        FieldTurf
# ...                       ...                   ...              ...
# 2092          MetLife Stadium                  cold        FieldTurf
# 2096        Lucas Oil Stadium                indoor        FieldTurf
# 2098        Allegiant Stadium                indoor            Grass
# 2099         M&T Bank Stadium              moderate        FieldTurf
# 2105          TIAA Bank Field                  warm            Grass
#
#       fantasy_points_ppr  target_per_game  carries_per_game  \
# 4                 289.60             9.29              0.00
# 5                  60.60             2.25              0.00
# 9                   0.76             0.00              0.00
# 16                134.90             3.91             12.91
# 27                  0.00             0.00              0.00
# ...                  ...              ...               ...
# 2092              119.94             0.00              3.00
# 2096              169.60             2.64             13.07
# 2098               73.90             1.46              8.00
# 2099              206.40             6.75              0.50
# 2105               78.10             7.11              0.00
#
#       team_off_snaps_per_game  off_snaps_per_game  attempts_per_game
# 4                       67.88               59.94               0.00
# 5                       64.88               39.88               0.00
# 9                        0.00                0.00               2.50
# 16                      65.82               32.18               0.00
# 27                      58.00                4.00               1.00
# ...                       ...                 ...                ...
# 2092                    62.25               57.33              30.67
# 2096                    68.36               37.93               0.00
# 2098                    61.77               17.46               0.00
# 2099                    67.56               56.56               0.00
# 2105                    72.78               52.78               0.00
#
# [524 rows x 46 columns]

# %%
test_2023_data_cleaned = new_features_training_data_2023.drop(columns = ['name', 'team', 'season', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions'])
test_2023_data_cleaned
# Out:
#      position  games  targets  rec_ypg    ypr  receiving_fumbles  \
# 4          WR     17      158    85.65  13.74                2.0
# 5          WR      8       18    30.75  20.50                0.0
# 9          QB      2        0     0.00   0.00                0.0
# 16         RB     11       43    21.18   7.77                1.0
# 27         QB      1        0     0.00   0.00                0.0
# ...       ...    ...      ...      ...    ...                ...
# 2092       QB     12        0     0.00   0.00                0.0
# 2096       RB     14       37    13.71   7.11                0.0
# 2098       RB     13       19     7.54   6.53                0.0
# 2099       WR     16      108    53.62  11.14                0.0
# 2105       WR      9       64    35.67   9.44                0.0
#
#       target_share  air_yards_share  carries  rush_ypg  ...  overall  \
# 4             0.30             0.42        0      0.00  ...     51.0
# 5             0.07             0.16        0      0.00  ...    195.0
# 9             0.00             0.00        0      0.00  ...      0.0
# 16            0.12            -0.02      142     59.64  ...    182.0
# 27            0.00             0.00        0      0.00  ...     24.0
# ...            ...              ...      ...       ...  ...      ...
# 2092          0.00             0.00       36     17.58  ...      2.0
# 2096          0.07            -0.01      183     56.71  ...     86.0
# 2098          0.04            -0.00      104     34.69  ...    122.0
# 2099          0.24             0.24        8      3.50  ...     22.0
# 2105          0.18             0.27        0      0.00  ...     37.0
#
#                  stadium_name  stadium_weather_type  stadium_surface  \
# 4     Lincoln Financial Field                  cold            Grass
# 5     Mercedes-Benz Superdome                indoor        FieldTurf
# 9          Paul Brown Stadium                  cold        FieldTurf
# 16              Lambeau Field                  cold            Grass
# 27            MetLife Stadium                  cold        FieldTurf
# ...                       ...                   ...              ...
# 2092          MetLife Stadium                  cold        FieldTurf
# 2096        Lucas Oil Stadium                indoor        FieldTurf
# 2098        Allegiant Stadium                indoor            Grass
# 2099         M&T Bank Stadium              moderate        FieldTurf
# 2105          TIAA Bank Field                  warm            Grass
#
#       fantasy_points_ppr  target_per_game  carries_per_game  \
# 4                 289.60             9.29              0.00
# 5                  60.60             2.25              0.00
# 9                   0.76             0.00              0.00
# 16                134.90             3.91             12.91
# 27                  0.00             0.00              0.00
# ...                  ...              ...               ...
# 2092              119.94             0.00              3.00
# 2096              169.60             2.64             13.07
# 2098               73.90             1.46              8.00
# 2099              206.40             6.75              0.50
# 2105               78.10             7.11              0.00
#
#       team_off_snaps_per_game  off_snaps_per_game  attempts_per_game
# 4                       67.88               59.94               0.00
# 5                       64.88               39.88               0.00
# 9                        0.00                0.00               2.50
# 16                      65.82               32.18               0.00
# 27                      58.00                4.00               1.00
# ...                       ...                 ...                ...
# 2092                    62.25               57.33              30.67
# 2096                    68.36               37.93               0.00
# 2098                    61.77               17.46               0.00
# 2099                    67.56               56.56               0.00
# 2105                    72.78               52.78               0.00
#
# [524 rows x 32 columns]

# %%
# Encoding categorical columns for model
encoded_2023_test_data = pd.get_dummies(test_2023_data_cleaned)
encoded_2023_test_data
# Out:
#       games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 4        17      158    85.65  13.74                2.0          0.30
# 5         8       18    30.75  20.50                0.0          0.07
# 9         2        0     0.00   0.00                0.0          0.00
# 16       11       43    21.18   7.77                1.0          0.12
# 27        1        0     0.00   0.00                0.0          0.00
# ...     ...      ...      ...    ...                ...           ...
# 2092     12        0     0.00   0.00                0.0          0.00
# 2096     14       37    13.71   7.11                0.0          0.07
# 2098     13       19     7.54   6.53                0.0          0.04
# 2099     16      108    53.62  11.14                0.0          0.24
# 2105      9       64    35.67   9.44                0.0          0.18
#
#       air_yards_share  carries  rush_ypg  rush_td_percentage  ...  \
# 4                0.42        0      0.00                0.00  ...
# 5                0.16        0      0.00                0.00  ...
# 9                0.00        0      0.00                0.00  ...
# 16              -0.02      142     59.64                0.01  ...
# 27               0.00        0      0.00                0.00  ...
# ...               ...      ...       ...                 ...  ...
# 2092             0.00       36     17.58                0.00  ...
# 2096            -0.01      183     56.71                0.03  ...
# 2098            -0.00      104     34.69                0.01  ...
# 2099             0.24        8      3.50                0.12  ...
# 2105             0.27        0      0.00                0.00  ...
#
#       stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 4                          False                            False
# 5                          False                            False
# 9                          False                            False
# 16                         False                            False
# 27                         False                            False
# ...                          ...                              ...
# 2092                       False                            False
# 2096                       False                            False
# 2098                       False                            False
# 2099                       False                            False
# 2105                       False                            False
#
#       stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 4                            False                           False
# 5                            False                           False
# 9                            False                           False
# 16                           False                           False
# 27                           False                           False
# ...                            ...                             ...
# 2092                         False                           False
# 2096                         False                           False
# 2098                         False                           False
# 2099                         False                           False
# 2105                          True                           False
#
#       stadium_weather_type_cold  stadium_weather_type_indoor  \
# 4                          True                        False
# 5                         False                         True
# 9                          True                        False
# 16                         True                        False
# 27                         True                        False
# ...                         ...                          ...
# 2092                       True                        False
# 2096                      False                         True
# 2098                      False                         True
# 2099                      False                        False
# 2105                      False                        False
#
#       stadium_weather_type_moderate  stadium_weather_type_warm  \
# 4                             False                      False
# 5                             False                      False
# 9                             False                      False
# 16                            False                      False
# 27                            False                      False
# ...                             ...                        ...
# 2092                          False                      False
# 2096                          False                      False
# 2098                          False                      False
# 2099                           True                      False
# 2105                          False                       True
#
#       stadium_surface_FieldTurf  stadium_surface_Grass
# 4                         False                   True
# 5                          True                  False
# 9                          True                  False
# 16                        False                   True
# 27                         True                  False
# ...                         ...                    ...
# 2092                       True                  False
# 2096                       True                  False
# 2098                      False                   True
# 2099                       True                  False
# 2105                      False                   True
#
# [524 rows x 69 columns]

# %%
# Defining y (target data)
y_just_2023 = encoded_2023_test_data['fantasy_points_ppr']

# Defining X (features)
X_just_2023 = encoded_2023_test_data.drop(columns = 'fantasy_points_ppr')

# %%
X_just_2023
# Out:
#       games  targets  rec_ypg    ypr  receiving_fumbles  target_share  \
# 4        17      158    85.65  13.74                2.0          0.30
# 5         8       18    30.75  20.50                0.0          0.07
# 9         2        0     0.00   0.00                0.0          0.00
# 16       11       43    21.18   7.77                1.0          0.12
# 27        1        0     0.00   0.00                0.0          0.00
# ...     ...      ...      ...    ...                ...           ...
# 2092     12        0     0.00   0.00                0.0          0.00
# 2096     14       37    13.71   7.11                0.0          0.07
# 2098     13       19     7.54   6.53                0.0          0.04
# 2099     16      108    53.62  11.14                0.0          0.24
# 2105      9       64    35.67   9.44                0.0          0.18
#
#       air_yards_share  carries  rush_ypg  rush_td_percentage  ...  \
# 4                0.42        0      0.00                0.00  ...
# 5                0.16        0      0.00                0.00  ...
# 9                0.00        0      0.00                0.00  ...
# 16              -0.02      142     59.64                0.01  ...
# 27               0.00        0      0.00                0.00  ...
# ...               ...      ...       ...                 ...  ...
# 2092             0.00       36     17.58                0.00  ...
# 2096            -0.01      183     56.71                0.03  ...
# 2098            -0.00      104     34.69                0.01  ...
# 2099             0.24        8      3.50                0.12  ...
# 2105             0.27        0      0.00                0.00  ...
#
#       stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 4                          False                            False
# 5                          False                            False
# 9                          False                            False
# 16                         False                            False
# 27                         False                            False
# ...                          ...                              ...
# 2092                       False                            False
# 2096                       False                            False
# 2098                       False                            False
# 2099                       False                            False
# 2105                       False                            False
#
#       stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 4                            False                           False
# 5                            False                           False
# 9                            False                           False
# 16                           False                           False
# 27                           False                           False
# ...                            ...                             ...
# 2092                         False                           False
# 2096                         False                           False
# 2098                         False                           False
# 2099                         False                           False
# 2105                          True                           False
#
#       stadium_weather_type_cold  stadium_weather_type_indoor  \
# 4                          True                        False
# 5                         False                         True
# 9                          True                        False
# 16                         True                        False
# 27                         True                        False
# ...                         ...                          ...
# 2092                       True                        False
# 2096                      False                         True
# 2098                      False                         True
# 2099                      False                        False
# 2105                      False                        False
#
#       stadium_weather_type_moderate  stadium_weather_type_warm  \
# 4                             False                      False
# 5                             False                      False
# 9                             False                      False
# 16                            False                      False
# 27                            False                      False
# ...                             ...                        ...
# 2092                          False                      False
# 2096                          False                      False
# 2098                          False                      False
# 2099                           True                      False
# 2105                          False                       True
#
#       stadium_surface_FieldTurf  stadium_surface_Grass
# 4                         False                   True
# 5                          True                  False
# 9                          True                  False
# 16                        False                   True
# 27                         True                  False
# ...                         ...                    ...
# 2092                       True                  False
# 2096                       True                  False
# 2098                      False                   True
# 2099                       True                  False
# 2105                      False                   True
#
# [524 rows x 68 columns]

# %%
test_2023_predictions = no_2023_lr_model.predict(X_just_2023)
test_2023_predictions
# Out:
# array([ 2.97883323e+02,  6.87666204e+01,  2.48868971e+00,  1.65378211e+02,
#        -1.77728368e+00,  2.30398902e+02,  5.37395753e+01,  1.25009670e+02,
#        -9.90748628e+00,  1.02658564e+02, -2.73709692e+00,  5.02877649e+01,
#         1.69442089e+02,  6.17371518e+01,  6.66837992e+01,  2.38039936e+02,
#         2.46441988e+02, -2.17956116e+01,  3.23185613e+01,  3.18963706e+02,
#         4.63128825e+01,  4.00085963e+01,  2.92567242e-02, -6.28064333e+00,
#         6.55892151e+01, -7.32024407e+00,  1.30730525e+02,  2.19994078e+02,
#         4.26087042e+01, -8.33822510e+00,  7.84463438e+01,  2.75428210e+02,
#         3.06018145e+01,  2.19165669e+01,  2.72934800e+02,  7.36161545e+00,
#         2.53622168e+01,  6.98026913e+01,  1.22760748e+01,  1.48656581e+02,
#         2.37754376e+02,  3.05847188e+01,  6.34594671e+01,  7.63797947e+01,
#         5.53032683e+01,  2.96437892e+02,  1.49448458e+01,  5.39440845e+01,
#        -2.70213886e+01,  1.87419602e+02,  8.54306500e+00,  2.76917204e+02,
#         2.45251764e+01,  1.88898466e+02,  1.81711656e+01,  2.63400535e+01,
#         2.59860982e+01,  2.65714142e+02,  1.74554194e+01,  1.10296289e+02,
#         5.00339368e+01,  2.28728423e+02,  3.42703145e+01, -8.81898824e+00,
#        -2.29002537e+01,  4.85089712e+01,  3.70863971e+02,  1.58391508e+01,
#         2.62650997e+01,  2.31926740e+00,  5.92149299e+01, -1.16731261e+00,
#         4.53863357e+01,  1.32581674e+02,  3.90897502e+01, -3.18020746e-01,
#         2.31533851e+02, -6.70461659e+00,  6.88667196e+01,  2.44070805e+02,
#         3.76082833e+01,  1.61049343e+02,  3.39911320e+02,  9.91160343e+01,
#         2.05868195e+02,  4.45235153e+00,  7.81759467e+01,  1.53393302e+01,
#         6.83837480e+01, -3.81867860e+00,  1.59131501e+02,  2.20148120e+01,
#         1.31249923e+00, -2.35676262e-01,  4.23813715e+01,  1.66319045e+02,
#         8.42309486e+00,  3.63237616e+01,  1.57410825e+02,  3.21916619e+01,
#         1.51835762e+02,  2.19856601e+02,  2.95393583e+01,  7.62310830e+01,
#         1.28346674e+01,  1.06042724e+02,  1.83110692e+01,  2.70468443e+02,
#         2.31218397e+02,  3.15161750e+02,  1.42060349e+02,  1.60345181e+02,
#         1.52041641e+02,  9.09070547e+01,  1.78900225e+01,  5.14223557e+00,
#         4.61603153e+01,  5.18446892e+01, -2.33073668e+00,  1.44750875e+02,
#         8.36408655e+01,  9.14237402e+00,  2.30701028e+01,  1.18728326e+02,
#         1.39275128e+01,  2.71184847e+02,  5.21786885e+01,  1.80786868e+02,
#         2.88567655e+01,  2.12111864e+02, -3.16407715e+01,  3.43575435e+01,
#         1.06251531e+01,  5.40276496e+01,  3.02947114e+00,  2.38901543e+02,
#         7.93626619e+01,  2.18511585e+02,  1.88748450e+01,  2.13579510e+02,
#         8.88719957e+01,  1.28578179e+02, -1.30072779e+00,  3.77717127e+01,
#         2.55022231e+02,  3.96559425e+01,  1.29683929e+01,  2.41806690e+02,
#         7.64574500e+01,  2.06181616e+02,  7.89048655e+00,  3.54495271e+01,
#         3.07000408e+00,  1.90364873e+02, -1.11217837e+01,  1.48563320e+02,
#         7.87936055e+01,  5.94098982e+00,  1.19706583e+02,  1.60117830e+01,
#         1.87422079e+02,  4.27397420e+01,  4.87947792e+01,  7.34357316e+01,
#         2.79746249e+01,  7.58456571e+01,  9.22498749e+00, -7.66326767e+00,
#         3.94711599e+01,  4.61915554e+01,  1.57870647e+02,  2.35818941e+01,
#         7.53100610e+01,  3.07110363e+00,  2.66854503e+00,  5.13464978e+00,
#         3.29041132e+00,  2.33476341e+02, -5.92518144e+00,  1.97084414e+02,
#         5.01032769e+01,  1.52906388e+02,  2.14158760e+02,  2.48650375e+02,
#         4.73681887e-01,  2.56392802e+02,  2.00471290e+01,  1.92369516e+02,
#         2.09822361e+02,  1.11836676e+02, -1.70514308e+00,  1.95182076e+01,
#         6.39845867e+01, -4.58533647e+00,  7.62712629e+00,  1.49239102e+02,
#         3.94328925e+01,  3.87296907e+01,  1.00665643e+02,  1.25011874e+01,
#         4.71952970e+01,  7.04011576e-02,  2.95604366e+01,  3.34432427e+01,
#        -6.82886370e+00,  5.44512788e+01,  9.49578980e+01,  2.16890678e+01,
#         2.11113457e+01,  2.20412518e+02,  7.11256114e+00, -1.22177279e+01,
#         2.61567046e+02,  4.49020380e+00,  5.24521844e+01,  1.25606510e+02,
#         2.29713166e+02,  7.41491389e+01,  1.52323097e+02,  1.78947301e+02,
#         1.92211494e+02,  1.01049426e+02,  2.43568031e+01,  2.14708459e+01,
#         3.31582370e+02, -1.12216952e+01,  1.29398596e+01,  5.71656608e+01,
#         5.52897832e+01,  7.84693324e+01,  4.25273759e+01,  1.65920745e+01,
#         1.99340647e+02,  2.60851278e+02,  5.29299613e+00, -2.44331210e+01,
#         7.62043694e+01,  3.60676015e+01,  2.91086835e+02,  1.78469369e+01,
#         1.19875608e+01, -1.59086152e+01,  9.40498324e+00,  4.85807594e+01,
#         1.97766061e+02,  1.61457330e+02,  1.97005330e+02,  2.07353378e+02,
#         2.17989047e+02,  5.35466445e+00,  2.84160334e+01,  6.95521063e+01,
#         2.20222243e+02,  1.42864339e+02, -3.49258488e+00,  7.28214537e+01,
#         6.69053007e+01,  1.42910385e+02,  1.11510037e+02,  2.66057759e+02,
#         3.37612393e+01,  6.41946033e+00,  4.53402558e+01,  1.02121901e+02,
#         1.48110354e+02,  8.85238479e+00, -2.11357161e+01,  1.25582962e+02,
#         1.99155089e+02,  3.31286417e+01,  3.02171927e+02,  3.19677491e+01,
#        -1.38829363e+01,  3.57227383e+02,  1.68261418e+02,  2.01281707e+02,
#         5.22181766e+01,  1.26976819e+02,  1.18724716e+02,  3.02338677e+01,
#         6.44307896e+01,  7.89494175e+01,  2.38718075e+01,  6.08062900e+01,
#         4.23305364e+00,  3.53269524e+01,  1.10411604e+02,  2.29183764e+02,
#         2.18959216e+02,  2.32732997e+02,  9.43055314e+01,  9.76286610e+00,
#         9.91316714e+01, -6.02408474e+00,  1.25741517e+02,  6.13387146e+01,
#         9.19708587e+01,  1.00545845e+02, -2.23323787e+01,  9.02695664e+01,
#        -3.60539057e+01,  2.80841317e+02,  2.53115303e+01,  4.85431684e+01,
#         9.64310133e+01,  5.03127448e+00,  1.04128326e+02,  2.06889299e+02,
#         1.32711633e+02, -5.11989950e+00,  2.27299338e+00,  1.91927994e+01,
#        -5.74513376e+00,  3.19184599e+01,  1.23319478e+02,  1.08997915e+02,
#         1.46215699e+02,  7.02729761e+01,  6.53897603e-01,  2.96736573e+00,
#         4.23890296e+01,  1.42774318e+02,  2.02860531e+00,  8.12433340e+01,
#         1.40896495e+02,  2.29700144e+02,  7.86002741e+00,  3.31822025e+02,
#        -2.73376585e+01,  7.95264444e+01,  2.14204240e+01,  2.64475588e+01,
#         3.80910639e+00,  3.97540184e+01,  1.21846907e+02,  7.82731783e+00,
#         1.86327991e+01,  2.54552145e+01,  8.37579027e+01,  3.38754819e+01,
#         2.66096252e+01,  1.33417070e+02,  4.14782323e+01,  3.98672854e+01,
#        -1.43801631e+01,  3.04181858e+01,  1.87367559e+01,  3.06140128e+01,
#         1.29558823e+02,  6.68669628e+01,  1.42865587e+02,  5.04140323e+00,
#        -8.02648505e+00,  6.05179192e+01,  1.14735773e+01,  6.18705444e+01,
#        -1.76661370e+01,  4.73452828e+01,  2.54284390e+02,  2.80846171e+01,
#         1.12882584e+01,  3.06961708e+01,  8.97172554e+01,  6.17305782e+01,
#         2.59219769e+02,  1.02581582e+02,  1.11663005e+02,  2.57161151e+02,
#         6.40366822e+01, -2.18184494e+01,  1.24657010e+01,  8.23712332e+01,
#         1.26077630e+00,  1.18765380e+02,  3.35571038e+01,  1.68829053e+01,
#         4.73490868e+01,  2.24348922e+01,  2.14104371e+02,  2.26605736e+00,
#        -1.35936555e+01,  8.31328364e+01,  5.21221611e+01,  1.07696377e+02,
#         2.25139585e+01,  3.76472643e-01,  8.67027313e+01,  2.50500259e+02,
#         1.19687977e+02,  8.77195348e+01,  7.70488073e+01,  4.04502913e+01,
#         3.01769360e+01,  2.05692801e+01,  7.36138325e+01,  3.17880102e+02,
#         3.84518907e+01,  8.97314715e+00,  4.25591884e+00,  4.19986162e+01,
#        -2.28751260e+01,  4.79011806e+01,  3.18079599e+02,  1.03923689e+02,
#         2.91143590e+01,  4.56873828e+01,  2.86817310e+02,  8.03936033e+00,
#         1.96407909e+02,  1.53021268e+00,  1.79513415e+01, -8.02918730e-01,
#         2.05517317e+02,  1.53365358e+02,  8.33749314e+01,  3.02661141e+01,
#         1.60880240e+02,  2.79598012e+01,  8.65008049e+01,  3.19596509e+01,
#         3.18075251e+01,  1.64175059e+01,  1.01832500e+02, -1.55268944e+01,
#         1.67379037e+02,  1.15179984e+02,  4.68349894e+01,  2.16913412e+01,
#         1.02423326e+02, -4.50359669e+00,  3.81737092e+01,  2.26627034e+02,
#         1.00842397e+02,  2.57750177e+01,  1.83815234e+01,  2.63789052e+02,
#         2.07826526e+02,  1.23817091e+02,  1.59198768e+01,  2.34596297e+02,
#         3.81872559e+01,  1.84781214e+01, -1.69327239e+00, -1.17618127e+01,
#        -4.72999108e+00,  7.49522667e+01,  6.27154660e+01,  2.75416128e+02,
#         2.38729784e+01,  1.91930773e+01,  1.16468344e+01,  3.80384626e+01,
#         2.20501866e+02,  2.02541900e+01,  1.66034891e+02,  8.52257203e+01,
#         6.93279216e+01,  1.35127313e+02,  2.94210014e+00, -6.68424375e+00,
#         1.36012328e+02,  2.55051961e+01,  2.16620129e+02,  1.36887205e+01,
#         7.92314466e+01,  5.11569231e+01,  6.45858510e+00,  2.50740111e+02,
#         2.80488685e+02, -7.55804714e+00,  2.23183992e+02,  1.62001368e+01,
#         6.27662994e+01,  2.88485931e+01, -2.78039607e+00,  6.49250757e+01,
#        -1.14242313e+01,  2.85977453e+02, -2.25934407e+00,  1.85437400e+02,
#         9.95830352e+01,  2.29416037e+01,  4.24152670e+01, -1.19416177e+01,
#         2.91944261e+02,  1.05827491e+00,  8.78630597e+01,  1.14130959e+02,
#         1.07130153e+02,  3.62483927e+01,  6.74510442e+00,  1.74189171e+02,
#        -5.76754974e+00,  1.42160953e+02,  1.59902738e+02,  1.38229350e+02,
#         1.92414503e+01,  1.14529380e+02,  2.14249778e+01,  1.90391340e+01,
#         2.08044009e+02,  3.44466840e+01,  2.36200528e+01,  3.59484979e+02,
#        -2.21355696e+00,  1.05729784e+02,  4.48060924e+01,  1.40701392e+01,
#         4.04552821e+00,  1.33993126e+02,  4.84561620e+01,  1.11917987e+02,
#         4.09202358e+01, -5.68720834e+00,  5.87656561e+01,  2.27944900e+01,
#         1.33202116e+02,  4.03973108e+00,  5.14619075e+00,  1.43486818e+02,
#         1.70381185e+02,  8.33435419e+01,  2.02294851e+02,  6.61035705e+01])

# %%
fantasy_2023_predictions = test_2023_data.copy()

# Creating a new column that holds model predictions
fantasy_2023_predictions['fantasy_2023_score_prediction'] = test_2023_predictions

# Rounding the fantasy score predictions to 2 decimal places
fantasy_2023_predictions['fantasy_2023_score_prediction'] = round(fantasy_2023_predictions['fantasy_2023_score_prediction'], 2)

# Chosing the columns that are shown in the dataframe
fantasy_2023_predictions = fantasy_2023_predictions[['name', 'team', 'position', 'fantasy_2023_score_prediction']]

# Pulling in a new column that has the actual fantasy score for each player from 2023
fantasy_2023_predictions['actual_fantasy_score'] = test_2023_data['fantasy_points_ppr']

fantasy_2023_predictions
# Out:
#                name team position  fantasy_2023_score_prediction  \
# 4        A.J. Brown  PHI       WR                         297.88
# 5        A.T. Perry   NO       WR                          68.77
# 9       AJ McCarron  CIN       QB                           2.49
# 16      Aaron Jones   GB       RB                         165.38
# 27    Aaron Rodgers  NYJ       QB                          -1.78
# ...             ...  ...      ...                            ...
# 2092    Zach Wilson  NYJ       QB                         143.49
# 2096      Zack Moss  IND       RB                         170.38
# 2098    Zamir White   LV       RB                          83.34
# 2099    Zay Flowers  BAL       WR                         202.29
# 2105      Zay Jones  JAX       WR                          66.10
#
#       actual_fantasy_score
# 4                   289.60
# 5                    60.60
# 9                     0.76
# 16                  134.90
# 27                    0.00
# ...                    ...
# 2092                119.94
# 2096                169.60
# 2098                 73.90
# 2099                206.40
# 2105                 78.10
#
# [524 rows x 5 columns]

# %%
# Calculating RMSE for model based on predicting 2023 fantasy scores compared to actual 2023 fantasy scores
mse_2023 = mean_squared_error(fantasy_2023_predictions['actual_fantasy_score'], fantasy_2023_predictions['fantasy_2023_score_prediction'])
rmse_2023 = math.sqrt(mse_2023)
rmse_2023
# Out:
# 14.229830865136156

# %%
# Calculating R2 for model based on predicting 2023 fantasy scores compared to actual 2023 fantasy scores

r2_2023 = r2_score(fantasy_2023_predictions['actual_fantasy_score'], fantasy_2023_predictions['fantasy_2023_score_prediction'])
r2_2023
# Out:
# 0.974004203717691

# %% [markdown]
# # Comparison of Model Accuracy vs. just assuming 2022 data would repeat in 2023

# %%
# We want to compare the results the model got to the results we would get if we just assumed
# that the 2022 results would continue in 2023.
# We can start by copying our 2023 prediction info into a new DataFrame

just_guess_repeating = fantasy_2023_predictions.copy()

# %%
# We will need a second table with just the 2022 actual results

just_2022 = all_seasons_data.loc[all_seasons_data['season'] == 2022].copy()

# %%
actual_2022 = just_2022.drop(columns = ['season', 'games', 'receptions', 'targets',
                                        'receiving_yards', 'rec_ypg', 'receiving_tds', 'ypr',
                                        'receiving_fumbles', 'receiving_2pt_conversions', 'target_share',
                                        'air_yards_share', 'carries', 'rushing_yards', 'rush_ypg',
                                        'rushing_tds', 'rush_td_percentage', 'rushing_fumbles',
                                        'rushing_2pt_conversions', 'completions', 'attempts', 'comp_percentage', 
                                        'passing_yards', 'pass_ypg', 'passing_tds', 'passing_2pt_conversions',
                                        'td_percentage', 'interceptions', 'sacks', 'sack_fumbles',
                                        'offense_snaps', 'teams_offense_snaps', 'round', 'overall', 
                                        'stadium_name', 'stadium_weather_type', 'stadium_surface'])
actual_2022.rename(columns={'fantasy_points_ppr': 'actual_fantasy_score_2022'}, inplace=True)
actual_2022
# Out:
#                name team position  actual_fantasy_score_2022
# 3        A.J. Brown  PHI       WR                     299.60
# 15      Aaron Jones   GB       RB                     248.60
# 26    Aaron Rodgers   GB       QB                     239.20
# 36     Adam Thielen  MIN       WR                     180.00
# 40    Adam Trautman   NO       TE                      44.70
# ...             ...  ...      ...                        ...
# 2088    Zach Pascal  PHI       WR                      36.00
# 2091    Zach Wilson  NYJ       QB                      98.92
# 2095      Zack Moss  IND       RB                      47.70
# 2097    Zamir White   LV       RB                       7.00
# 2104      Zay Jones  JAX       WR                     198.10
#
# [390 rows x 4 columns]

# %%
# Now we need to merge the two dataframes. 

fantasy_merged = pd.merge(just_guess_repeating, actual_2022, on='name')
fantasy_merged.drop(columns = ['team_y', 'position_y'], inplace=True)
fantasy_merged.rename(columns={'team_x': 'team','position_x': 'position', 
                               'actual_fantasy_score': 'actual_fantasy_score_2023'}, inplace=True)

fantasy_merged
# Out:
#               name team position  fantasy_2023_score_prediction  \
# 0       A.J. Brown  PHI       WR                         297.88
# 1      Aaron Jones   GB       RB                         165.38
# 2    Aaron Rodgers  NYJ       QB                          -1.78
# 3     Adam Thielen  CAR       WR                         230.40
# 4    Adam Trautman  DEN       TE                          53.74
# ..             ...  ...      ...                            ...
# 385    Zach Pascal  ARI       WR                           5.15
# 386    Zach Wilson  NYJ       QB                         143.49
# 387      Zack Moss  IND       RB                         170.38
# 388    Zamir White   LV       RB                          83.34
# 389      Zay Jones  JAX       WR                          66.10
#
#      actual_fantasy_score_2023  actual_fantasy_score_2022
# 0                       289.60                     299.60
# 1                       134.90                     248.60
# 2                         0.00                     239.20
# 3                       231.00                     180.00
# 4                        60.40                      44.70
# ..                         ...                        ...
# 385                       5.90                      36.00
# 386                     119.94                      98.92
# 387                     169.60                      47.70
# 388                      73.90                       7.00
# 389                      78.10                     198.10
#
# [390 rows x 6 columns]

# %%
# Now we can compare the RMS error of the 2022 final scores vs. the actual 2023 data to see whether
# the model is giving more accurate results than just assuming next year will be the same as last year...

mse_assume = mean_squared_error(fantasy_merged['actual_fantasy_score_2023'], fantasy_merged['actual_fantasy_score_2022'])
rmse_assume = math.sqrt(mse_assume)
rmse_assume
# Out:
# 71.00374769451727

# %%
# The average error of '71' points is quite a bit worse than the results from our machine learning model!
# That is exactly what we were hoping.

# %% [markdown]
# # Predictions for 2024

# %%
# Adding new features to match training data
prediction_data = pd.read_csv('predicting_data.csv')

prediction_data['target_per_game'] = round((prediction_data['targets']/prediction_data['games']),2)
prediction_data['carries_per_game'] = round((prediction_data['carries']/prediction_data['games']),2)
prediction_data['team_off_snaps_per_game'] = round((prediction_data['teams_offense_snaps']/prediction_data['games']),2)
prediction_data['off_snaps_per_game'] = round((prediction_data['offense_snaps']/prediction_data['games']),2)
prediction_data['attempts_per_game'] = round((prediction_data['attempts']/prediction_data['games']),2)



prediction_data.fillna(0, inplace=True)
new_features_2024_prediction_data = prediction_data
new_features_2024_prediction_data
# Out:
#               name team position      games  receptions     targets  \
# 0       A.J. Brown  PHI       WR  15.400000   75.800000  119.600000
# 1       A.T. Perry   NO       WR   8.000000   12.000000   18.000000
# 2      AJ McCarron  CIN       QB   2.000000    0.000000    0.000000
# 3      Aaron Jones   GB       RB  13.571429   38.857143   52.000000
# 4    Aaron Rodgers  NYJ       QB  13.272727    0.181818    0.181818
# ..             ...  ...      ...        ...         ...         ...
# 519    Zach Wilson  NYJ       QB  11.333333    0.333333    0.666667
# 520      Zack Moss  IND       RB  12.000000   17.000000   23.000000
# 521    Zamir White   LV       RB  12.000000    7.500000    9.500000
# 522    Zay Flowers  BAL       WR  16.000000   77.000000  108.000000
# 523      Zay Jones  JAX       WR  13.500000   43.333333   75.166667
#
#      receiving_yards    rec_ypg  receiving_tds        ypr  ...  round  \
# 0        1189.400000  76.596000       8.400000  16.020000  ...    2.0
# 1         246.000000  30.750000       4.000000  20.500000  ...    6.0
# 2           0.000000   0.000000       0.000000   0.000000  ...    0.0
# 3         296.571429  20.691429       2.571429   7.080000  ...    5.0
# 4          -0.909091  -0.057273       0.000000  -0.909091  ...    1.0
# ..               ...        ...            ...        ...  ...    ...
# 519         0.666667   0.073333       0.333333   0.666667  ...    1.0
# 520       124.000000   9.417500       1.000000   6.367500  ...    3.0
# 521        49.000000   3.770000       0.000000   3.265000  ...    4.0
# 522       858.000000  53.620000       5.000000  11.140000  ...    1.0
# 523       468.666667  33.471667       3.000000  10.906667  ...    2.0
#
#      overall             stadium_name  stadium_weather_type  stadium_surface  \
# 0       51.0  Lincoln Financial Field                  cold            Grass
# 1      195.0  Mercedes-Benz Superdome                indoor        FieldTurf
# 2        0.0       Paul Brown Stadium                  cold        FieldTurf
# 3      182.0            Lambeau Field                  cold            Grass
# 4       24.0          MetLife Stadium                  cold        FieldTurf
# ..       ...                      ...                   ...              ...
# 519      2.0          MetLife Stadium                  cold        FieldTurf
# 520     86.0        Lucas Oil Stadium                indoor        FieldTurf
# 521    122.0        Allegiant Stadium                indoor            Grass
# 522     22.0         M&T Bank Stadium              moderate        FieldTurf
# 523     37.0          TIAA Bank Field                  warm            Grass
#
#      target_per_game  carries_per_game  team_off_snaps_per_game  \
# 0               7.77              0.06                    67.03
# 1               2.25              0.00                    64.88
# 2               0.00              0.62                     0.00
# 3               3.83             12.39                    65.60
# 4               0.01              2.85                    67.14
# ..               ...               ...                      ...
# 519             0.06              2.74                    60.88
# 520             1.92              9.73                    67.94
# 521             0.79              5.04                    63.04
# 522             6.75              0.50                    67.56
# 523             5.57              0.09                    68.38
#
#      off_snaps_per_game  attempts_per_game
# 0                 52.79               0.03
# 1                 39.88               0.00
# 2                  0.00               7.12
# 3                 35.54               0.00
# 4                 63.86              34.22
# ..                  ...                ...
# 519               56.85              29.21
# 520               31.04               0.00
# 521               10.92               0.00
# 522               56.56               0.00
# 523               48.88               0.02
#
# [524 rows x 44 columns]

# %%
prediction_2024_data_cleaned = new_features_2024_prediction_data.drop(columns = ['name', 'team', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_2pt_conversions', 
                            'rushing_yards', 'rushing_tds', 'rushing_2pt_conversions', 'completions', 'passing_yards', 
                            'passing_tds', 'interceptions'])
prediction_2024_data_cleaned.head()
# Out:
#   position      games     targets    rec_ypg        ypr  receiving_fumbles  \
# 0       WR  15.400000  119.600000  76.596000  16.020000           1.400000
# 1       WR   8.000000   18.000000  30.750000  20.500000           0.000000
# 2       QB   2.000000    0.000000   0.000000   0.000000           0.000000
# 3       RB  13.571429   52.000000  20.691429   7.080000           0.857143
# 4       QB  13.272727    0.181818  -0.057273  -0.909091           0.000000
#
#    target_share  air_yards_share     carries   rush_ypg  ...  round  overall  \
# 0      0.268000         0.384000    1.000000   0.904000  ...    2.0     51.0
# 1      0.070000         0.160000    0.000000   0.000000  ...    6.0    195.0
# 2      0.000000         0.000000    1.250000   4.875000  ...    0.0      0.0
# 3      0.115714         0.007143  168.142857  61.561429  ...    5.0    182.0
# 4      0.000000         0.000000   37.818182  12.918182  ...    1.0     24.0
#
#               stadium_name  stadium_weather_type  stadium_surface  \
# 0  Lincoln Financial Field                  cold            Grass
# 1  Mercedes-Benz Superdome                indoor        FieldTurf
# 2       Paul Brown Stadium                  cold        FieldTurf
# 3            Lambeau Field                  cold            Grass
# 4          MetLife Stadium                  cold        FieldTurf
#
#    target_per_game  carries_per_game  team_off_snaps_per_game  \
# 0             7.77              0.06                    67.03
# 1             2.25              0.00                    64.88
# 2             0.00              0.62                     0.00
# 3             3.83             12.39                    65.60
# 4             0.01              2.85                    67.14
#
#    off_snaps_per_game  attempts_per_game
# 0               52.79               0.03
# 1               39.88               0.00
# 2                0.00               7.12
# 3               35.54               0.00
# 4               63.86              34.22
#
# [5 rows x 31 columns]

# %%
prediction_2024_data_cleaned.columns
# Out:
# Index(['position', 'games', 'targets', 'rec_ypg', 'ypr', 'receiving_fumbles',
#        'target_share', 'air_yards_share', 'carries', 'rush_ypg',
#        'rush_td_percentage', 'rushing_fumbles', 'attempts', 'comp_percentage',
#        'pass_ypg', 'passing_2pt_conversions', 'td_percentage', 'sacks',
#        'sack_fumbles', 'offense_snaps', 'teams_offense_snaps', 'round',
#        'overall', 'stadium_name', 'stadium_weather_type', 'stadium_surface',
#        'target_per_game', 'carries_per_game', 'team_off_snaps_per_game',
#        'off_snaps_per_game', 'attempts_per_game'],
#       dtype='object')

# %%
# Encoding categorical columns for model
encoded_prediction_2024_data = pd.get_dummies(prediction_2024_data_cleaned)
encoded_prediction_2024_data
# Out:
#          games     targets    rec_ypg        ypr  receiving_fumbles  \
# 0    15.400000  119.600000  76.596000  16.020000           1.400000
# 1     8.000000   18.000000  30.750000  20.500000           0.000000
# 2     2.000000    0.000000   0.000000   0.000000           0.000000
# 3    13.571429   52.000000  20.691429   7.080000           0.857143
# 4    13.272727    0.181818  -0.057273  -0.909091           0.000000
# ..         ...         ...        ...        ...                ...
# 519  11.333333    0.666667   0.073333   0.666667           0.000000
# 520  12.000000   23.000000   9.417500   6.367500           0.500000
# 521  12.000000    9.500000   3.770000   3.265000           0.000000
# 522  16.000000  108.000000  53.620000  11.140000           0.000000
# 523  13.500000   75.166667  33.471667  10.906667           0.333333
#
#      target_share  air_yards_share     carries   rush_ypg  rush_td_percentage  \
# 0        0.268000         0.384000    1.000000   0.904000            0.066000
# 1        0.070000         0.160000    0.000000   0.000000            0.000000
# 2        0.000000         0.000000    1.250000   4.875000            0.050000
# 3        0.115714         0.007143  168.142857  61.561429            0.037143
# 4        0.000000         0.000000   37.818182  12.918182            0.036364
# ..            ...              ...         ...        ...                 ...
# 519      0.000000         0.003333   31.000000  14.380000            0.060000
# 520      0.050000         0.002500  116.750000  41.467500            0.030000
# 521      0.020000         0.000000   60.500000  20.525000            0.005000
# 522      0.240000         0.240000    8.000000   3.500000            0.120000
# 523      0.163333         0.225000    1.166667   0.220000            0.000000
#
#      ...  stadium_name_Soldier Field  stadium_name_State Farm Stadium  \
# 0    ...                       False                            False
# 1    ...                       False                            False
# 2    ...                       False                            False
# 3    ...                       False                            False
# 4    ...                       False                            False
# ..   ...                         ...                              ...
# 519  ...                       False                            False
# 520  ...                       False                            False
# 521  ...                       False                            False
# 522  ...                       False                            False
# 523  ...                       False                            False
#
#      stadium_name_TIAA Bank Field  stadium_name_U.S. Bank Stadium  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# ..                            ...                             ...
# 519                         False                           False
# 520                         False                           False
# 521                         False                           False
# 522                         False                           False
# 523                          True                           False
#
#      stadium_weather_type_cold  stadium_weather_type_indoor  \
# 0                         True                        False
# 1                        False                         True
# 2                         True                        False
# 3                         True                        False
# 4                         True                        False
# ..                         ...                          ...
# 519                       True                        False
# 520                      False                         True
# 521                      False                         True
# 522                      False                        False
# 523                      False                        False
#
#      stadium_weather_type_moderate  stadium_weather_type_warm  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# ..                             ...                        ...
# 519                          False                      False
# 520                          False                      False
# 521                          False                      False
# 522                           True                      False
# 523                          False                       True
#
#      stadium_surface_FieldTurf  stadium_surface_Grass
# 0                        False                   True
# 1                         True                  False
# 2                         True                  False
# 3                        False                   True
# 4                         True                  False
# ..                         ...                    ...
# 519                       True                  False
# 520                       True                  False
# 521                      False                   True
# 522                       True                  False
# 523                      False                   True
#
# [524 rows x 68 columns]

# %%
predictions_2024 = lr_model.predict(encoded_prediction_2024_data)

predictions_2024
# Out:
# array([ 2.41000415e+02,  6.20371682e+01,  1.21633448e+01,  2.02398813e+02,
#         2.13585851e+02,  1.55531873e+02,  4.77596799e+01,  1.23211987e+02,
#         2.59627436e+01,  1.11239160e+02,  6.11265341e+00,  3.99249369e+01,
#         1.06778670e+02,  8.09165960e+01,  1.42805078e+02,  2.74514058e+02,
#         2.20789431e+02,  1.19486117e+00,  5.29124289e+01,  2.69449967e+02,
#         4.21588935e+01,  3.58778173e+01,  1.75794680e+02,  8.17058183e+00,
#         6.99294042e+01, -3.93421502e+00,  1.82448951e+02,  2.28250156e+02,
#         1.02694044e+02, -4.66430709e+00,  7.09539019e+01,  2.04526040e+02,
#         2.45774745e+01,  4.83021704e+01,  2.71405700e+02,  1.74232167e+01,
#         2.08096988e+01,  6.78879239e+01,  6.99347804e+01,  1.98711016e+02,
#         2.00930869e+02,  2.85537823e+01,  2.88998278e+01,  3.46208078e+01,
#         6.88225807e+01,  1.99979463e+02,  1.23006337e+01,  4.20314312e+01,
#         5.87987509e+00,  1.64191700e+02,  1.04764986e+01,  1.76533644e+02,
#         4.24182738e+01,  1.84904815e+02,  1.32010415e+01,  4.88221613e+01,
#         2.28136945e+01,  2.60110826e+02,  4.69172194e+01,  1.02877136e+02,
#         4.95214741e+01,  1.86461513e+02,  5.58808358e+01,  1.92380721e+02,
#         4.07701377e+01,  4.98318896e+01,  2.77576011e+02,  1.68906967e+01,
#         5.23432483e+01,  9.40678396e-01,  5.91144230e+01,  8.41928057e+01,
#         8.93409702e+01,  1.11805976e+02,  6.60799413e+01,  1.74154106e+01,
#         2.06793686e+02,  5.85707863e+00,  4.62327893e+01,  2.29028792e+02,
#         3.92179062e+01,  1.71289527e+02,  2.60971792e+02,  1.22666021e+02,
#         1.41958789e+02,  2.55357357e+00,  1.21972669e+02,  1.60317476e+01,
#         3.98839681e+01, -2.07291417e-01,  1.20319667e+02,  4.76904061e+00,
#         1.43202772e+01, -2.30341454e+00,  4.01546574e+01,  2.20091219e+02,
#         1.29948835e+01,  1.25908627e+02,  1.45604282e+02,  2.41299194e+01,
#         1.13011008e+02,  1.93660999e+02,  3.32175324e+01,  5.63428011e+01,
#         1.73301197e+01,  1.04137684e+02,  6.58748012e+00,  2.31093559e+02,
#         2.43088296e+02,  2.66979886e+02,  1.34591163e+02,  1.61376991e+02,
#         9.40488467e+01,  1.40510222e+02,  6.40971884e+01,  5.01616105e+01,
#         6.38385265e+01,  1.82427035e+02,  3.86951524e+01,  1.31879968e+02,
#         1.43487182e+02,  1.02785616e+01,  8.03555952e+01,  1.21199257e+02,
#         2.86809459e+00,  2.33905320e+02,  5.04465198e+01,  2.10669689e+02,
#         6.71603232e+01,  1.06765038e+02, -2.90964299e+01,  3.47814569e+01,
#         9.44953414e+01,  9.70048434e+01,  5.05706800e+01,  2.43388605e+02,
#         1.29562054e+02,  2.21826996e+02,  4.93284086e+01,  1.96972596e+02,
#         8.25662285e+01,  1.29406739e+02,  1.36472546e+00,  2.00392856e+01,
#         2.59046135e+02,  3.88925296e+01,  2.12596424e+01,  2.19485486e+02,
#         2.06830019e+02,  1.20920282e+02,  8.80568687e+00,  3.14815196e+01,
#         5.98338189e+01,  1.82954673e+02,  9.04008487e+00,  2.01138907e+02,
#         5.31300194e+01,  8.00284252e+01,  1.16096644e+02,  1.35757512e+01,
#         1.89588868e+02,  7.75897254e+01,  2.41089919e+01,  4.26655842e+01,
#         2.59952662e+01, -4.89064899e+01,  1.11856444e+01, -7.69133865e+00,
#         3.96562345e+01,  8.67993146e+01,  1.30004466e+02,  2.21981341e+01,
#         7.52954611e+01,  3.06379434e+01,  2.15227769e+00,  1.01085338e+01,
#         2.83679594e+00,  1.57954898e+02, -7.11740822e+00,  2.55786759e+02,
#         6.47213336e+01,  1.67147055e+02,  1.16697712e+02,  2.45327657e+02,
#         2.05718997e+00,  6.56787394e+01,  2.12803167e+01,  1.87577095e+02,
#         1.86150992e+02,  1.02841214e+02,  3.94705693e+00,  1.76717438e+01,
#         5.11553049e+01,  2.12751194e+01,  5.97452131e+00,  1.14815910e+02,
#         5.44396256e+01,  6.79331747e+01,  1.24122090e+02,  1.25170405e+01,
#         1.16605197e+02,  3.22819074e+01,  4.30522898e+01,  6.38296203e+01,
#        -5.55875908e+00,  7.18455524e+01,  9.89488037e+01,  5.40958768e+01,
#         1.17214775e+01,  1.85070601e+02,  5.58164342e+00,  8.38045754e+01,
#         2.61091977e+02,  1.30131832e+01,  6.96677772e+01,  1.18030676e+02,
#         2.31888000e+02,  7.58428735e+01,  1.54176650e+02,  1.04837517e+02,
#         1.55455926e+02,  1.01834670e+02,  2.55957108e+01,  3.36108443e+01,
#         2.68009588e+02,  2.07948246e+01,  4.93973298e+01,  1.76583169e+01,
#         5.65325038e+01,  1.35929364e+02,  5.36961164e+01,  1.40102773e+02,
#         1.70464020e+02,  1.87628168e+02,  2.23412744e+01,  5.62695819e+00,
#         3.71794233e+01,  1.11003629e+02,  2.34661758e+02,  1.14654175e+01,
#         3.93257290e+01, -1.54043209e+01,  9.14139293e+00,  6.53298933e+01,
#         1.50123472e+02,  1.59750919e+02,  1.93083416e+02,  2.38528638e+02,
#         1.58350586e+02,  6.78362745e+01,  5.58948068e+00,  1.17822919e+02,
#         6.31161258e+01,  1.52220461e+02,  1.80541227e+01,  7.97182815e+01,
#         1.38092176e+02,  2.32614536e+02,  1.03871969e+02,  2.22908925e+02,
#         3.83901390e+01,  8.10864272e+00,  1.54691052e+01,  9.96359940e+01,
#         2.20012402e+02,  1.94054448e+01,  1.73714250e+01,  8.16295607e+01,
#         1.93725509e+02,  7.12441550e+01,  6.27840689e+01,  3.82160813e+01,
#        -1.59050625e+01,  3.18598319e+02,  1.65649066e+02,  2.48049814e+02,
#         2.01642055e+01,  1.32627018e+02,  8.68866589e+01,  2.45817253e+01,
#         1.12070564e+01,  6.30228280e+01,  2.65918382e+01,  1.50160877e+02,
#         9.77208207e+00,  2.12231481e+02,  5.38309807e+01,  2.14981414e+02,
#         3.08036764e+02,  2.97635483e+02,  4.39639628e+01,  9.15830763e+00,
#         8.93839274e+01, -1.21019190e+01,  1.39569509e+02,  7.62464803e+01,
#         4.77466865e+01,  1.65508993e+02, -2.28436289e+01,  9.67631713e+01,
#        -3.54575761e+01,  2.55609718e+02,  1.03176498e+01,  4.66756675e+01,
#         1.05399184e+02,  1.04479835e+00,  9.81722834e+01,  2.08952086e+02,
#         1.61112937e+02,  6.36886116e-01,  1.08547373e+02,  1.31718115e+01,
#        -3.18534300e+00,  1.71171124e+01,  1.10343600e+02,  6.98422686e+01,
#         2.21767941e+02,  3.94250135e+01,  3.04411175e+00,  2.02308478e+01,
#         2.80846183e+01,  1.39182681e+02, -2.34001298e+00,  5.41031965e+01,
#         2.59728986e+02,  1.18749499e+02,  2.17708856e+01,  2.93241682e+02,
#         2.86485151e+01,  1.33672808e+02,  9.28838699e+01,  2.00496139e+01,
#         1.66433716e+02,  1.76490352e+01,  6.59841797e+01,  7.22585157e+00,
#         1.93003690e+01,  1.18518906e+01,  8.20836684e+01,  3.03551375e+01,
#         4.27222191e+01,  1.96650802e+02,  4.08227020e+01,  3.76091558e+01,
#         6.29520253e+00,  1.25926211e+01,  3.76054455e+01,  1.30107904e+02,
#         1.80298078e+02,  1.11006460e+02,  1.69860424e+02,  5.42170730e+01,
#         1.51973840e+02,  6.27809322e+01,  5.56143290e+00,  3.03862453e+01,
#        -1.38612171e+01,  8.32535163e+01,  2.52228018e+02,  1.01055850e+02,
#         1.81751392e+02,  1.04308406e+02,  1.34750051e+02,  6.24234572e+01,
#         2.02571548e+02,  1.95417326e+02,  1.11669741e+02,  2.44869575e+02,
#         1.07749805e+02, -1.21171053e+01,  6.38037033e+01,  1.19368823e+02,
#         1.14996982e+01,  1.75077304e+02,  1.07136588e+02,  2.52640857e+01,
#         4.75828336e+01,  2.01604024e+01,  2.57889939e+02,  4.68958450e+00,
#        -1.97725860e+01,  1.17563904e+02,  1.96562126e+02,  2.31230153e+01,
#         2.09450845e+01,  2.41996790e+01,  9.02667626e+01,  1.49189811e+02,
#         4.67074300e+01,  1.32980152e+02,  5.84767917e+01,  6.26079880e+01,
#         2.81032172e+01,  4.40717735e+01,  1.19733689e+02,  2.90894024e+02,
#         1.42255032e+01,  1.15768105e+01,  3.14899411e+01,  2.34354523e+01,
#         4.31857738e+01,  4.56807368e+01,  3.18361786e+02,  1.03024434e+02,
#         6.71273582e+01,  3.24816423e+01,  2.20683530e+02,  1.74318905e+01,
#         6.33575777e+01,  4.82481618e+00,  1.26999101e+02,  5.13072060e+01,
#         2.01820352e+02,  1.29968012e+02,  9.49264002e+01,  3.81530223e+01,
#         1.78276111e+02,  5.97850716e+01,  3.32673560e+01,  2.48037768e+01,
#         3.17865557e+01,  5.32154823e+01,  1.69108155e+02, -1.42059694e+01,
#         1.33797621e+02,  1.14145412e+02,  3.74955453e+01,  2.04387087e+01,
#         1.03304665e+02,  1.46014574e+01,  5.57730184e+01,  2.69236435e+02,
#         2.08085563e+02,  3.85131428e+01,  1.29094223e+02,  1.21480120e+02,
#         2.08898743e+02,  6.05970386e+01,  2.16837522e+01,  2.06496438e+02,
#         4.45477013e+01,  1.63637817e+01,  6.74316504e+00, -8.72166511e+00,
#        -3.54316978e+00,  2.96834282e+01,  5.95832224e+01,  2.42127981e+02,
#        -5.53165040e+00,  1.14849961e+02,  4.58861675e+01,  2.06175162e+01,
#         1.46272461e+02,  1.98610722e+01,  1.66428044e+02,  1.90853434e+01,
#         3.24304472e+01,  1.02235751e+02,  1.53069432e+01,  6.29265529e+01,
#         1.90809811e+02,  4.81072701e+01,  2.16841111e+02,  6.45966738e+00,
#         8.57616680e+01,  4.69196794e+01,  3.11220306e+00,  1.70654701e+02,
#         2.52864108e+02,  2.56637072e+01,  2.46075708e+02,  1.96274974e+01,
#         6.41167358e+01,  3.67675748e+01,  2.52396103e+01,  2.31154421e+01,
#        -1.51744591e-01,  2.84136443e+02, -1.01934655e+01,  1.18438090e+02,
#         9.99158750e+01,  1.31824894e+01,  6.97588512e+01, -1.31510385e+01,
#         2.02797889e+02,  3.87081068e+00,  8.71904255e+01,  8.92226730e+01,
#         3.39590721e+01,  6.94901037e+01,  2.19000049e+01,  1.69139720e+02,
#         1.78631869e+00,  1.54789251e+02,  1.67677670e+02,  6.56393120e+01,
#         1.84133148e+01,  1.04110497e+02,  1.93681972e+01,  4.23943120e+01,
#         1.91615235e+02,  3.78725429e+01,  4.23354350e+01,  2.73104776e+02,
#        -1.01021475e+00,  7.89259942e+01,  4.49567879e+01,  6.99554014e+01,
#         2.10250818e+01,  9.03726198e+01,  7.06674342e+01,  1.07571117e+02,
#         4.00273301e+01,  7.35736178e+01,  6.04149240e+01,  2.34987202e+01,
#         1.31726211e+02,  4.28774443e+00,  7.55279103e+01,  1.32256809e+02,
#         1.00247391e+02,  4.17068677e+01,  2.06924686e+02,  1.03680156e+02])

# %%
# Creating copy of original dataframe to create a clean predictions dataframe with each player
fantasy_2024_predictions = prediction_data.copy()

# Creating a new column that holds model predictions & average per week score
fantasy_2024_predictions['fantasy_2024_score_prediction'] = predictions_2024
fantasy_2024_predictions['fantasy_2024_per_week_score_prediction'] = (predictions_2024/17)

# Rounding the fantasy score predictions & per week scores to 2 decimal places 
fantasy_2024_predictions['fantasy_2024_score_prediction'] = round(fantasy_2024_predictions['fantasy_2024_score_prediction'], 2)
fantasy_2024_predictions['fantasy_2024_per_week_score_prediction'] = round(fantasy_2024_predictions['fantasy_2024_per_week_score_prediction'], 2)


#### ================== ALL PLAYERS ========================= ####

# Chosing the columns that are shown in the dataframe
fantasy_2024_predictions = fantasy_2024_predictions[['name', 'team', 'position', 'fantasy_2024_score_prediction', 'fantasy_2024_per_week_score_prediction']]

# Sorting all players in descending order
fantasy_2024_predictions = fantasy_2024_predictions.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all players
display(fantasy_2024_predictions.reset_index(drop=True).head(10))

#### ================== WRs ========================= ####

# Filtering for WRs
fantasy_2024_predictions_WR = fantasy_2024_predictions[fantasy_2024_predictions['position'] == 'WR']

# # Sorting all WRs in descending order
fantasy_2024_predictions_WR = fantasy_2024_predictions_WR.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all WRs
display(fantasy_2024_predictions_WR.reset_index(drop=True).head(10))

#### ================== QBs ========================= ####

# Filtering for QBs
fantasy_2024_predictions_QB = fantasy_2024_predictions[fantasy_2024_predictions['position'] == 'QB']

# # Sorting all QBs in descending order
fantasy_2024_predictions_QB = fantasy_2024_predictions_QB.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all QBs
display(fantasy_2024_predictions_QB.reset_index(drop=True).head(10))

#### ================== RBs ========================= ####

# Filtering for RBs
fantasy_2024_predictions_RB = fantasy_2024_predictions[fantasy_2024_predictions['position'] == 'RB']

# # Sorting all RBs in descending order
fantasy_2024_predictions_RB = fantasy_2024_predictions_RB.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all RBs
display(fantasy_2024_predictions_RB.reset_index(drop=True).head(10))

#### ================== TEs ========================= ####

# Filtering for TEs
fantasy_2024_predictions_TE = fantasy_2024_predictions[fantasy_2024_predictions['position'] == 'TE']

# # Sorting all TEs in descending order
fantasy_2024_predictions_TE = fantasy_2024_predictions_TE.sort_values(by='fantasy_2024_score_prediction', ascending=False)

# Displaying all TEs
display(fantasy_2024_predictions_TE.reset_index(drop=True).head(10))
# Out:
#                name team position  fantasy_2024_score_prediction  \
# 0        Josh Allen  BUF       QB                         318.60
# 1        Puka Nacua   LA       WR                         318.36
# 2    Justin Herbert  LAC       QB                         308.04
# 3  Justin Jefferson  MIN       WR                         297.64
# 4     Lamar Jackson  BAL       QB                         293.24
# 5   Patrick Mahomes   KC       QB                         290.89
# 6   Trevor Lawrence  JAX       QB                         284.14
# 7       CeeDee Lamb  DAL       WR                         277.58
# 8      Alvin Kamara   NO       RB                         274.51
# 9       Tyreek Hill  MIA       WR                         273.10
#
#    fantasy_2024_per_week_score_prediction
# 0                                   18.74
# 1                                   18.73
# 2                                   18.12
# 3                                   17.51
# 4                                   17.25
# 5                                   17.11
# 6                                   16.71
# 7                                   16.33
# 8                                   16.15
# 9                                   16.06
#                 name team position  fantasy_2024_score_prediction  \
# 0         Puka Nacua   LA       WR                         318.36
# 1   Justin Jefferson  MIN       WR                         297.64
# 2        CeeDee Lamb  DAL       WR                         277.58
# 3        Tyreek Hill  MIA       WR                         273.10
# 4  Amon-Ra St. Brown  DET       WR                         269.45
# 5      Ja'Marr Chase  CIN       WR                         261.09
# 6       Keenan Allen  LAC       WR                         255.61
# 7     Garrett Wilson  NYJ       WR                         245.33
# 8         Mike Evans   TB       WR                         244.87
# 9    DeAndre Hopkins  TEN       WR                         243.39
#
#    fantasy_2024_per_week_score_prediction
# 0                                   18.73
# 1                                   17.51
# 2                                   16.33
# 3                                   16.06
# 4                                   15.85
# 5                                   15.36
# 6                                   15.04
# 7                                   14.43
# 8                                   14.40
# 9                                   14.32
#               name team position  fantasy_2024_score_prediction  \
# 0       Josh Allen  BUF       QB                         318.60
# 1   Justin Herbert  LAC       QB                         308.04
# 2    Lamar Jackson  BAL       QB                         293.24
# 3  Patrick Mahomes   KC       QB                         290.89
# 4  Trevor Lawrence  JAX       QB                         284.14
# 5   Russell Wilson  DEN       QB                         269.24
# 6      Jalen Hurts  PHI       QB                         268.01
# 7     Dak Prescott  DAL       QB                         266.98
# 8      C.J. Stroud  HOU       QB                         260.11
# 9     Kyler Murray  ARI       QB                         259.73
#
#    fantasy_2024_per_week_score_prediction
# 0                                   18.74
# 1                                   18.12
# 2                                   17.25
# 3                                   17.11
# 4                                   16.71
# 5                                   15.84
# 6                                   15.77
# 7                                   15.70
# 8                                   15.30
# 9                                   15.28
#                   name team position  fantasy_2024_score_prediction  \
# 0         Alvin Kamara   NO       RB                         274.51
# 1       Bijan Robinson  ATL       RB                         271.41
# 2  Christian McCaffrey   SF       RB                         260.97
# 3         Najee Harris  PIT       RB                         257.89
# 4      Ezekiel Elliott   NE       RB                         255.79
# 5       Travis Etienne  JAX       RB                         252.86
# 6          Josh Jacobs   LV       RB                         248.05
# 7         Jahmyr Gibbs  DET       RB                         231.89
# 8        Austin Ekeler  LAC       RB                         228.25
# 9            Joe Mixon  CIN       RB                         222.91
#
#    fantasy_2024_per_week_score_prediction
# 0                                   16.15
# 1                                   15.97
# 2                                   15.35
# 3                                   15.17
# 4                                   15.05
# 5                                   14.87
# 6                                   14.59
# 7                                   13.64
# 8                                   13.43
# 9                                   13.11
#              name team position  fantasy_2024_score_prediction  \
# 0    Travis Kelce   KC       TE                         246.08
# 1     Sam LaPorta  DET       TE                         208.90
# 2   George Kittle   SF       TE                         187.58
# 3    Mark Andrews  BAL       TE                         180.30
# 4  Dalton Kincaid  BUF       TE                         161.38
# 5     Evan Engram  JAX       TE                         157.95
# 6  T.J. Hockenson  MIN       TE                         146.27
# 7      Kyle Pitts  ATL       TE                         139.18
# 8    Jimmy Graham   NO       TE                         138.09
# 9  Dallas Goedert  PHI       TE                         134.59
#
#    fantasy_2024_per_week_score_prediction
# 0                                   14.48
# 1                                   12.29
# 2                                   11.03
# 3                                   10.61
# 4                                    9.49
# 5                                    9.29
# 6                                    8.60
# 7                                    8.19
# 8                                    8.12
# 9                                    7.92

# %% [markdown]
# # Creating csv files with results

# %%
# Saving all 524 players 2024 predictions data as a CSV file
fantasy_2024_predictions.to_csv('fantasy_football_2024_predictions.csv', index=False)

# %%
# Reorganizing columns and adding 2024 season column for concat of players past seasons fantasy scores data
fantasy_2024_predictions_trend = fantasy_2024_predictions.copy()
fantasy_2024_predictions_trend['season'] = 2024
fantasy_2024_predictions_trend = fantasy_2024_predictions_trend.rename(columns = {'fantasy_2024_score_prediction' : 'fantasy_points_ppr'})
fantasy_2024_predictions_trend = fantasy_2024_predictions_trend[['name','team', 'position','season','fantasy_points_ppr']]
fantasy_2024_predictions_trend.head()
# Out:
#                  name team position  season  fantasy_points_ppr
# 273        Josh Allen  BUF       QB    2024              318.60
# 402        Puka Nacua   LA       WR    2024              318.36
# 288    Justin Herbert  LAC       QB    2024              308.04
# 289  Justin Jefferson  MIN       WR    2024              297.64
# 327     Lamar Jackson  BAL       QB    2024              293.24

# %%
# Reorganizing columns for concat of 2024 data
all_seasons_data_trend = all_seasons_data.copy()
all_seasons_data_trend = all_seasons_data_trend[['name','team', 'position','season','fantasy_points_ppr']]
all_seasons_data_trend.head()
# Out:
#          name team position  season  fantasy_points_ppr
# 0  A.J. Brown  TEN       WR    2019               217.1
# 1  A.J. Brown  TEN       WR    2020               247.5
# 2  A.J. Brown  TEN       WR    2021               180.9
# 3  A.J. Brown  PHI       WR    2022               299.6
# 4  A.J. Brown  PHI       WR    2023               289.6

# %%
# Concatinating players past season fantasy scores with the models 2024 score predictions
score_trends_df = pd.concat([all_seasons_data_trend, fantasy_2024_predictions_trend], axis=0)

# Reogranizing columns and sorting by 'name' and then 'season'
score_trends_df = score_trends_df[['name', 'team', 'position', 'season', 'fantasy_points_ppr' ]]
score_trends_df = score_trends_df.sort_values(['name', 'season']).reset_index(drop = True)

score_trends_df.head(21)
# Out:
#            name team position  season  fantasy_points_ppr
# 0    A.J. Brown  TEN       WR    2019              217.10
# 1    A.J. Brown  TEN       WR    2020              247.50
# 2    A.J. Brown  TEN       WR    2021              180.90
# 3    A.J. Brown  PHI       WR    2022              299.60
# 4    A.J. Brown  PHI       WR    2023              289.60
# 5    A.J. Brown  PHI       WR    2024              241.00
# 6    A.T. Perry   NO       WR    2023               60.60
# 7    A.T. Perry   NO       WR    2024               62.04
# 8   AJ McCarron  CIN       QB    2017                2.64
# 9   AJ McCarron  HOU       QB    2019               16.90
# 10  AJ McCarron  HOU       QB    2020                0.80
# 11  AJ McCarron  CIN       QB    2023                0.76
# 12  AJ McCarron  CIN       QB    2024               12.16
# 13  Aaron Jones   GB       RB    2017               80.00
# 14  Aaron Jones   GB       RB    2018              171.40
# 15  Aaron Jones   GB       RB    2019              314.80
# 16  Aaron Jones   GB       RB    2020              258.90
# 17  Aaron Jones   GB       RB    2021              229.00
# 18  Aaron Jones   GB       RB    2022              248.60
# 19  Aaron Jones   GB       RB    2023              134.90
# 20  Aaron Jones   GB       RB    2024              202.40

# %%
score_trends_df.to_csv('fantasy_football_players_career_scores.csv', index=False)
